# %% [markdown]
# # 1. 20대 데이터 합치기

# %%
import pandas as pd

df_20th_1 = pd.read_csv("./[최종] 20대 국회 의안정보 1_12 페이지.csv")
df_20th_2 = pd.read_csv("./[최종] 20대 국회 의안정보 18페이지부터.csv")
df_20th_3 = pd.read_csv("./final-20th-bill-info.csv", encoding='utf-8-sig')

# %%
df_20th_3.head()
# Out:
#       의안번호 처리여부                                      의안명 제안자구분        제안일자  \
# 0  2013115    처    채용절차의 공정화에 관한 법률 일부개정법률안(권칠승의원 등 10인)    의원  2018-04-18
# 1  2013114    처               국세기본법 일부개정법률안(정병국의원 등 10인)    의원  2018-04-17
# 2  2013113    처                 특허법 일부개정법률안(조배숙의원 등 12인)    의원  2018-04-17
# 3  2013112    처                 상표법 일부개정법률안(조배숙의원 등 12인)    의원  2018-04-17
# 4  2013111    처              디자인보호법 일부개정법률안(조배숙의원 등 12인)    의원  2018-04-17
#
#          의결일자    의결결과  심사진행상태                   문서                    제안회기  \
# 0  2020-05-29  임기만료폐기     NaN  의안원문\n비용추계서 미첨부 사유서  제20대 (2016~2020) 제359회
# 1  2020-05-29  임기만료폐기     NaN                 의안원문  제20대 (2016~2020) 제359회
# 2  2018-12-07  대안반영폐기     NaN          의안원문\n비용추계서  제20대 (2016~2020) 제359회
# 3  2018-12-07  대안반영폐기     NaN          의안원문\n비용추계서  제20대 (2016~2020) 제359회
# 4  2018-12-07    수정가결     NaN          의안원문\n비용추계서  제20대 (2016~2020) 제359회
#
#                                                 제안이유            소관위원회  \
# 0  ['제안이유 및 주요내용현행법은 구인자가 채용대상자를 확정하였을 때 지체 없이 구직...          환경노동위원회
# 1  ['제안이유세무조사에 관한 기본적인 사항은 「국세기본법」에 규정되어 있으나, 세부적...          기획재정위원회
# 2  ['제안이유 및 주요내용중소기업, 학생, 기초생활수급자 등의 사회적 약자는 고비용이...  산업통상자원중소벤처기업위원회
# 3  ['제안이유 및 주요내용중소기업, 학생, 기초생활수급자 등의 사회적 약자는 고비용이...  산업통상자원중소벤처기업위원회
# 4  ['제안이유 및 주요내용중소기업, 학생, 기초생활수급자 등의 사회적 약자는 고비용이...  산업통상자원중소벤처기업위원회
#
#                                                  제안자
# 0  ['권칠승(더불어민주당/權七勝)', '김해영(더불어민주당/金海永)', '박재호(더불...
# 1  ['정병국(바른미래당/鄭柄國)', '김삼화(바른미래당/金三和)', '김성태(자유한국...
# 2  ['조배숙(민주평화당/趙培淑)', '김경진(민주평화당/金京鎭)', '김광수(민주평화...
# 3  ['조배숙(민주평화당/趙培淑)', '김경진(민주평화당/金京鎭)', '김광수(민주평화...
# 4  ['조배숙(민주평화당/趙培淑)', '김경진(민주평화당/金京鎭)', '김광수(민주평화...

# %%
a = [df_20th_1, df_20th_3, df_20th_2]

df_20th = pd.concat(a)
df_20th.head()
# Out:
#       의안번호 처리여부                                          의안명 제안자구분  \
# 0  ZZ23959    계             「인공지능산업 진흥에 관한 법률안」에 대한 의견표명 결정문    기타
# 1  2024996    처    집합건물의 소유 및 관리에 관한 법률 일부개정법률안(김병관의원 등 13인)    의원
# 2  2024995    처                    지방세법 일부개정법률안(김병관의원 등 10인)    의원
# 3  2024994    처      법률용어 정비를 위한 정보위원회 소관 2개 법률 일부개정을 위한 법률안   위원장
# 4  2024993    처              진실·화해를 위한 과거사정리 기본법 일부개정법률안(대안)   위원장
#
#          제안일자        의결일자    의결결과  심사진행상태                   문서  \
# 0  2020-05-28         NaN     NaN     NaN                 의안원문
# 1  2020-05-22  2020-05-29  임기만료폐기     NaN                 의안원문
# 2  2020-05-22  2020-05-29  임기만료폐기     NaN  의안원문\n비용추계서 미첨부 사유서
# 3  2020-05-20  2020-05-20    원안가결     NaN                 의안원문
# 4  2020-05-20  2020-05-20    원안가결     NaN                 의안원문
#
#                      제안회기                                               제안이유  \
# 0  제20대 (2016~2020) 제378회                                                NaN
# 1  제20대 (2016~2020) 제378회  ['■ 제안이유아파트 등 공동주택은 「공동주택관리법」에 의해 체계적으로 관리되고 있...
# 2  제20대 (2016~2020) 제378회  ['제안이유 및 주요내용현행법상 아파트 등 주택에 대한 재산세 과세표준은 국토교통부...
# 3  제20대 (2016~2020) 제378회                                                NaN
# 4  제20대 (2016~2020) 제378회                                                NaN
#
#      소관위원회                                                제안자  index
# 0      NaN                                                NaN    NaN
# 1  법제사법위원회  ['김병관(더불어민주당/金炳官)', '고용진(더불어민주당/高榕禛)', '김병욱(더불...    NaN
# 2  행정안전위원회  ['김병관(더불어민주당/金炳官)', '김철민(더불어민주당/金哲玟)', '박재호(더불...    NaN
# 3    정보위원회                                                NaN    NaN
# 4  행정안전위원회                                                NaN    NaN

# %%
df_20th.to_csv('20th.csv', encoding='utf-8-sig')

# %%
df_20th.tail()
# Out:
#          의안번호 처리여부                                                의안명 제안자구분  \
# 7216  2000005    처                         교육기본법 일부개정법률안(이찬열의원 등 10인)    의원
# 7217  2000004    처                         정부조직법 일부개정법률안(이종배의원 등 11인)    의원
# 7218  2000003    처                         근로기준법 일부개정법률안(이찬열의원 등 11인)    의원
# 7219  2000002    처             빅데이터의 이용 및 산업진흥 등에 관한 법률안(배덕광의원 등 14인)    의원
# 7220  2000001    처    통일경제파주특별자치시의 설치 및 파주평화경제특별구역의 조성·운영과 지원에 관한 ...    의원
#
#             제안일자        의결일자    의결결과  심사진행상태                     문서  \
# 7216  2016-05-30  2020-05-29  임기만료폐기     NaN          의안원문\r\n비용추계서
# 7217  2016-05-30  2020-05-29  임기만료폐기     NaN          의안원문\r\n비용추계서
# 7218  2016-05-30  2020-05-29  임기만료폐기     NaN                   의안원문
# 7219  2016-05-30  2020-05-29  임기만료폐기     NaN  의안원문\r\n비용추계서 미첨부 사유서
# 7220  2016-05-30  2020-05-29  임기만료폐기     NaN  의안원문\r\n비용추계서 미첨부 사유서
#
#                         제안회기  \
# 7216  제20대 (2016~2020) 제342회
# 7217  제20대 (2016~2020) 제342회
# 7218  제20대 (2016~2020) 제342회
# 7219  제20대 (2016~2020) 제342회
# 7220  제20대 (2016~2020) 제342회
#
#                                                    제안이유          소관위원회  \
# 7216  ['현행법은 국가와 지방자치단체가 경제적 이유로 교육을 받기 곤란한 자를 위하여 장...          교육위원회
# 7217  ['제안이유 및 주요내용통계청에 따르면 우리나라는 2000년에 65세 이상의 노인인...        행정안전위원회
# 7218  ['제안이유 및 주요내용지난 2015년 12월 고용노동부에서 발간한 ‘우리나라 노동...        환경노동위원회
# 7219  ['■ 제안이유빅데이터산업은 사물인터넷·클라우드 컴퓨팅 산업 등과 함께 정보통신산업...  과학기술정보방송통신위원회
# 7220  ['제안이유소득 양극화와 계층분화 심화ㆍ가계부채 심화ㆍ국가부채 급증ㆍ사회갈등 심화ㆍ...        외교통일위원회
#
#                                                     제안자  index
# 7216  ['이찬열(더불어민주당/李燦烈)', '김경협(더불어민주당/金炅俠)', '백재현(더불...    NaN
# 7217  ['이종배(새누리당/李鍾培)', '권성동(새누리당/權性東)', '김재경(새누리당/金...    NaN
# 7218  ['이찬열(더불어민주당/李燦烈)', '김경협(더불어민주당/金炅俠)', '김현미(더불...    NaN
# 7219  ['배덕광(새누리당/裵德光)', '김세연(새누리당/金世淵)', '김정훈(새누리당/金...    NaN
# 7220  ['박정(더불어민주당/朴釘)', '김경협(더불어민주당/金炅俠)', '노웅래(더불어민...    NaN

# %% [markdown]
# # 2. 21대 데이터 인코딩

# %%
df_21st = pd.read_csv("./final-21st-bill-info.csv", encoding='utf-8-sig')

# %%
df_21st.to_csv('21st.csv', encoding='utf-8-sig')

# %%
df_21st.tail()
# Out:
#          의안번호 처리여부                                          의안명 제안자구분  \
# 2959  2100005    계                  고등교육법 일부개정법률안(이종배의원 등 103인)    의원
# 2960  2100004    계    감염병의 예방 및 관리에 관한 법률 일부개정법률안(이종배의원 등 103인)    의원
# 2961  2100003    계         장애인활동 지원에 관한 법률 일부개정법률안(장제원의원 등 12인)    의원
# 2962  2100002    계                   정부조직법 일부개정법률안(신현영의원 등 12인)    의원
# 2963  2100001    계        공공기관의 사회적 가치 실현에 관한 기본법안(박광온의원 등 16인)    의원
#
#             제안일자 의결일자 의결결과 심사진행상태                   문서  \
# 2959  2020-06-01  NaN  NaN  소관위접수  의안원문\n비용추계서 미첨부 사유서
# 2960  2020-06-01  NaN  NaN  소관위심사  의안원문\n비용추계서 미첨부 사유서
# 2961  2020-06-01  NaN  NaN  소관위심사  의안원문\n비용추계서 미첨부 사유서
# 2962  2020-06-01  NaN  NaN  소관위접수          의안원문\n비용추계서
# 2963  2020-06-01  NaN  NaN  소관위접수                 의안원문
#
#                         제안회기  \
# 2959  제21대 (2020~2024) 제378회
# 2960  제21대 (2020~2024) 제378회
# 2961  제21대 (2020~2024) 제378회
# 2962  제21대 (2020~2024) 제378회
# 2963  제21대 (2020~2024) 제378회
#
#                                                    제안이유    소관위원회  \
# 2959  ['전대미문의 코로나-19 감염병의 장기간 창궐로 대학들은 감염병 예방을 위해 온라...    교육위원회
# 2960  ['제안이유 및 주요내용현행법에 따르면 감염병 확산방지를 위한 격리시설의 설치·운영...  보건복지위원회
# 2961  ['제안이유 및 주요내용현행법은 「노인장기요양보험법」에 따른 노인등을 활동지원급여 ...  보건복지위원회
# 2962  ['제안이유 및 주요내용코로나바이러스감염증-19(COVID-19) 대유행 이후 국가...  행정안전위원회
# 2963  ['제안이유세계적으로 양극화 및 불균형이라는 심각한 위기에 직면하고 있는 상황에서 ...  기획재정위원회
#
#                                                     제안자
# 2959                                                 []
# 2960  ['이종배(미래통합당/李鍾培)', '강기윤(미래통합당/姜起潤)', '강대식(미래통합...
# 2961                                                 []
# 2962  ['신현영(더불어민주당/申賢榮)', '고용진(더불어민주당/高榕禛)', '김경만(더불...
# 2963  ['박광온(더불어민주당/朴洸瑥)', '강병원(더불어민주당/姜炳遠)', '권칠승(더불...

# %% [markdown]
# # 3. 제안이유, 제안자 칼럼 전처리

# %%
df_20 = pd.read_csv("./20th.csv")
df_21 = pd.read_csv("./21st.csv")

# %%
# [''], [] 제거

df_20['제안이유'] = df_20['제안이유'].str[2:-2]
df_20['제안자'] = df_20['제안자'].str[1:-1]
df_21['제안이유'] = df_21['제안이유'].str[2:-2]
df_21['제안자'] = df_21['제안자'].str[1:-1]

# %%
# 콤마 기준 스플릿

df_20['제안자'] = df_20['제안자'].str.split(',')
df_21['제안자'] = df_21['제안자'].str.split(',')

# %%
df_20.head()
# Out:
#    Unnamed: 0     의안번호 처리여부                                          의안명  \
# 0           0  ZZ23959    계             「인공지능산업 진흥에 관한 법률안」에 대한 의견표명 결정문
# 1           1  2024996    처    집합건물의 소유 및 관리에 관한 법률 일부개정법률안(김병관의원 등 13인)
# 2           2  2024995    처                    지방세법 일부개정법률안(김병관의원 등 10인)
# 3           3  2024994    처      법률용어 정비를 위한 정보위원회 소관 2개 법률 일부개정을 위한 법률안
# 4           4  2024993    처              진실·화해를 위한 과거사정리 기본법 일부개정법률안(대안)
#
#   제안자구분        제안일자        의결일자    의결결과  심사진행상태                   문서  \
# 0    기타  2020-05-28         NaN     NaN     NaN                 의안원문
# 1    의원  2020-05-22  2020-05-29  임기만료폐기     NaN                 의안원문
# 2    의원  2020-05-22  2020-05-29  임기만료폐기     NaN  의안원문\n비용추계서 미첨부 사유서
# 3   위원장  2020-05-20  2020-05-20    원안가결     NaN                 의안원문
# 4   위원장  2020-05-20  2020-05-20    원안가결     NaN                 의안원문
#
#                      제안회기                                               제안이유  \
# 0  제20대 (2016~2020) 제378회                                                NaN
# 1  제20대 (2016~2020) 제378회  ■ 제안이유아파트 등 공동주택은 「공동주택관리법」에 의해 체계적으로 관리되고 있는 ...
# 2  제20대 (2016~2020) 제378회  제안이유 및 주요내용현행법상 아파트 등 주택에 대한 재산세 과세표준은 국토교통부가 ...
# 3  제20대 (2016~2020) 제378회                                                NaN
# 4  제20대 (2016~2020) 제378회                                                NaN
#
#      소관위원회                                                제안자  index
# 0      NaN                                                NaN    NaN
# 1  법제사법위원회  ['김병관(더불어민주당/金炳官)',  '고용진(더불어민주당/高榕禛)',  '김병욱(...    NaN
# 2  행정안전위원회  ['김병관(더불어민주당/金炳官)',  '김철민(더불어민주당/金哲玟)',  '박재호(...    NaN
# 3    정보위원회                                                NaN    NaN
# 4  행정안전위원회                                                NaN    NaN

# %%
# 20대 - '제안자' 이름만 따서 '제안의원'칼럼 생성


df_20['제안자'] = df_20['제안자'].fillna("a") #object of type 'float' has no len() 오류 해결


list1 = []

for i in range(len(df_20)):
    
    list2 = []
    
    if df_20['제안자'][i] != "a":
        
        for j in range(len(df_20['제안자'][i])):
            
            list2.append(df_20['제안자'][i][j].split('(')[0][1:])
            
        list1.append(list2)
    
    else:
        list1.append(np.NaN)
        
df_20['제안의원'] = list1

# %%
# 21대 - '제안자' 이름만 따서 '제안의원'칼럼 생성

df_21['제안자'] = df_21['제안자'].fillna("a") #object of type 'float' has no len() 오류 해결

list1 = []

for i in range(len(df_21)):
    
    list2 = []
    
    if df_21['제안자'][i] != "a":
        
        for j in range(len(df_21['제안자'][i])):
            
            list2.append(df_21['제안자'][i][j].split('(')[0][1:])
            
        list1.append(list2)
    
    else:
        list1.append(np.NaN)
        
df_21['제안의원'] = list1

# %%
# 20대 - '제안자' 당만 따서 '제안정당'칼럼 생성


list1 = []

for i in range(len(df_20)):
    
    list2 = []
    
    if df_20['제안자'][i] != "a":
        
        for j in range(len(df_20['제안자'][i])):
            
            list2.append(df_20['제안자'][i][j].split('(')[-1].split('/')[0])
            
        list1.append(list2)
    
    else:
        list1.append(np.NaN)
        
df_20['제안정당'] = list1

# %%
# 21대 - '제안자' 당만 따서 '제안정당'칼럼 생성


list1 = []

for i in range(len(df_21)):
    
    list2 = []
    
    if df_21['제안자'][i] != "a":
        
        for j in range(len(df_21['제안자'][i])):
            
            list2.append(df_21['제안자'][i][j].split('(')[-1].split('/')[0])
            
        list1.append(list2)
    
    else:
        list1.append(np.NaN)
        
df_21['제안정당'] = list1

# %%
# '의안명' 뒤에 괄호 지우기

for i in range(len(df_20['의안명'])):
    if '(' in df_20['의안명'][i]:
        df_20['의안명'][i] = df_20['의안명'][i].split('(')[0]
        

for i in range(len(df_21['의안명'])):
    if '(' in df_21['의안명'][i]:
        df_21['의안명'][i] = df_21['의안명'][i].split('(')[0]
# Out:
# /Users/ojoo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/ojoo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
for i in range(len(df_20)):
    try:
        df_20['제안정당'][i] = set(df_20['제안정당'][i])
        df_20['제안정당'][i] = list(df_20['제안정당'][i])
    except:
        pass



for i in range(len(df_21)):
    try:
        df_21['제안정당'][i] = set(df_21['제안정당'][i])
        df_21['제안정당'][i] = list(df_21['제안정당'][i])
    except:
        pass
# Out:
# /Users/ojoo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/ojoo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/ojoo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /Users/ojoo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]

# %%
# '제안이유' 칼럼에서 '주요내용' 뒷 내용만 따서 '주요내용'칼럼 만들기

df_20['주요내용']=''
for i in range(len(df_20)):
    
    if '주요내용' in str(df_20['제안이유'][i]):
        df_20['주요내용'][i] = df_20['제안이유'][i].split('주요내용')[-1]

df_21['주요내용']=''
for i in range(len(df_21)):
    
    if '주요내용' in str(df_21['제안이유'][i]):
        df_21['주요내용'][i] = df_21['제안이유'][i].split('주요내용')[-1]
# Out:
# /Users/ojoo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/ojoo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]

# %%
df_20['주요내용'].head(50)
# Out:
# 0
# 1     가. 지방자치단체의 장은 조사 또는 감사 결과 관리인에게 부정한 행위나 그 밖에 그...
# 2     현행법상 아파트 등 주택에 대한 재산세 과세표준은 국토교통부가 해마다 「부동산 가격...
# 3
# 4
# 5
# 6     가. 행정사 자격시험의 일부 면제 요건 강화(안 제9조제1항 및 제2항)나. 특별자...
# 7
# 8
# 9
# 10
# 11
# 12
# 13    가. 생활안정지원대상자에게 「의료급여법」에 따른 본인 부담금 및 비급여비용에 대한 ...
# 14
# 15
# 16
# 17    가. 한시적 양육비 긴급지원이 이루어진 경우 양육비 채무자에게 국세 체납처분의 예에...
# 18    가. ‘아동·청소년이용음란물’을 ‘아동·청소년성착취물’로 그 용어를 변경함(안 제2...
# 19    가. 가족친화 사회환경 조성 기본계획이 수립된 경우 여성가족부장관은 지체 없이 국회...
# 20    가. 배우자가 대한민국 국민이 아닌 외국인 가정폭력피해자도 외국인보호시설에 입소할 ...
# 21    전통무예 진흥을 위해 지방자치단체가 전통무예단체에 운영비를 지원할 수 있는 법적 근...
# 22    국가와 지방자치단체에 노인 건강을 위한 노인 체육 진흥 시책마련 의무를 부과하고, ...
# 23    가. 전문 이스포츠 용역과 관련한 표준계약서를 마련하고, 사용을 권장하려는 것임(안...
# 24    가. 이 법은 장애예술인의 문화예술 활동 지원에 필요한 사항을 정하여 장애예술인의 ...
# 25    가. 문화재매매업자에 대한 교육 실시의 근거를 마련함(안 제15조의2 신설).나. ...
# 26    가. 문화재청에 문화재수리 관련 계획 사항을 심의하기 위하여 문화재수리기술위원회를 ...
# 27    국회의 입법 및 정책활동에 대한 통합적인 공보기능을 강화하기 위하여 2009년 의장...
# 28    현행법에 따르면 과학기술정보통신부장관은 5년마다 과학기술발전에 관한 중·장기 정책목...
# 29
# 30    가. 연구기관의 감사제도를 폐지함(안 제11조 및 제12조)나. 연구회에 연구기관에...
# 31    가. 법률용어의 정비는 간단한 의미의 비전문적인 용어를 중심으로 법제적 및 국어학적...
# 32    가. 특구에서 연구기관 등이 연구개발 및 신기술 활성화를 위한 실증을 할 수 있고,...
# 33    가. 공인인증기관, 공인인증서 및 공인전자서명 제도의 폐지(안 제2조)과학기술정보통...
# 34    가. 정보통신망의 정상적인 보호·인증 절차를 우회하여 정보통신망에 접근할 수 있도록...
# 35    가. 연구활동종사자 건강보호의 중요성을 감안하여 목적 규정을 정비함(안 제1조).나...
# 36    가. 이 법의 목적 및 주요 용어 정의 등(안 제1장)1) 이 법은 지능정보화 관련...
# 37    가. 공공안전을 위해 불가피한 경우 예외적으로 전파차단장치를 운용할 수 있는 근거를...
# 38    가. 이용약관에 대한 인가제를 신고제로 전환하되, 이용자 보호 등을 위하여 전기통신...
# 39
# 40    가. 지역별 소프트웨어산업 진흥(안 제9조)지역별 특성에 기반한 소프트웨어산업의 진...
# 41    가. 법률용어의 정비는 간단한 의미의 비전문적인 용어를 중심으로 법제적 및 국어학적...
# 42    가. 골재채취업 양도 및 상속 신고를 받은 경우 7일 이내에 신고수리 여부를 신고인...
# 43    가. 교육？훈련 대행의 유효기간 및 갱신(안 제20조의3 신설)교육？훈련 대행의 유...
# 44    광역버스가 대도시권의 광역적인 교통수요를 상당 부분 해소하고 있음에도 불구하고 동 ...
# 45    가. 국토안전관리원을 설립하여 건설공사의 안전 및 품질관리, 시설물의 안전 및 유지...
# 46    가.부동산 조사？통계 전문기관으로서 기관의 성격을 분명히 드러낼 수 있도록 현행 사...
# 47    가. 공항운영자 또는 항공운송사업자가 탑승승객에 대한 본인일치여부 확인 등을 위해 ...
# 48    가. 철도운영자등이 안전관리체계를 지속적으로 유지하는지 점검·확인하기 위한 검사를 ...
# 49    가. 운항증명을 받은 국내항공운송사업자 또는 국제항공운송사업자가 제1항에 따라 항공...
# Name: 주요내용, dtype: object

# %% [markdown]
# # 3. 워드클라우드 함수

# %%
from konlpy.tag import Twitter
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import stopwords
# %matplotlib inline
import matplotlib 
from IPython.display import set_matplotlib_formats


def wordcloud(text_list):
    
    twitter = Twitter()
    morphs = []
    nv = []
    
    for sentence in text_list:
        morphs.append(twitter.pos(sentence))
    
    # 명사, 동사만 & 추가 조건
    for sentence in morphs:
        for word, tag in sentence:
            if (tag == ('Noun' or 'Verb')) and (len(word)!=1):
                nv.append(word)
    
    for word in nv:
        if word=='법률' or word=='경우' or word=='것임' or word=='대한' or word=='신설' or word=='규정' or word=='현행법' or word=='사업':
            nv.remove(word)
    
    # 빈도수 정렬
    count = Counter(nv)
    wordfreq = dict(count.most_common())
    

    
    # 디스플레이 설정
    
    matplotlib.rc('font',family = 'Malgun Gothic') 
    set_matplotlib_formats('retina') 
    matplotlib.rc('axes',unicode_minus = False)

    wordcloud = WordCloud(font_path="/Library/Fonts/NanumSquareL.ttf", background_color='white',colormap = "Accent_r", width=3000, height=2000).generate_from_frequencies(wordfreq) 
    plt.imshow(wordcloud) 
    plt.axis('off') 
    plt.show()

    return wordfreq

# %%
# !pip install Jpype
# Out:
# ERROR: Could not find a version that satisfies the requirement Jpype (from versions: none)
# ERROR: No matching distribution found for Jpype

# %% [markdown]
# # 4. 정당 별 워드클라우드

# %%
df = df_20['제안정당'].apply(lambda x: pd.Series(x))
df.columns = ['one','two','three','four','five','six','seven','eight']

df_ = df_21['제안정당'].apply(lambda x: pd.Series(x))
df_.columns = ['one','two','three','four','five','six','seven','eight']

# %%
# DF = 의안번호, 의안명, 주요내용, (제안정당 -> 칼럼화) 총 4개 칼럼


DF1 = df_20[['의안번호','의안명','주요내용']]

DF1 = pd.concat([DF1, df], axis = 1, sort=False)

DF2 = df_21[['의안번호','의안명','주요내용']]

DF2 = pd.concat([DF2, df_], axis = 1, sort=False)

# %%
DF1.head(50)
# Out:
#        의안번호                                                의안명  \
# 0   ZZ23959                   「인공지능산업 진흥에 관한 법률안」에 대한 의견표명 결정문
# 1   2024996                       집합건물의 소유 및 관리에 관한 법률 일부개정법률안
# 2   2024995                                       지방세법 일부개정법률안
# 3   2024994            법률용어 정비를 위한 정보위원회 소관 2개 법률 일부개정을 위한 법률안
# 4   2024993                        진실·화해를 위한 과거사정리 기본법 일부개정법률안
# 5   2024992             화재예방, 소방시설 설치·유지 및 안전관리에 관한 법률 일부개정법률안
# 6   2024991                                       행정사법 일부개정법률안
# 7   2024990                              재난 및 안전관리 기본법 일부개정법률안
# 8   2024989                          자전거 이용 활성화에 관한 법률 일부개정법률안
# 9   2024988                                      지방재정법 일부개정법률안
# 10  2024987             부마민주항쟁 관련자의 명예회복 및 보상 등에 관한 법률 일부개정법률안
# 11  2024986                             집회 및 시위에 관한 법률 일부개정법률안
# 12  2024985                                   소방시설공사업법 일부개정법률안
# 13  2024984    일제하 일본군위안부 피해자에 대한 보호ㆍ지원 및 기념사업 등에 관한 법률 일부개...
# 14  2024983                       다중이용업소의 안전관리에 관한 특별법 일부개정법률안
# 15  2024982                                      도로교통법 일부개정법률안
# 16  2024981                     소규모 공공시설 안전관리 등에 관한 법률 일부개정법률안
# 17  2024980                       양육비 이행확보 및 지원에 관한 법률 일부개정법률안
# 18  2024979                         아동·청소년의 성보호에 관한 법률 일부개정법률안
# 19  2024978                    가족친화 사회환경의 조성 촉진에 관한 법률 일부개정법률안
# 20  2024977                    가정폭력방지 및 피해자보호 등에 관한 법률 일부개정법률안
# 21  2024976                                    전통무예진흥법 일부개정법률안
# 22  2024975                                    국민체육진흥법 일부개정법률안
# 23  2024974                                               이스포츠
# 24  2024973                           장애예술인 문화예술 활동 지원에 관한 법률안
# 25  2024972                                     문화재보호법 일부개정법률안
# 26  2024971                             문화재수리 등에 관한 법률 일부개정법률안
# 27  2024970                                     국회사무처법 일부개정법률안
# 28  2024969                                    과학기술기본법 일부개정법률안
# 29  2024968                            2019년도 국정감사 결과보고서 채택의 건
# 30  2024967       과학기술분야 정부출연연구기관 등의 설립·운영 및 육성에 관한 법률 일부개정법률안
# 31  2024966    법률용어 정비를 위한 과학기술정보방송통신위원회 소관 32개 법률 일부개정을 위한...
# 32  2024965                         연구개발특구의 육성에 관한 특별법 일부개정법률안
# 33  2024964                                      전자서명법 전부개정법률안
# 34  2024963                 정보통신망 이용촉진 및 정보보호 등에 관한 법률 일부개정법률안
# 35  2024962                         연구실 안전환경 조성에 관한 법률 전부개정법률안
# 36  2024961                                  국가정보화 기본법 전부개정법률안
# 37  2024960                                        전파법 일부개정법률안
# 38  2024959                                    전기통신사업법 일부개정법률안
# 39  2024958         법률용어 정비를 위한 기획재정위원회 소관 33개 법률 일부개정을 위한 법률안
# 40  2024957                                소프트웨어산업 진흥법 전부개정법률안
# 41  2024956         법률용어 정비를 위한 국토교통위원회 소관 78개 법률 일부개정을 위한 법률안
# 42  2024955                                      골재채취법 일부개정법률안
# 43  2024954                                   건설기술 진흥법 일부개정법률안
# 44  2024953                       대도시권 광역교통 관리에 관한 특별법 일부개정법률안
# 45  2024952                                          국토안전관리원법안
# 46  2024951                                     한국감정원법 일부개정법률안
# 47  2024950                                      항공보안법 일부개정법률안
# 48  2024949                                      철도안전법 일부개정법률안
# 49  2024948                                      항공안전법 일부개정법률안
#
#                                                  주요내용     one  two three four  \
# 0                                                         NaN  NaN   NaN  NaN
# 1   가. 지방자치단체의 장은 조사 또는 감사 결과 관리인에게 부정한 행위나 그 밖에 그...  더불어민주당  NaN   NaN  NaN
# 2   현행법상 아파트 등 주택에 대한 재산세 과세표준은 국토교통부가 해마다 「부동산 가격...  더불어민주당  NaN   NaN  NaN
# 3                                                         NaN  NaN   NaN  NaN
# 4                                                         NaN  NaN   NaN  NaN
# 5                                                         NaN  NaN   NaN  NaN
# 6   가. 행정사 자격시험의 일부 면제 요건 강화(안 제9조제1항 및 제2항)나. 특별자...     NaN  NaN   NaN  NaN
# 7                                                         NaN  NaN   NaN  NaN
# 8                                                         NaN  NaN   NaN  NaN
# 9                                                         NaN  NaN   NaN  NaN
# 10                                                        NaN  NaN   NaN  NaN
# 11                                                        NaN  NaN   NaN  NaN
# 12                                                        NaN  NaN   NaN  NaN
# 13  가. 생활안정지원대상자에게 「의료급여법」에 따른 본인 부담금 및 비급여비용에 대한 ...     NaN  NaN   NaN  NaN
# 14                                                        NaN  NaN   NaN  NaN
# 15                                                        NaN  NaN   NaN  NaN
# 16                                                        NaN  NaN   NaN  NaN
# 17  가. 한시적 양육비 긴급지원이 이루어진 경우 양육비 채무자에게 국세 체납처분의 예에...     NaN  NaN   NaN  NaN
# 18  가. ‘아동·청소년이용음란물’을 ‘아동·청소년성착취물’로 그 용어를 변경함(안 제2...     NaN  NaN   NaN  NaN
# 19  가. 가족친화 사회환경 조성 기본계획이 수립된 경우 여성가족부장관은 지체 없이 국회...     NaN  NaN   NaN  NaN
# 20  가. 배우자가 대한민국 국민이 아닌 외국인 가정폭력피해자도 외국인보호시설에 입소할 ...     NaN  NaN   NaN  NaN
# 21  전통무예 진흥을 위해 지방자치단체가 전통무예단체에 운영비를 지원할 수 있는 법적 근...     NaN  NaN   NaN  NaN
# 22  국가와 지방자치단체에 노인 건강을 위한 노인 체육 진흥 시책마련 의무를 부과하고, ...     NaN  NaN   NaN  NaN
# 23  가. 전문 이스포츠 용역과 관련한 표준계약서를 마련하고, 사용을 권장하려는 것임(안...     NaN  NaN   NaN  NaN
# 24  가. 이 법은 장애예술인의 문화예술 활동 지원에 필요한 사항을 정하여 장애예술인의 ...     NaN  NaN   NaN  NaN
# 25  가. 문화재매매업자에 대한 교육 실시의 근거를 마련함(안 제15조의2 신설).나. ...     NaN  NaN   NaN  NaN
# 26  가. 문화재청에 문화재수리 관련 계획 사항을 심의하기 위하여 문화재수리기술위원회를 ...     NaN  NaN   NaN  NaN
# 27  국회의 입법 및 정책활동에 대한 통합적인 공보기능을 강화하기 위하여 2009년 의장...     NaN  NaN   NaN  NaN
# 28  현행법에 따르면 과학기술정보통신부장관은 5년마다 과학기술발전에 관한 중·장기 정책목...     NaN  NaN   NaN  NaN
# 29                                                        NaN  NaN   NaN  NaN
# 30  가. 연구기관의 감사제도를 폐지함(안 제11조 및 제12조)나. 연구회에 연구기관에...     NaN  NaN   NaN  NaN
# 31  가. 법률용어의 정비는 간단한 의미의 비전문적인 용어를 중심으로 법제적 및 국어학적...     NaN  NaN   NaN  NaN
# 32  가. 특구에서 연구기관 등이 연구개발 및 신기술 활성화를 위한 실증을 할 수 있고,...     NaN  NaN   NaN  NaN
# 33  가. 공인인증기관, 공인인증서 및 공인전자서명 제도의 폐지(안 제2조)과학기술정보통...     NaN  NaN   NaN  NaN
# 34  가. 정보통신망의 정상적인 보호·인증 절차를 우회하여 정보통신망에 접근할 수 있도록...     NaN  NaN   NaN  NaN
# 35  가. 연구활동종사자 건강보호의 중요성을 감안하여 목적 규정을 정비함(안 제1조).나...     NaN  NaN   NaN  NaN
# 36  가. 이 법의 목적 및 주요 용어 정의 등(안 제1장)1) 이 법은 지능정보화 관련...     NaN  NaN   NaN  NaN
# 37  가. 공공안전을 위해 불가피한 경우 예외적으로 전파차단장치를 운용할 수 있는 근거를...     NaN  NaN   NaN  NaN
# 38  가. 이용약관에 대한 인가제를 신고제로 전환하되, 이용자 보호 등을 위하여 전기통신...     NaN  NaN   NaN  NaN
# 39                                                        NaN  NaN   NaN  NaN
# 40  가. 지역별 소프트웨어산업 진흥(안 제9조)지역별 특성에 기반한 소프트웨어산업의 진...     NaN  NaN   NaN  NaN
# 41  가. 법률용어의 정비는 간단한 의미의 비전문적인 용어를 중심으로 법제적 및 국어학적...     NaN  NaN   NaN  NaN
# 42  가. 골재채취업 양도 및 상속 신고를 받은 경우 7일 이내에 신고수리 여부를 신고인...     NaN  NaN   NaN  NaN
# 43  가. 교육？훈련 대행의 유효기간 및 갱신(안 제20조의3 신설)교육？훈련 대행의 유...     NaN  NaN   NaN  NaN
# 44  광역버스가 대도시권의 광역적인 교통수요를 상당 부분 해소하고 있음에도 불구하고 동 ...     NaN  NaN   NaN  NaN
# 45  가. 국토안전관리원을 설립하여 건설공사의 안전 및 품질관리, 시설물의 안전 및 유지...     NaN  NaN   NaN  NaN
# 46  가.부동산 조사？통계 전문기관으로서 기관의 성격을 분명히 드러낼 수 있도록 현행 사...     NaN  NaN   NaN  NaN
# 47  가. 공항운영자 또는 항공운송사업자가 탑승승객에 대한 본인일치여부 확인 등을 위해 ...     NaN  NaN   NaN  NaN
# 48  가. 철도운영자등이 안전관리체계를 지속적으로 유지하는지 점검·확인하기 위한 검사를 ...     NaN  NaN   NaN  NaN
# 49  가. 운항증명을 받은 국내항공운송사업자 또는 국제항공운송사업자가 제1항에 따라 항공...     NaN  NaN   NaN  NaN
#
#    five  six seven eight
# 0   NaN  NaN   NaN   NaN
# 1   NaN  NaN   NaN   NaN
# 2   NaN  NaN   NaN   NaN
# 3   NaN  NaN   NaN   NaN
# 4   NaN  NaN   NaN   NaN
# 5   NaN  NaN   NaN   NaN
# 6   NaN  NaN   NaN   NaN
# 7   NaN  NaN   NaN   NaN
# 8   NaN  NaN   NaN   NaN
# 9   NaN  NaN   NaN   NaN
# 10  NaN  NaN   NaN   NaN
# 11  NaN  NaN   NaN   NaN
# 12  NaN  NaN   NaN   NaN
# 13  NaN  NaN   NaN   NaN
# 14  NaN  NaN   NaN   NaN
# 15  NaN  NaN   NaN   NaN
# 16  NaN  NaN   NaN   NaN
# 17  NaN  NaN   NaN   NaN
# 18  NaN  NaN   NaN   NaN
# 19  NaN  NaN   NaN   NaN
# 20  NaN  NaN   NaN   NaN
# 21  NaN  NaN   NaN   NaN
# 22  NaN  NaN   NaN   NaN
# 23  NaN  NaN   NaN   NaN
# 24  NaN  NaN   NaN   NaN
# 25  NaN  NaN   NaN   NaN
# 26  NaN  NaN   NaN   NaN
# 27  NaN  NaN   NaN   NaN
# 28  NaN  NaN   NaN   NaN
# 29  NaN  NaN   NaN   NaN
# 30  NaN  NaN   NaN   NaN
# 31  NaN  NaN   NaN   NaN
# 32  NaN  NaN   NaN   NaN
# 33  NaN  NaN   NaN   NaN
# 34  NaN  NaN   NaN   NaN
# 35  NaN  NaN   NaN   NaN
# 36  NaN  NaN   NaN   NaN
# 37  NaN  NaN   NaN   NaN
# 38  NaN  NaN   NaN   NaN
# 39  NaN  NaN   NaN   NaN
# 40  NaN  NaN   NaN   NaN
# 41  NaN  NaN   NaN   NaN
# 42  NaN  NaN   NaN   NaN
# 43  NaN  NaN   NaN   NaN
# 44  NaN  NaN   NaN   NaN
# 45  NaN  NaN   NaN   NaN
# 46  NaN  NaN   NaN   NaN
# 47  NaN  NaN   NaN   NaN
# 48  NaN  NaN   NaN   NaN
# 49  NaN  NaN   NaN   NaN

# %%
# 당이름 확인

print(df['one'].value_counts())
print(df['two'].value_counts())
print(df['three'].value_counts())
print(df['four'].value_counts())
print(df['five'].value_counts())
print(df['six'].value_counts())
print(df['seven'].value_counts())
print(df['eight'].value_counts())
# Out:
# 더불어민주당        5753
# 국민의당          4829
# 바른미래당         3991
# 자유한국당         2792
# 정의당           1822
#               1648
# 새누리당           882
# 민주평화당          847
# 바른정당           470
# 무소속            317
# 개혁보수신당          39
# 미래통합당           39
# 우리공화당           35
# 대한애국당           33
#  ''             21
# 더불어시민당          19
# 새로운보수당          15
# 대안신당            14
# 미래한국당           10
# 민생당             10
# 미래를향한전진4.0       2
# 민중당              2
# 비)               1
# Name: one, dtype: int64
# 더불어민주당    7296
# 자유한국당     1911
# 민주평화당     1543
# 무소속        862
# 국민의당       523
# 새누리당       443
# 바른미래당      356
# 바른정당       267
# 정의당        147
# 민중당         44
#  ''         35
# 미래한국당       18
# 대안신당        13
# 미래통합당       12
# 개혁보수신당      10
# 우리공화당        9
# 새로운보수당       8
# 민생당          6
# 대한애국당        2
# 새민중정당        1
# 비)           1
# 더불어시민당       1
# Name: two, dtype: int64
# 더불어민주당        1907
# 무소속           1224
# 자유한국당         1025
# 민주평화당          695
# 새누리당           506
# 바른정당           284
# 정의당            276
# 바른미래당          261
# 민중당             75
# 국민의당            60
#  ''             28
# 새민중정당           17
# 미래한국당           10
# 개혁보수신당           7
# 대안신당             7
# 미래통합당            6
# 우리공화당            2
# 미래를향한전진4.0       2
# 민생당              2
# 비)               1
# Name: three, dtype: int64
# 무소속       849
# 자유한국당     606
# 더불어민주당    353
# 정의당       122
# 바른정당       71
# 민중당        66
# 바른미래당      60
# 민주평화당      31
# 새누리당       24
#  ''        14
# 새민중정당       5
# 국민의당        3
# 개혁보수신당      3
# 미래한국당       2
# 더불어시민당      2
# 대안신당        1
# 민생당         1
# Name: four, dtype: int64
# 무소속       288
# 자유한국당     140
# 민중당        33
# 더불어민주당     32
# 미래한국당       3
# 미래통합당       1
# 바른미래당       1
# Name: five, dtype: int64
# 자유한국당     34
# 무소속       30
# 민중당        4
# 민생당        1
# 더불어민주당     1
# 새민중정당      1
# Name: six, dtype: int64
# 자유한국당    4
# 무소속      3
# 민중당      2
# Name: seven, dtype: int64
# 무소속      1
# 자유한국당    1
# Name: eight, dtype: int64

# %%
# 20대
DM = [] # 더불어민주당
MT = [] # 미래통합당
MS = [] # 무소속
JH = [] # 자유한국당
KM = [] # 국민의당
SN = [] # 새누리당
BM = [] # 바른미래당
JE = [] # 정의당

# 21대
DM_ = [] # 더불어민주당
MT_ = [] # 미래통합당
JE_ = [] # 정의당

# %%
# '제안정당'에 '~당'이 포함되는 경우 각 정당 리스트에 '제안이유' 텍스트 넣기


for i in range(len(DF1)):
    if '더불어민주당' in (str(DF1['one'][i]) or str(DF1['two'][i]) or str(DF1['three'][i]) or str(DF1['four'][i]) or str(DF1['five'][i]) or str(DF1['six'][i]) or str(DF1['seven'][i]) or str(DF1['eight'][i])):
        DM.append(DF1['주요내용'][i])


for i in range(len(DF1)):
    if '미래통합당' in (str(DF1['one'][i]) or str(DF1['two'][i]) or str(DF1['three'][i]) or str(DF1['four'][i]) or str(DF1['five'][i]) or str(DF1['six'][i]) or str(DF1['seven'][i]) or str(DF1['eight'][i])):
        MT.append(DF1['주요내용'][i])
        
        
for i in range(len(DF1)):
    if '무소속' in (str(DF1['one'][i]) or str(DF1['two'][i]) or str(DF1['three'][i]) or str(DF1['four'][i]) or str(DF1['five'][i]) or str(DF1['six'][i]) or str(DF1['seven'][i]) or str(DF1['eight'][i])):
        MS.append(DF1['주요내용'][i])
        
        
for i in range(len(DF1)):
    if '자유한국당' in (str(DF1['one'][i]) or str(DF1['two'][i]) or str(DF1['three'][i]) or str(DF1['four'][i]) or str(DF1['five'][i]) or str(DF1['six'][i]) or str(DF1['seven'][i]) or str(DF1['eight'][i])):
        JH.append(DF1['주요내용'][i])
        
        
for i in range(len(DF1)):
    if '국민의당' in (str(DF1['one'][i]) or str(DF1['two'][i]) or str(DF1['three'][i]) or str(DF1['four'][i]) or str(DF1['five'][i]) or str(DF1['six'][i]) or str(DF1['seven'][i]) or str(DF1['eight'][i])):
        KM.append(DF1['주요내용'][i])
        
        
for i in range(len(DF1)):
    if '새누리당' in (str(DF1['one'][i]) or str(DF1['two'][i]) or str(DF1['three'][i]) or str(DF1['four'][i]) or str(DF1['five'][i]) or str(DF1['six'][i]) or str(DF1['seven'][i]) or str(DF1['eight'][i])):
        SN.append(DF1['주요내용'][i])
        
        
for i in range(len(DF1)):
    if '바른미래당' in (str(DF1['one'][i]) or str(DF1['two'][i]) or str(DF1['three'][i]) or str(DF1['four'][i]) or str(DF1['five'][i]) or str(DF1['six'][i]) or str(DF1['seven'][i]) or str(DF1['eight'][i])):
        BM.append(DF1['주요내용'][i])

        
for i in range(len(DF1)):
    if '정의당' in (str(DF1['one'][i]) or str(DF1['two'][i]) or str(DF1['three'][i]) or str(DF1['four'][i]) or str(DF1['five'][i]) or str(DF1['six'][i]) or str(DF1['seven'][i]) or str(DF1['eight'][i])):
        JE.append(DF1['주요내용'][i])
        
        
for i in range(len(DF2)):
    if '더불어민주당' in (str(DF2['one'][i]) or str(DF2['two'][i]) or str(DF2['three'][i]) or str(DF2['four'][i]) or str(DF2['five'][i]) or str(DF2['six'][i]) or str(DF2['seven'][i]) or str(DF2['eight'][i])):
        DM_.append(DF2['주요내용'][i])
        
        
for i in range(len(DF2)):
    if '미래통합당' in (str(DF2['one'][i]) or str(DF2['two'][i]) or str(DF2['three'][i]) or str(DF2['four'][i]) or str(DF2['five'][i]) or str(DF2['six'][i]) or str(DF2['seven'][i]) or str(DF2['eight'][i])):
        MT_.append(DF2['주요내용'][i])
        
        
for i in range(len(DF2)):
    if '정의당' in (str(DF2['one'][i]) or str(DF2['two'][i]) or str(DF2['three'][i]) or str(DF2['four'][i]) or str(DF2['five'][i]) or str(DF2['six'][i]) or str(DF2['seven'][i]) or str(DF2['eight'][i])):
        JE_.append(DF2['주요내용'][i])

# %%
# 더불어민주당 20
wordcloud(DM)
# Out:
# {'관리': 2682,
#  '위원회': 2501,
#  '지원': 2364,
#  '관련': 2283,
#  '국가': 2156,
#  '사항': 2129,
#  '계획': 2025,
#  '지역': 2013,
#  '국민': 2007,
#  '기관': 1978,
#  '해당': 1868,
#  '시설': 1857,
#  '행위': 1776,
#  '운영': 1776,
#  '발생': 1748,
#  '장관': 1746,
#  '마련': 1633,
#  '의결': 1616,
#  '근거': 1610,
#  '보호': 1600,
#  '업무': 1570,
#  '안전': 1563,
#  '시행': 1538,
#  '지방자치단체': 1445,
#  '설치': 1428,
#  '사용': 1401,
#  '제도': 1391,
#  '의무': 1366,
#  '신설': 1365,
#  '대하': 1362,
#  '정보': 1351,
#  '거나': 1341,
#  '개정': 1330,
#  '산업': 1323,
#  '교육': 1310,
#  '이상': 1308,
#  '이하': 1299,
#  '대상': 1219,
#  '기준': 1212,
#  '제공': 1199,
#  '현행법': 1183,
#  '조정': 1182,
#  '사회': 1167,
#  '위해': 1124,
#  '항제': 1103,
#  '사업자': 1102,
#  '수립': 1099,
#  '일부': 1079,
#  '조사': 1076,
#  '지정': 1075,
#  '현행': 1054,
#  '기간': 1054,
#  '수행': 1043,
#  '이용': 998,
#  '기업': 997,
#  '공무원': 997,
#  '사람': 966,
#  '포함': 962,
#  '위반': 960,
#  '상황': 954,
#  '지급': 954,
#  '대해': 944,
#  '피해': 926,
#  '부담': 917,
#  '기술': 902,
#  '업자': 893,
#  '목적': 889,
#  '최근': 889,
#  '정부': 887,
#  '필요': 887,
#  '범위': 879,
#  '심의': 878,
#  '처벌': 876,
#  '제출': 875,
#  '적용': 874,
#  '실시': 871,
#  '제한': 865,
#  '개발': 854,
#  '보장': 828,
#  '지적': 824,
#  '정책': 817,
#  '발전': 810,
#  '근로자': 802,
#  '사유': 800,
#  '또한': 797,
#  '관계': 794,
#  '의료': 792,
#  '제기': 775,
#  '실정': 773,
#  '개선': 772,
#  '번호': 765,
#  '금지': 764,
#  '주택': 762,
#  '확보': 751,
#  '조치': 745,
#  '추진': 740,
#  '기금': 732,
#  '금융투자': 731,
#  '문제': 728,
#  '대표': 726,
#  '변경': 716,
#  '결과': 706,
#  '신고': 705,
#  '신청': 704,
#  '자료': 700,
#  '서비스': 696,
#  '절차': 695,
#  '요구': 694,
#  '의안': 692,
#  '부과': 690,
#  '문화': 678,
#  '환경': 676,
#  '평가': 673,
#  '국회': 672,
#  '등록': 671,
#  '공공기관': 669,
#  '학교': 665,
#  '자동차': 663,
#  '활동': 659,
#  '범죄': 652,
#  '내용': 652,
#  '인정': 651,
#  '명시': 649,
#  '방지': 648,
#  '체계': 644,
#  '보험': 643,
#  '확대': 638,
#  '비용': 633,
#  '결정': 625,
#  '추가': 620,
#  '위원': 608,
#  '계약': 606,
#  '재정': 602,
#  '의원': 595,
#  '예방': 595,
#  '시장': 594,
#  '생활': 593,
#  '지방': 584,
#  '법령': 584,
#  '자격': 584,
#  '기본': 579,
#  '구역': 579,
#  '금액': 579,
#  '허가': 565,
#  '거래': 565,
#  '중소기업': 564,
#  '경제': 562,
#  '법적': 557,
#  '한국': 555,
#  '통해': 554,
#  '현재': 554,
#  '권리': 554,
#  '위탁': 554,
#  '대통령령': 552,
#  '한편': 552,
#  '건강': 552,
#  '심사': 551,
#  '처리': 549,
#  '불구': 549,
#  '공사': 549,
#  '단체': 545,
#  '정비': 540,
#  '진흥': 537,
#  '사건': 535,
#  '의견': 533,
#  '증가': 531,
#  '다른': 518,
#  '소득': 517,
#  '확인': 517,
#  '사실': 515,
#  '건설': 514,
#  '이행': 514,
#  '협력': 511,
#  '요청': 509,
#  '방법': 509,
#  '검사': 501,
#  '직무': 499,
#  '사고': 499,
#  '중앙': 496,
#  '활성화': 496,
#  '피해자': 495,
#  '삭제': 494,
#  '효율': 490,
#  '참고': 487,
#  '수정': 483,
#  '재산': 483,
#  '주민': 481,
#  '특례': 481,
#  '이내': 472,
#  '발의': 468,
#  '고려': 468,
#  '제외': 468,
#  '징역': 463,
#  '법인': 459,
#  '과정': 459,
#  '안정': 454,
#  '예산': 452,
#  '청소년': 451,
#  '지속': 451,
#  '경찰': 451,
#  '청구': 450,
#  '전제': 449,
#  '고용': 449,
#  '복지': 447,
#  '일반': 446,
#  '기여': 444,
#  '촉진': 443,
#  '설립': 443,
#  '명령': 442,
#  '회의': 442,
#  '안이': 439,
#  '투자': 438,
#  '호의': 438,
#  '민간': 438,
#  '협의': 434,
#  '직접': 433,
#  '소속': 429,
#  '금융': 428,
#  '급여': 426,
#  '자격증': 424,
#  '규정': 423,
#  '요건': 420,
#  '교통': 420,
#  '여부': 415,
#  '침해': 413,
#  '이익': 412,
#  '공급': 411,
#  '활용': 410,
#  '벌금': 409,
#  '선거': 409,
#  '납부': 406,
#  '판매': 403,
#  '공익': 403,
#  '취소': 402,
#  '승인': 401,
#  '사무': 401,
#  '책임': 398,
#  '장애인': 397,
#  '종사': 395,
#  '유지': 393,
#  '행정': 393,
#  '아동': 392,
#  '수준': 392,
#  '종합': 391,
#  '규제': 390,
#  '운용': 388,
#  '실질': 388,
#  '실효': 386,
#  '근로': 386,
#  '반영': 386,
#  '도입': 384,
#  '행정기관': 383,
#  '처분': 379,
#  '우려': 377,
#  '이유': 377,
#  '관할': 377,
#  '것이므': 374,
#  '구성': 372,
#  '전문': 372,
#  '기능': 369,
#  '공개': 368,
#  '특별': 367,
#  '학생': 364,
#  '성과': 363,
#  '분야': 361,
#  '집행': 360,
#  '정의': 360,
#  '소비자': 360,
#  '과태료': 355,
#  '참여': 354,
#  '조항': 353,
#  '국내': 352,
#  '제재': 351,
#  '도지사': 351,
#  '증진': 350,
#  '센터': 350,
#  '법원': 349,
#  '제품': 349,
#  '작성': 346,
#  '수급': 345,
#  '보전': 345,
#  '혁신': 344,
#  '알선': 343,
#  '용어': 342,
#  '사전': 342,
#  '회사': 342,
#  '대학': 342,
#  '감독': 339,
#  '도모': 338,
#  '강화': 337,
#  '부여': 336,
#  '보상': 335,
#  '일정': 334,
#  '가맹': 333,
#  '비율': 332,
#  '어린이': 331,
#  '장기': 330,
#  '대책': 326,
#  '따라서': 325,
#  '도록': 324,
#  '사례': 323,
#  '재난': 323,
#  '개인': 323,
#  '대여': 322,
#  '영향': 322,
#  '취득': 321,
#  '인력': 321,
#  '실태': 320,
#  '국토교통부': 319,
#  '효과': 314,
#  '건축물': 313,
#  '인구': 313,
#  '부정': 312,
#  '방송': 312,
#  '인증': 312,
#  '도시': 309,
#  '위험': 308,
#  '조성': 306,
#  '연구': 305,
#  '대응': 304,
#  '퇴직': 304,
#  '필요성': 301,
#  '점검': 301,
#  '확정': 300,
#  '국제': 298,
#  '행사': 295,
#  '보고': 294,
#  '의사': 292,
#  '토지': 291,
#  '공제': 291,
#  '로서': 290,
#  '청년': 290,
#  '수단': 288,
#  '주체': 287,
#  '각종': 286,
#  '우리나라': 286,
#  '자의': 284,
#  '임금': 284,
#  '별도': 284,
#  '재원': 282,
#  '권한': 282,
#  '상품': 282,
#  '규모': 281,
#  '분쟁': 280,
#  '취업': 280,
#  '직원': 280,
#  '성폭력': 276,
#  '보건': 275,
#  '이해': 275,
#  '이용자': 274,
#  '자가': 272,
#  '매년': 272,
#  '보건복지부': 271,
#  '방식': 270,
#  '임원': 270,
#  '체결': 269,
#  '치료': 268,
#  '불법': 264,
#  '구축': 264,
#  '자녀': 263,
#  '도로': 263,
#  '소송': 262,
#  '남북': 262,
#  '생산': 261,
#  '허용': 261,
#  '가족': 261,
#  '통상': 261,
#  '가격': 260,
#  '통합': 260,
#  '주거': 260,
#  '상의': 259,
#  '이후': 259,
#  '과학기술': 259,
#  '폐지': 258,
#  '개인정보': 258,
#  '어려움': 257,
#  '가입': 257,
#  '향상': 256,
#  '생명': 256,
#  '보유': 255,
#  '유통': 255,
#  '권고': 255,
#  '사망': 255,
#  '창업': 254,
#  '신체': 252,
#  '준수': 252,
#  '운송': 252,
#  '조직': 251,
#  '후보자': 251,
#  '초과': 249,
#  '장치': 249,
#  '보완': 249,
#  '보조금': 249,
#  '정당': 248,
#  '표현': 248,
#  '대상자': 247,
#  '국세': 244,
#  '소방': 244,
#  '사후': 243,
#  '기반': 243,
#  '주의': 243,
#  '취지': 241,
#  '자치': 241,
#  '손실': 240,
#  '국회의원': 240,
#  '상향': 240,
#  '원칙': 240,
#  '기구': 239,
#  '일본': 239,
#  '해소': 238,
#  '통한': 238,
#  '노인': 236,
#  '연금': 235,
#  '감사': 234,
#  '완화': 234,
#  '특수': 233,
#  '기록': 233,
#  '면제': 232,
#  '업체': 230,
#  '과세': 229,
#  '임대': 229,
#  '영업': 229,
#  '시정': 229,
#  '차량': 229,
#  '임명': 228,
#  '체육': 228,
#  '화재': 227,
#  '정관': 227,
#  '수사': 227,
#  '자금': 226,
#  '구분': 225,
#  '거짓': 225,
#  '대통령': 225,
#  '차별': 224,
#  '주요': 224,
#  '정치': 223,
#  '재해': 222,
#  '현장': 222,
#  '주변': 221,
#  '인사': 221,
#  '현실': 221,
#  '문장': 221,
#  '수입': 220,
#  '방안': 220,
#  '실제': 220,
#  '투표': 220,
#  '환자': 219,
#  '구체': 219,
#  '합리': 218,
#  '통지': 217,
#  '보조': 217,
#  '능력': 217,
#  '채용': 217,
#  '군수': 216,
#  '폐기물': 216,
#  '수익': 215,
#  '세액': 215,
#  '적극': 214,
#  '개월': 214,
#  '소관': 214,
#  '관광': 214,
#  '구조': 213,
#  '특정': 213,
#  '정도': 213,
#  '육성': 212,
#  '에너지': 212,
#  '장애': 212,
#  '산정': 211,
#  '시스템': 211,
#  '공단': 210,
#  '매매': 210,
#  '지구': 209,
#  '형사': 209,
#  '결격': 208,
#  '대한민국': 207,
#  '손해': 207,
#  '진행': 206,
#  '시간': 206,
#  '상태': 206,
#  '부동산': 205,
#  '위임': 205,
#  '선고': 204,
#  '공표': 204,
#  '조합': 204,
#  '고하': 203,
#  '사용자': 203,
#  '제대로': 202,
#  '이전': 202,
#  '교원': 202,
#  '연도': 201,
#  '로부터': 201,
#  '전체': 201,
#  '때문': 201,
#  '한정': 201,
#  '단서': 201,
#  '제정': 199,
#  '기한': 199,
#  '전자': 199,
#  '기초': 199,
#  '역할': 198,
#  '경영': 197,
#  '미만': 197,
#  '교류': 197,
#  '우선': 196,
#  '입법': 196,
#  '연장': 196,
#  '보급': 196,
#  '기존': 195,
#  '해외': 195,
#  '노력': 195,
#  '형평성': 195,
#  '근무': 194,
#  '수용': 194,
#  '당사자': 194,
#  '임용': 194,
#  '추천': 194,
#  '공동': 193,
#  '선정': 193,
#  '교육부': 193,
#  '물질': 193,
#  '표시': 192,
#  '채권': 191,
#  '가능성': 190,
#  '청장': 190,
#  '우리': 190,
#  '외국인': 189,
#  '교부': 189,
#  '실적': 189,
#  '연구개발': 189,
#  '임차': 189,
#  '손해배상': 188,
#  '개별': 188,
#  '현황': 187,
#  '벌칙': 186,
#  '설비': 186,
#  '판단': 186,
#  '해결': 185,
#  '공인': 185,
#  '공유': 184,
#  '조건': 184,
#  '편의': 184,
#  '징수': 184,
#  '통계': 184,
#  '물품': 182,
#  '미비': 182,
#  '비밀': 182,
#  '발행': 181,
#  '장비': 181,
#  '징계': 180,
#  '사법': 180,
#  '과도': 179,
#  '철도': 179,
#  '자원부': 179,
#  '자율': 179,
#  '재판': 179,
#  '발급': 178,
#  '출연': 178,
#  '보험료': 178,
#  '각각': 177,
#  '지식': 177,
#  '강제': 177,
#  '실현': 176,
#  '동의': 176,
#  '시책': 176,
#  '특별자치시': 175,
#  '공기업': 174,
#  '정지': 173,
#  '중심': 173,
#  '대도시': 173,
#  '모든': 172,
#  '계속': 172,
#  '회계': 171,
#  '상임': 171,
#  '거부': 171,
#  '전문가': 171,
#  '경쟁': 170,
#  '통신': 170,
#  '특성': 169,
#  '특별법': 169,
#  '복무': 168,
#  '여성': 168,
#  '분석': 168,
#  '신뢰': 168,
#  '시험': 167,
#  '다수': 167,
#  '진료': 166,
#  '측면': 166,
#  '대부분': 166,
#  '언어': 166,
#  '명칭': 165,
#  '전환': 165,
#  '단지': 165,
#  '광부': 165,
#  '위원장': 164,
#  '해양': 164,
#  '유공': 164,
#  '여건': 163,
#  '공정': 163,
#  '품질': 163,
#  '제조': 163,
#  '보고서': 162,
#  '구매': 162,
#  '운행': 162,
#  '급식': 162,
#  '서류': 161,
#  '본인': 161,
#  '소유자': 161,
#  '유해': 161,
#  '불법행위': 161,
#  '전부': 160,
#  '인터넷': 160,
#  '배출': 160,
#  '원인': 160,
#  '형태': 159,
#  '수당': 159,
#  '신용카드': 159,
#  '상호': 158,
#  '광고': 158,
#  '벌금형': 158,
#  '대비': 158,
#  '임대주택': 158,
#  '지난': 158,
#  '운동': 158,
#  '표준': 157,
#  '자산': 157,
#  '서면': 157,
#  '수집': 157,
#  '체육관': 156,
#  '중소': 156,
#  '헌법': 156,
#  '이바지': 155,
#  '용역': 155,
#  '군인': 155,
#  '경쟁력': 154,
#  '노동': 154,
#  '운전자': 154,
#  '가중': 153,
#  '훈련': 153,
#  '기재': 153,
#  '교통사고': 153,
#  '위기': 152,
#  '한계': 152,
#  '대한': 152,
#  '예술': 151,
#  '확산': 150,
#  '별표': 150,
#  '결산': 150,
#  '질병': 150,
#  '북한': 150,
#  '대규모': 149,
#  '투명': 149,
#  '일자리': 149,
#  '전담': 149,
#  '역사': 149,
#  '담당': 149,
#  '통보': 149,
#  '계층': 148,
#  '물류': 148,
#  '정신': 147,
#  '취약': 147,
#  '환경부': 147,
#  '재생에너지': 147,
#  '공간': 147,
#  '달리': 146,
#  '정기': 146,
#  '동시': 145,
#  '종료': 145,
#  '합의': 145,
#  '문화재': 145,
#  '항공': 145,
#  '통일': 144,
#  '어린이집': 144,
#  '부분': 144,
#  '파악': 143,
#  '고시': 143,
#  '외부': 143,
#  '별로': 142,
#  '경감': 142,
#  '자유': 142,
#  '공시': 141,
#  '한도': 141,
#  '유발': 141,
#  '인식': 141,
#  '부재': 141,
#  '건축': 141,
#  '이상인': 141,
#  '보존': 141,
#  '특별회계': 140,
#  '용도': 140,
#  '고용노동부': 140,
#  '입찰': 140,
#  '국유재산': 139,
#  '전문성': 139,
#  '과징금': 139,
#  '집단': 139,
#  '성장': 139,
#  '외국': 139,
#  '첨단': 139,
#  '기부': 139,
#  '이로': 138,
#  '경비': 138,
#  '문제점': 137,
#  '자체': 137,
#  '남아': 137,
#  '미세먼지': 137,
#  '작업': 136,
#  '운전': 136,
#  '결함': 135,
#  '배상': 135,
#  '지위': 134,
#  '수요': 134,
#  '하도급': 134,
#  '종전': 134,
#  '가정': 134,
#  '성범죄': 133,
#  '인권': 133,
#  '동안': 133,
#  '자원': 133,
#  '소재': 133,
#  '유도': 133,
#  '의료인': 133,
#  '질서': 132,
#  '주식': 131,
#  '촬영': 131,
#  '정보통': 131,
#  '업주': 131,
#  '예외': 131,
#  '유족': 131,
#  '직장': 131,
#  '악용': 130,
#  '금품': 130,
#  '의약품': 130,
#  '경과': 130,
#  '파견': 130,
#  '혜택': 129,
#  '평균': 129,
#  '소요': 129,
#  '대행': 129,
#  '프로그램': 129,
#  '균형발전': 129,
#  '사업': 129,
#  '건물': 128,
#  '감소': 128,
#  '간의': 128,
#  '지원이': 128,
#  '가입자': 128,
#  '물의': 128,
#  '벤처기업': 128,
#  '특허': 128,
#  '전국': 127,
#  '거주': 127,
#  '농업': 127,
#  '명의': 126,
#  '방송통신': 126,
#  '민주': 126,
#  '폭행': 126,
#  '원금': 125,
#  '처우': 125,
#  '동물': 125,
#  '부터': 124,
#  '규칙': 124,
#  '접근성': 124,
#  '자살': 124,
#  '부금': 123,
#  '국무총리': 123,
#  '구제': 123,
#  '출석': 123,
#  '투자자': 123,
#  '부품': 122,
#  '예정': 122,
#  '상담': 122,
#  '보수': 122,
#  '수수료': 122,
#  '정함': 122,
#  '대기업': 122,
#  '누구': 122,
#  '서명': 122,
#  '설정': 121,
#  '연령': 121,
#  '면허': 121,
#  '행정처분': 121,
#  '양도': 121,
#  '임기': 121,
#  '판결': 121,
#  '한자어': 121,
#  '측정': 121,
#  '준정부기관': 121,
#  '지방의회': 120,
#  '기계': 120,
#  '회복': 120,
#  '정거': 120,
#  '장소': 120,
#  '단계': 120,
#  '수도권': 120,
#  '행정안전부': 119,
#  '권익': 119,
#  '매우': 119,
#  '광역': 119,
#  '소유': 118,
#  '대체': 118,
#  '선임': 117,
#  '편성': 117,
#  '기회': 117,
#  '안전성': 117,
#  '누설': 117,
#  '식품': 117,
#  '거리': 117,
#  '비교': 117,
#  '금고': 117,
#  '소환투표': 117,
#  '국민권익위': 117,
#  '협조': 116,
#  '임대료': 116,
#  '유아': 116,
#  '달성': 115,
#  '지도': 115,
#  '요양': 115,
#  '재단': 115,
#  '자등': 115,
#  '최저임금': 115,
#  '정법': 114,
#  '더욱': 114,
#  '배분': 114,
#  '근로시간': 114,
#  '매입': 114,
#  '대금': 114,
#  '무상': 114,
#  '관리자': 114,
#  '평화': 114,
#  '택시': 114,
#  '이동통신': 114,
#  '취급': 113,
#  '은행': 113,
#  '저해': 113,
#  '조합원': 113,
#  '장의': 113,
#  '담보': 112,
#  '보증': 112,
#  '제조업': 112,
#  '변화': 112,
#  '보육': 112,
#  '부칙': 111,
#  '영상': 111,
#  '결제': 111,
#  '변호사': 111,
#  '존재': 111,
#  '출산': 111,
#  '의료기기': 111,
#  '공제조합': 111,
#  '정보통신망': 110,
#  '지방세': 110,
#  '반면': 110,
#  '교육감': 110,
#  '시민': 110,
#  '심판': 110,
#  '선박': 110,
#  '출자': 109,
#  '교직원': 109,
#  '혼란': 109,
#  '가산금': 109,
#  '초래': 109,
#  '직업': 109,
#  '개설': 109,
#  '양성': 109,
#  '증대': 109,
#  '가축': 109,
#  '요원': 108,
#  '당시': 108,
#  '종류': 108,
#  '어업': 108,
#  '성능': 108,
#  '검토': 108,
#  '상생': 108,
#  '일상': 108,
#  '이자': 108,
#  '전자서명': 108,
#  '하나': 107,
#  '자문': 107,
#  '준용': 107,
#  '부지': 106,
#  '개정안': 106,
#  '배제': 106,
#  '업종': 106,
#  '회원': 106,
#  '예상': 106,
#  '배우자': 106,
#  '최소': 105,
#  '윤리': 105,
#  '단위': 105,
#  '세법': 105,
#  '특별자치도': 105,
#  '약속': 105,
#  '지연': 104,
#  '정성': 104,
#  '중인': 104,
#  '전용': 104,
#  '조달': 104,
#  '빈번': 104,
#  '유기': 103,
#  '체류': 103,
#  '협약': 103,
#  '제작': 102,
#  '해양수산부': 102,
#  '노후': 102,
#  '가지': 102,
#  '검증': 102,
#  '심리': 102,
#  '성희롱': 102,
#  '긴급': 101,
#  '모집': 101,
#  '형법': 101,
#  '조문': 101,
#  '성격': 101,
#  '해석': 101,
#  '공직': 101,
#  '세대': 100,
#  '제시': 100,
#  '학력': 100,
#  '가장': 99,
#  '국가공무원': 99,
#  '재산권': 99,
#  '정보통신부': 99,
#  '감안': 98,
#  '공공': 98,
#  '부처': 98,
#  '홍보': 98,
#  '가구': 98,
#  '발굴': 98,
#  '도시재생': 98,
#  '마약': 98,
#  '장려': 98,
#  '연간': 97,
#  '인상': 97,
#  '조례': 97,
#  '상한': 97,
#  '공립': 97,
#  '병원': 97,
#  '연구기관': 97,
#  '가치': 97,
#  '주행': 97,
#  '점포': 97,
#  '선택': 96,
#  '모두': 96,
#  '위생': 96,
#  '학습': 96,
#  '유치원': 95,
#  '가능': 95,
#  '규율': 95,
#  '개최': 95,
#  '이사회': 95,
#  '노동조합': 95,
#  '청원': 95,
#  '지출': 94,
#  '경력': 94,
#  '근절': 94,
#  '서도': 94,
#  '저출산': 94,
#  '효력': 94,
#  '균형': 94,
#  '자로': 93,
#  '소득세': 93,
#  '차원': 93,
#  '도서': 93,
#  '확립': 93,
#  '논란': 93,
#  '다음': 93,
#  '준비': 93,
#  '불합리': 93,
#  '훼손': 93,
#  '남용': 93,
#  '고자': 93,
#  '여객': 93,
#  '법치': 93,
#  '설명': 93,
#  '법률': 93,
#  '수법': 92,
#  '구성원': 92,
#  '집회': 92,
#  '민원': 92,
#  '수가': 92,
#  '증명서': 92,
#  '민법': 92,
#  '국민연금': 92,
#  '산림': 92,
#  '반환': 92,
#  '광역시': 92,
#  '출입': 92,
#  '대형': 92,
#  '사채': 92,
#  '감리': 92,
#  '복합': 92,
#  '여러': 91,
#  '소규모': 91,
#  '고지': 91,
#  '화학물질': 91,
#  '경찰관': 91,
#  '지자체': 91,
#  '항공기': 91,
#  '유출': 90,
#  '매출': 90,
#  ...}

# %%
# 미래통합당 20
wordcloud(MT)
# Out:
# {'자동차': 27,
#  '관리': 25,
#  '예방': 22,
#  '발생': 18,
#  '장관': 18,
#  '감염병': 18,
#  '해당': 17,
#  '지원': 17,
#  '지역': 17,
#  '관련': 16,
#  '최근': 16,
#  '촬영': 16,
#  '기관': 15,
#  '안전': 15,
#  '대상': 15,
#  '시행': 14,
#  '아동': 14,
#  '청소년': 14,
#  '제공': 14,
#  '후견인': 14,
#  '근로자': 13,
#  '위원회': 13,
#  '여론조사': 13,
#  '사고': 12,
#  '피해': 12,
#  '조항': 12,
#  '변호사': 12,
#  '국선': 12,
#  '시장': 11,
#  '국민': 11,
#  '전담': 11,
#  '미군': 11,
#  '포함': 11,
#  '국가': 11,
#  '청원': 11,
#  '정보': 11,
#  '자살': 11,
#  '사항': 10,
#  '한국인': 10,
#  '거나': 10,
#  '결격': 10,
#  '후견': 10,
#  '요청': 10,
#  '일부': 9,
#  '상황': 9,
#  '운영': 9,
#  '현장': 9,
#  '도입': 9,
#  '보호': 9,
#  '개정': 9,
#  '교육': 9,
#  '취지': 9,
#  '의결': 9,
#  '우선': 9,
#  '처벌': 9,
#  '제도': 9,
#  '임대주택': 9,
#  '선거': 9,
#  '실시': 9,
#  '성년': 9,
#  '중소기업': 9,
#  '교통사고': 9,
#  '현재': 8,
#  '이상': 8,
#  '통해': 8,
#  '적용': 8,
#  '공무원': 8,
#  '조치': 8,
#  '사건': 8,
#  '재산': 8,
#  '과세': 8,
#  '보증': 8,
#  '상담': 8,
#  '소득': 8,
#  '신설': 8,
#  '세계': 8,
#  '체험학습': 8,
#  '증여': 8,
#  '재활용': 7,
#  '대해': 7,
#  '처리': 7,
#  '이용': 7,
#  '건설': 7,
#  '내용': 7,
#  '의무': 7,
#  '해석': 7,
#  '사용': 7,
#  '특별': 7,
#  '디지털': 7,
#  '범죄': 7,
#  '환자': 7,
#  '근거': 7,
#  '업무': 7,
#  '피성년후견인': 7,
#  '제한': 7,
#  '기금': 7,
#  '유산': 7,
#  '상속': 7,
#  '부담': 6,
#  '호의': 6,
#  '작업': 6,
#  '활용': 6,
#  '기간': 6,
#  '대한민국': 6,
#  '사람': 6,
#  '심의': 6,
#  '활성화': 6,
#  '번방': 6,
#  '삭제': 6,
#  '사회': 6,
#  '개인': 6,
#  '사업자': 6,
#  '소상': 6,
#  '공인': 6,
#  '확인': 6,
#  '피고인': 6,
#  '변호인': 6,
#  '자금': 6,
#  '채권': 6,
#  '법원': 6,
#  '생명': 6,
#  '보건복지부': 6,
#  '창업': 6,
#  '현황': 6,
#  '안정': 5,
#  '우려': 5,
#  '장비': 5,
#  '산업': 5,
#  '보건': 5,
#  '구입': 5,
#  '금액': 5,
#  '대표': 5,
#  '휴직': 5,
#  '사태': 5,
#  '방지': 5,
#  '수립': 5,
#  '캠핑': 5,
#  '선택': 5,
#  '착취': 5,
#  '규모': 5,
#  '실정': 5,
#  '단체': 5,
#  '또한': 5,
#  '영화상': 5,
#  '영관': 5,
#  '관람객': 5,
#  '가액': 5,
#  '코로나': 5,
#  '확산': 5,
#  '온라인': 5,
#  '신고': 5,
#  '임대': 5,
#  '민간': 5,
#  '거주': 5,
#  '임차': 5,
#  '사례': 5,
#  '양도': 5,
#  '설문': 5,
#  '본인': 5,
#  '피한정후견인': 5,
#  '과도': 5,
#  '통지': 5,
#  '신용': 5,
#  '수행': 5,
#  '보전': 5,
#  '방식': 5,
#  '당시': 5,
#  '기록': 5,
#  '학교': 5,
#  '법무부': 5,
#  '입국': 5,
#  '번호': 5,
#  '유네스코': 5,
#  '운전자': 5,
#  '업체': 4,
#  '가격': 4,
#  '주택': 4,
#  '수준': 4,
#  '설치': 4,
#  '센터': 4,
#  '장치': 4,
#  '시스템': 4,
#  '운용': 4,
#  '필요': 4,
#  '확보': 4,
#  '항제': 4,
#  '간의': 4,
#  '소속': 4,
#  '관계': 4,
#  '지급': 4,
#  '이후': 4,
#  '사유': 4,
#  '정부': 4,
#  '계획': 4,
#  '의견': 4,
#  '종류': 4,
#  '제작': 4,
#  '확대': 4,
#  '보장': 4,
#  '여성': 4,
#  '유포': 4,
#  '취하': 4,
#  '이처럼': 4,
#  '대하': 4,
#  '음란물': 4,
#  '성범죄': 4,
#  '기여': 4,
#  '진흥': 4,
#  '감염': 4,
#  '불법': 4,
#  '법적': 4,
#  '간이': 4,
#  '제출': 4,
#  '기준': 4,
#  '매출': 4,
#  '대구': 4,
#  '경북': 4,
#  '분양': 4,
#  '전환': 4,
#  '과대': 4,
#  '예비': 4,
#  '실제': 4,
#  '표본': 4,
#  '절차': 4,
#  '제약': 4,
#  '능력': 4,
#  '촉진': 4,
#  '직업': 4,
#  '자유': 4,
#  '평등권': 4,
#  '나라': 4,
#  '질병': 4,
#  '사무': 4,
#  '검사': 4,
#  '효율': 4,
#  '권리': 4,
#  '공탁': 4,
#  '자료': 4,
#  '학생': 4,
#  '자격': 4,
#  '현행법': 4,
#  '지정': 4,
#  '설명': 4,
#  '설립': 4,
#  '교육부': 4,
#  '교육감': 4,
#  '시험': 4,
#  '장가': 4,
#  '미술품': 4,
#  '거부': 3,
#  '이로': 3,
#  '기능': 3,
#  '생활': 3,
#  '폐지': 3,
#  '따라서': 3,
#  '위험': 3,
#  '환경': 3,
#  '상태': 3,
#  '파악': 3,
#  '구축': 3,
#  '재해': 3,
#  '달리': 3,
#  '입법': 3,
#  '명령': 3,
#  '상공': 3,
#  '방위': 3,
#  '지위': 3,
#  '협정': 3,
#  '근무': 3,
#  '위원': 3,
#  '국방부': 3,
#  '이내': 3,
#  '무급': 3,
#  '위해': 3,
#  '최대한': 3,
#  '반영': 3,
#  '자동차관리법': 3,
#  '특수': 3,
#  '운행': 3,
#  '서비스': 3,
#  '접근': 3,
#  '부모': 3,
#  '협박': 3,
#  '피해자': 3,
#  '강요': 3,
#  '형태': 3,
#  '갈수록': 3,
#  '조직': 3,
#  '관람': 3,
#  '이하': 3,
#  '코로나바이러스': 3,
#  '감염증': 3,
#  '진자': 3,
#  '대책': 3,
#  '동의': 3,
#  '소지': 3,
#  '고하': 3,
#  '공급': 3,
#  '어려움': 3,
#  '국내': 3,
#  '적극': 3,
#  '별도': 3,
#  '불구': 3,
#  '참여': 3,
#  '대통령': 3,
#  '특정': 3,
#  '여론': 3,
#  '제기': 3,
#  '목적': 3,
#  '왜곡': 3,
#  '부작용': 3,
#  '현행': 3,
#  '지방공무원법': 3,
#  '정신': 3,
#  '구체': 3,
#  '퇴직': 3,
#  '도록': 3,
#  '국가공무원': 3,
#  '신청': 3,
#  '법령': 3,
#  '체계': 3,
#  '개시': 3,
#  '서류': 3,
#  '열람': 3,
#  '처분': 3,
#  '조력': 3,
#  '담보': 3,
#  '기타': 3,
#  '채용': 3,
#  '국회예산정책처': 3,
#  '예산': 3,
#  '재정': 3,
#  '조사': 3,
#  '지원이': 3,
#  '지적': 3,
#  '금지': 3,
#  '전제': 3,
#  '조정': 3,
#  '재난': 3,
#  '고용': 3,
#  '국제': 3,
#  '전문': 3,
#  '응시': 3,
#  '가산': 3,
#  '세법': 3,
#  '차익': 3,
#  '분리': 3,
#  '규정': 3,
#  '변호': 3,
#  '위촉': 3,
#  '평가': 3,
#  '운송': 3,
#  '화물자동차': 3,
#  '차량': 3,
#  '변동': 2,
#  '구조': 2,
#  '가지': 2,
#  '폐기물': 2,
#  '수거': 2,
#  '초래': 2,
#  '비닐': 2,
#  '가중': 2,
#  '과정': 2,
#  '모니터링': 2,
#  '선제': 2,
#  '도모': 2,
#  '한국': 2,
#  '위탁': 2,
#  '무선': 2,
#  '전파': 2,
#  '무선통신': 2,
#  '위치': 2,
#  '공정': 2,
#  '기술': 2,
#  '국토교통부': 2,
#  '비용': 2,
#  '로부터': 2,
#  '제외': 2,
#  '위반': 2,
#  '벌칙': 2,
#  '보건관리': 2,
#  '작성': 2,
#  '도급': 2,
#  '추가': 2,
#  '실효': 2,
#  '재화': 2,
#  '용역': 2,
#  '결제': 2,
#  '소득세': 2,
#  '법인세': 2,
#  '세액': 2,
#  '국무총리': 2,
#  '위원장': 2,
#  '실무': 2,
#  '비분': 2,
#  '협상': 2,
#  '미타': 2,
#  '지연': 2,
#  '승합자동차': 2,
#  '그대로': 2,
#  '소비자': 2,
#  '직접': 2,
#  '텔레그램': 2,
#  '가해자': 2,
#  '일자리': 2,
#  '금전': 2,
#  '유혹': 2,
#  '개인정보': 2,
#  '지인': 2,
#  '프로그램': 2,
#  '이득': 2,
#  '기도': 2,
#  '가입': 2,
#  '텔레': 2,
#  '그램': 2,
#  '채팅': 2,
#  '가입자': 2,
#  '불분명': 2,
#  '행위': 2,
#  '성적': 2,
#  '영상': 2,
#  '근절': 2,
#  '영화': 2,
#  '입장': 2,
#  '입장권': 2,
#  '범위': 2,
#  '부과금': 2,
#  '징수': 2,
#  '급감': 2,
#  '휴업': 2,
#  '일정': 2,
#  '완화': 2,
#  '반포': 2,
#  '신체': 2,
#  '지하': 2,
#  '중단': 2,
#  '형량': 2,
#  '상향': 2,
#  '서도': 2,
#  '직전': 2,
#  '연도': 2,
#  '대가': 2,
#  '납부': 2,
#  '부여': 2,
#  '상승': 2,
#  '인건비': 2,
#  '위축': 2,
#  '대상자': 2,
#  '납세': 2,
#  '경제활동': 2,
#  '감소': 2,
#  '임대료': 2,
#  '무기': 2,
#  '지난': 2,
#  '특별법': 2,
#  '모집': 2,
#  '지층': 2,
#  '보도': 2,
#  '표집': 2,
#  '집단': 2,
#  '결과': 2,
#  '자체': 2,
#  '여부': 2,
#  '전국': 2,
#  '단위': 2,
#  '지방자치단체': 2,
#  '전체': 2,
#  '계정': 2,
#  '중복': 2,
#  '방법': 2,
#  '개선': 2,
#  '정도': 2,
#  '사정': 2,
#  '모순': 2,
#  '제의': 2,
#  '저해': 2,
#  '로써': 2,
#  '하나': 2,
#  '때문': 2,
#  '직권': 2,
#  '면직': 2,
#  '여지': 2,
#  '원천': 2,
#  '차단됨': 2,
#  '포괄': 2,
#  '획일': 2,
#  '기본권': 2,
#  '야기': 2,
#  '가슴': 2,
#  '통증': 2,
#  '명예퇴직': 2,
#  '이익': 2,
#  '상실': 2,
#  '위헌법률심판': 2,
#  '제청': 2,
#  '부합': 2,
#  '완비': 2,
#  '소송': 2,
#  '해소': 2,
#  '행사': 2,
#  '공소': 2,
#  '보관': 2,
#  '등사': 2,
#  '헌법': 2,
#  '변론': 2,
#  '기업': 2,
#  '부실': 2,
#  '회수': 2,
#  '현금': 2,
#  '재원': 2,
#  '감안': 2,
#  '회사': 2,
#  '공고': 2,
#  '분쟁': 2,
#  '해결': 2,
#  '에어백': 2,
#  '제어장치': 2,
#  '모두': 2,
#  '판독': 2,
#  '사용자': 2,
#  '자등': 2,
#  '자살률': 2,
#  '증가': 2,
#  '치료': 2,
#  '증진': 2,
#  '한편': 2,
#  '존중': 2,
#  '결산': 2,
#  '공공기관': 2,
#  '비공개': 2,
#  '이유': 2,
#  '분석': 2,
#  '소의': 2,
#  '종사': 2,
#  '부터': 2,
#  '참고': 2,
#  '정태옥': 2,
#  '의원': 2,
#  '발의': 2,
#  '의안': 2,
#  '것이므': 2,
#  '안이': 2,
#  '수정': 2,
#  '영업': 2,
#  '활동': 2,
#  '긴급': 2,
#  '인정': 2,
#  '유입': 2,
#  '외국인': 2,
#  '손실보상': 2,
#  '여명': 2,
#  '등재': 2,
#  '대중': 2,
#  '이해': 2,
#  '통한': 2,
#  '분야': 2,
#  '연구': 2,
#  '마련': 2,
#  '협력': 2,
#  '공제사업': 2,
#  '변호사시험': 2,
#  '가업승계': 2,
#  '시일': 2,
#  '항상': 2,
#  '세로': 2,
#  '납세의무': 2,
#  '종결': 2,
#  '미술': 2,
#  '해촉': 2,
#  '독립': 2,
#  '명단': 2,
#  '우리나라': 1,
#  '비중': 1,
#  '유가': 1,
#  '원자재': 1,
#  '충격': 1,
#  '취약': 1,
#  '수도권': 1,
#  '급락': 1,
#  '요인': 1,
#  '수익': 1,
#  '악화': 1,
#  '정상': 1,
#  '작동': 1,
#  '불편': 1,
#  '고형': 1,
#  '연료': 1,
#  '침체': 1,
#  '적체': 1,
#  '시점': 1,
#  '유리': 1,
#  '주요': 1,
#  '품목': 1,
#  '공공': 1,
#  '기구': 1,
#  '변화': 1,
#  '상시': 1,
#  '징후': 1,
#  '예측': 1,
#  '비축': 1,
#  '대응': 1,
#  '안정화': 1,
#  '폐기물관리': 1,
#  '공단': 1,
#  '설비': 1,
#  '복합': 1,
#  '등를': 1,
#  '자의': 1,
#  '하청': 1,
#  '홀로': 1,
#  '노동자': 1,
#  '죽음': 1,
#  '계기': 1,
#  '모든': 1,
#  '조성하': 1,
#  '전부': 1,
#  '이전': 1,
#  '일용': 1,
#  '보이': 1,
#  '명세서': 1,
#  '주체': 1,
#  '호성': 1,
#  '달성': 1,
#  '흠결': 1,
#  '체인': 1,
#  '중대': 1,
#  '중지': 1,
#  '정의': 1,
#  '대금': 1,
#  '개월': 1,
#  '선결': 1,
#  '제하': 1,
#  '신용카드': 1,
#  '소득공제': 1,
#  '수단': 1,
#  '인상': 1,
#  '아메리카합중국': 1,
#  '상호': 1,
#  '조약': 1,
#  '시설': 1,
#  '구역': 1,
#  '합중국': 1,
#  '군대': 1,
#  '임용': 1,
#  '주둔지': 1,
#  '국적': 1,
#  '차관': 1,
#  '위임': 1,
#  '성함': 1,
#  '생계': 1,
#  '재발': 1,
#  '급여': 1,
#  '이행': 1,
#  '승용자동차': 1,
#  '로만': 1,
#  '차로': 1,
#  '정작': 1,
#  '대여': 1,
#  '문제점': 1,
#  '로서': 1,
#  '업역': 1,
#  '확장': 1,
#  '공유': 1,
#  '개설': 1,
#  '상대로': 1,
#  '더욱': 1,
#  '형법': 1,
#  '물임': 1,
#  '유기': 1,
#  '징역': 1,
#  '하자': 1,
#  '대화방': 1,
#  '수위': 1,
#  '강화': 1,
#  '수의': 1,
#  '방문': 1,
#  '임시': 1,
#  '대통령령': 1,
#  '동안': 1,
#  '면제': 1,
#  '소위': 1,
#  '박사': 1,
#  '비롯': 1,
#  '카메라': 1,
#  '급증': 1,
#  '욕망': 1,
#  '수치심': 1,
#  '유발': 1,
#  '포자': 1,
#  '자도': 1,
#  '발견': 1,
#  '전송': 1,
#  '부과': 1,
#  '해태': 1,
#  '책임': 1,
#  '물어': 1,
#  '여야': 1,
#  '강간': 1,
#  '모의': 1,
#  '유통': 1,
#  '거래': 1,
#  '성행': 1,
#  '미성년': 1,
#  '대거': 1,
#  '제재': 1,
#  '일괄': 1,
#  '각심': 1,
#  '합계': 1,
#  '미달': 1,
#  '세금': 1,
#  '계산서': 1,
#  '교부': 1,
#  '제반': 1,
#  '단순화': 1,
#  '업종': 1,
#  '부가가치': 1,
#  '혜택': 1,
#  '유지': 1,
#  '반면': 1,
#  '물가': 1,
#  '지속': 1,
#  '최저임금': 1,
#  '소비': 1,
#  '심리': 1,
#  '영세': 1,
#  '경감': 1,
#  '확진': 1,
#  '집중': 1,
#  '자발': 1,
#  '주민': 1,
#  '배달': 1,
#  '주문': 1,
#  '노력': 1,
#  '차원': 1,
#  '주장': 1,
#  '소재지': 1,
#  '종전': 1,
#  '구분': 1,
#  '분법': 1,
#  '종료': 1,
#  '양수': 1,
#  '과거': 1,
#  '상의': 1,
#  '악용': 1,
#  '여당': 1,
#  '논란': 1,
#  '리얼미터': 1,
#  '서울': 1,
#  '종로구': 1,
#  '남녀': 1,
#  '이낙연': 1,
#  '황교안': 1,
#  '후보': 1,
#  '가상': 1,
#  '대결': 1,
#  '응답': 1,
#  '가운데': 1,
#  '문재인': 1,
#  '투표': 1,
#  '수집': 1,
#  '의문': 1,
#  '객관': 1,
#  '핵심': 1,
#  '크기': 1,
#  '판단': 1,
#  '반드시': 1,
#  '국회의원': 1,
#  '지방의회': 1,
#  '정당': 1,
#  '지지': 1,
#  '공표': 1,
#  '중앙': 1,
#  '등록': 1,
#  '여론조작': 1,
#  '청와대': 1,
#  '중인': 1,
#  '네이버': 1,
#  '카카오': 1,
#  '소셜미디어': 1,
#  '로그인': 1,
#  '여러': 1,
#  '전자문서': 1,
#  '주소': 1,
#  '거소': 1,
#  '기재': 1,
#  '서명': 1,
#  '대체': 1,
#  '규율': 1,
#  '본래': 1,
#  '장애': 1,
#  '노령': 1,
#  '결여': 1,
#  '배우자': 1,
#  '청구': 1,
#  '가정법원': 1,
#  '한정': 1,
#  '심판': 1,
#  '말함': 1,
#  '민법': 1,
#  '계속': 1,
#  '증거물': 1,
#  '복사': 1,
#  '형사': 1,
#  '대칭성': 1,
#  '방어': 1,
#  '위함임': 1,
#  '형사소송법': 1,
#  '대부분': 1,
#  '기소': 1,
#  '불기소': 1,
#  '알권리': 1,
#  '사법': 1,
#  '신뢰': 1,
#  '허용': 1,
#  '예외': 1,
#  '단서': 1,
#  '고소': 1,
#  '고지': 1,
#  '격차': 1,
#  '관성': 1,
#  '금은': 1,
#  '융통': 1,
#  '미약': 1,
#  '채무': 1,
#  '본연': 1,
#  '연간': 1,
#  '채권자': 1,
#  '가능성': 1,
#  '현저': 1,
#  '본안': 1,
#  '패소': 1,
#  '극히': 1,
#  '배수': 1,
#  '지출': 1,
#  '대신': 1,
#  '계약': 1,
#  '문서': 1,
#  '법인': 1,
#  '정관': 1,
#  '직원': 1,
#  '아르바이트': 1,
#  '경위': 1,
#  '엔진': 1,
#  '변속': 1,
#  '필수': 1,
#  '적임': 1,
#  '부품': 1,
#  '전문성': 1,
#  '제작사': 1,
#  '보험': 1,
#  '정차': 1,
#  '추세': 1,
#  '위로': 1,
#  '음주': 1,
#  '흡연': 1,
#  '약물': 1,
#  '오용': 1,
#  '남용': 1,
#  '정신건강': 1,
#  '열거': 1,
#  '의식': 1,
#  '함양': 1,
#  '국회의장': 1,
#  '허가': 1,
#  '정보공개': 1,
#  '전화': 1,
#  '홍보': 1,
#  '문화': 1,
#  '감독': 1,
#  '보균자': 1,
#  '잠복기': 1,
#  '구별': 1,
#  '이번': 1,
#  '우한': 1,
#  '폐렴': 1,
#  '부가': 1,
#  '중국': 1,
#  '전역': 1,
#  '요구': 1,
#  '정치': 1,
#  '본부장': 1,
#  '보완': 1,
#  '수용': 1,
#  '다른': 1,
#  '전원': 1,
#  '유행': 1,
#  '경제': 1,
#  '해외': 1,
#  '시작': 1,
#  '내의': 1,
#  '차단': 1,
#  '병원': 1,
#  '병상': 1,
#  '의료인': 1,
#  '위생': 1,
#  '방역': 1,
#  '용품': 1,
#  '자영': 1,
#  '업자': 1,
#  '행정': 1,
#  '역할': 1,
#  '가치': 1,
#  '개발': 1,
#  '과제': 1,
#  '부상': 1,
#  '이론': 1,
#  '매체': 1,
#  '담당': 1,
#  '제안': 1,
#  '총회': 1,
#  '승인': 1,
#  '접근성': 1,
#  '고자': 1,
#  '실태': 1,
#  '인력': 1,
#  '양성': 1,
#  '정책': 1,
#  '추진': 1,
#  '위급': 1,
#  '대처': 1,
#  '지침': 1,
#  '제정': 1,
#  '교육청': 1,
#  '보급': 1,
#  '교직원': 1,
#  '교육활동': 1,
#  '참여자': 1,
#  '보상': 1,
#  '국교': 1,
#  '공제': 1,
#  '합격': 1,
#  '법학': 1,
#  '대학원': 1,
#  '재학생': 1,
#  '졸업생': 1,
#  '관장': 1,
#  '선발': 1,
#  '예정': 1,
#  '인원': 1,
#  '제시': 1,
#  '소관': 1,
#  '이상인': 1,
#  '한도': 1,
#  '증여세': 1,
#  '추후': 1,
#  '대한': 1,
#  '상속세': 1,
#  '투자': 1,
#  '긍정': 1,
#  '형평성': 1,
#  '측면': 1,
#  '서화': 1,
#  '골동품': 1,
#  '유예': 1,
#  '영향': 1,
#  '최소': 1,
#  '다소': 1,
#  '혼란': 1,
#  '국회': 1,
#  '논의': 1,
#  '예규': 1,
#  '선정': 1,
#  '사실': 1,
#  '진행': 1,
#  '제대로': 1,
#  '과반수': 1,
#  '외부': 1,
#  '구성': 1,
#  '사망': 1,
#  '자수': 1,
#  '원인': 1,
#  '사업': 1,
#  '경찰청': 1,
#  '누락': 1,
#  '보유': 1}

# %%
# 무소속 20
wordcloud(MS)
# Out:
# {'지역': 229,
#  '지원': 193,
#  '개발': 154,
#  '시설': 142,
#  '기관': 126,
#  '해당': 117,
#  '발생': 117,
#  '위원회': 112,
#  '관련': 111,
#  '안전': 105,
#  '관리': 103,
#  '계획': 103,
#  '제공': 102,
#  '정보': 102,
#  '장관': 100,
#  '업무': 99,
#  '시행': 99,
#  '사용': 97,
#  '의료': 94,
#  '이하': 94,
#  '등록': 94,
#  '자동차': 92,
#  '사항': 91,
#  '조사': 90,
#  '신설': 88,
#  '보호': 86,
#  '행위': 84,
#  '제도': 84,
#  '교육': 84,
#  '국가': 83,
#  '의무': 81,
#  '항제': 80,
#  '근거': 79,
#  '지정': 78,
#  '산업': 78,
#  '제한': 77,
#  '대상': 76,
#  '지방자치단체': 75,
#  '관할': 74,
#  '대하': 73,
#  '국민': 72,
#  '중소기업': 70,
#  '거나': 70,
#  '기간': 69,
#  '운영': 68,
#  '설치': 65,
#  '사업자': 64,
#  '최근': 64,
#  '근로자': 64,
#  '현행법': 64,
#  '위반': 63,
#  '방지': 63,
#  '위해': 63,
#  '필요': 62,
#  '대해': 62,
#  '마련': 62,
#  '기업': 61,
#  '부과': 60,
#  '지적': 59,
#  '사람': 59,
#  '실시': 58,
#  '환자': 58,
#  '보험': 58,
#  '피해': 57,
#  '기준': 57,
#  '사회': 57,
#  '실정': 57,
#  '적용': 57,
#  '신청': 57,
#  '세무서': 57,
#  '이용': 56,
#  '기술': 55,
#  '상황': 55,
#  '포함': 54,
#  '주민': 54,
#  '자료': 54,
#  '일부': 53,
#  '공사': 53,
#  '지방': 52,
#  '계약': 52,
#  '환경': 52,
#  '의결': 52,
#  '종사': 51,
#  '목적': 51,
#  '육성': 50,
#  '조정': 50,
#  '개정': 49,
#  '확보': 49,
#  '시장': 48,
#  '단체': 48,
#  '수립': 48,
#  '결과': 48,
#  '법적': 48,
#  '요청': 48,
#  '대체복무': 48,
#  '금지': 46,
#  '신고': 45,
#  '범위': 44,
#  '거래': 44,
#  '조치': 44,
#  '이상': 44,
#  '한국': 43,
#  '현행': 43,
#  '과태료': 43,
#  '확인': 43,
#  '발전': 42,
#  '지구': 42,
#  '부정': 42,
#  '업자': 42,
#  '수행': 41,
#  '심의': 41,
#  '금융': 41,
#  '전력': 41,
#  '복무': 41,
#  '예비역': 41,
#  '구역': 40,
#  '정부': 40,
#  '명시': 40,
#  '센터': 40,
#  '한편': 40,
#  '종합': 40,
#  '제출': 40,
#  '개선': 39,
#  '또한': 39,
#  '결정': 39,
#  '폐업': 39,
#  '금액': 38,
#  '연장': 38,
#  '영업': 38,
#  '인정': 37,
#  '부담': 37,
#  '비용': 36,
#  '지급': 36,
#  '공무원': 36,
#  '사고': 36,
#  '수급': 36,
#  '경제': 35,
#  '처벌': 35,
#  '사건': 35,
#  '지속': 35,
#  '투자': 35,
#  '우려': 35,
#  '평가': 35,
#  '제기': 35,
#  '관계': 35,
#  '급여': 35,
#  '규제': 34,
#  '촉진': 34,
#  '예방': 34,
#  '균형개발': 34,
#  '범죄': 33,
#  '다른': 33,
#  '소득': 33,
#  '협의': 33,
#  '서비스': 33,
#  '특정': 32,
#  '문제': 32,
#  '사유': 32,
#  '장애': 32,
#  '주변': 32,
#  '학생': 32,
#  '정신질환': 32,
#  '규정': 32,
#  '통해': 31,
#  '내용': 31,
#  '불구': 31,
#  '고려': 31,
#  '허가': 31,
#  '여부': 31,
#  '대책': 31,
#  '치매': 31,
#  '처리': 30,
#  '효율': 30,
#  '군수': 30,
#  '정책': 30,
#  '국내': 30,
#  '고용': 30,
#  '주택': 30,
#  '선거': 30,
#  '확대': 29,
#  '활용': 29,
#  '안정': 29,
#  '취소': 29,
#  '교통': 29,
#  '보장': 28,
#  '추가': 28,
#  '각각': 28,
#  '운용': 28,
#  '영향': 28,
#  '수입': 28,
#  '요구': 28,
#  '대출': 28,
#  '장애인': 28,
#  '부대': 28,
#  '대응': 27,
#  '따라서': 27,
#  '수준': 27,
#  '국토교통부': 27,
#  '의원': 27,
#  '청소년': 27,
#  '업체': 27,
#  '최저임금': 27,
#  '공단': 26,
#  '유지': 26,
#  '벌금': 26,
#  '판매': 26,
#  '이유': 26,
#  '명칭': 26,
#  '전자': 25,
#  '연구': 25,
#  '실효': 25,
#  '사실': 25,
#  '재정': 25,
#  '체육': 25,
#  '행정': 25,
#  '징역': 25,
#  '현재': 24,
#  '개별': 24,
#  '실태': 24,
#  '자산': 24,
#  '보건복지부': 24,
#  '공개': 24,
#  '점검': 24,
#  '공급': 24,
#  '징수': 24,
#  '방법': 24,
#  '재활용': 24,
#  '연령': 24,
#  '문화': 23,
#  '임용': 23,
#  '의견': 23,
#  '가족': 23,
#  '증진': 23,
#  '요건': 23,
#  '직접': 23,
#  '제조': 23,
#  '건설': 23,
#  '심사': 23,
#  '거짓': 23,
#  '활성화': 22,
#  '통한': 22,
#  '인증': 22,
#  '필요성': 22,
#  '대통령령': 22,
#  '이행': 22,
#  '적극': 22,
#  '진흥': 22,
#  '증가': 22,
#  '침해': 22,
#  '과징금': 22,
#  '체계': 22,
#  '유통': 22,
#  '혼란': 22,
#  '단지': 22,
#  '처분': 22,
#  '이용자': 22,
#  '검사': 22,
#  '전시': 22,
#  '간의': 21,
#  '복지': 21,
#  '절차': 21,
#  '노인': 21,
#  '사례': 21,
#  '학교': 21,
#  '고시': 21,
#  '납부': 21,
#  '예산': 21,
#  '도모': 21,
#  '담배': 21,
#  '업종': 21,
#  '유사': 21,
#  '장치': 20,
#  '직원': 20,
#  '제외': 20,
#  '중앙': 20,
#  '위탁': 20,
#  '복귀': 20,
#  '반영': 20,
#  '임금': 20,
#  '훈련': 20,
#  '도지사': 20,
#  '자격': 20,
#  '작성': 20,
#  '취득': 20,
#  '과세': 20,
#  '장기': 20,
#  '폐지': 20,
#  '디지털': 20,
#  '요원': 20,
#  '종전': 20,
#  '직권': 20,
#  '감독': 19,
#  '효과': 19,
#  '차량': 19,
#  '유아': 19,
#  '업주': 19,
#  '로서': 19,
#  '보고': 19,
#  '체결': 19,
#  '삭제': 19,
#  '가격': 19,
#  '자가': 19,
#  '응급의료': 19,
#  '정년': 19,
#  '활동': 18,
#  '정의': 18,
#  '일정': 18,
#  '법령': 18,
#  '고용노동부': 18,
#  '취업': 18,
#  '제재': 18,
#  '기여': 18,
#  '정지': 18,
#  '청구': 18,
#  '생활': 18,
#  '수면': 18,
#  '해외': 18,
#  '보건': 18,
#  '자의': 18,
#  '특별': 18,
#  '기본': 18,
#  '성능': 18,
#  '물의': 18,
#  '철도': 18,
#  '회선': 18,
#  '가축': 18,
#  '전기요금': 18,
#  '호의': 17,
#  '경력': 17,
#  '한정': 17,
#  '별도': 17,
#  '일반': 17,
#  '형평성': 17,
#  '배우자': 17,
#  '성과': 17,
#  '벌금형': 17,
#  '조건': 17,
#  '대표': 17,
#  '번호': 17,
#  '부사관': 17,
#  '각종': 16,
#  '인력': 16,
#  '채용': 16,
#  '규모': 16,
#  '휴직': 16,
#  '공항': 16,
#  '상향': 16,
#  '근로시간': 16,
#  '도입': 16,
#  '혜택': 16,
#  '이후': 16,
#  '소속': 16,
#  '행정기관': 16,
#  '청장': 16,
#  '기초': 16,
#  '다수': 16,
#  '도록': 16,
#  '당사자': 16,
#  '지도': 16,
#  '근로': 16,
#  '선거운동': 16,
#  '분야': 16,
#  '종류': 16,
#  '사망': 16,
#  '구축': 16,
#  '변경': 16,
#  '시효': 16,
#  '병원': 16,
#  '정보통신망': 16,
#  '학교폭력': 16,
#  '장교': 16,
#  '상근': 16,
#  '비상근': 16,
#  '로부터': 15,
#  '추진': 15,
#  '승인': 15,
#  '퇴직': 15,
#  '민간': 15,
#  '어린이': 15,
#  '복직': 15,
#  '위협': 15,
#  '상태': 15,
#  '어려움': 15,
#  '기반': 15,
#  '조성': 15,
#  '신용정보': 15,
#  '개인': 15,
#  '근무': 15,
#  '제대로': 15,
#  '소비자': 15,
#  '중단': 15,
#  '인구': 15,
#  '공장': 15,
#  '달리': 15,
#  '폐기물': 15,
#  '위기': 15,
#  '소송': 15,
#  '후보자': 15,
#  '현역': 15,
#  '사업': 15,
#  '비율': 14,
#  '우리나라': 14,
#  '자금': 14,
#  '부칙': 14,
#  '전부': 14,
#  '보조': 14,
#  '신규': 14,
#  '이내': 14,
#  '때문': 14,
#  '초래': 14,
#  '특례': 14,
#  '조항': 14,
#  '우선': 14,
#  '질병': 14,
#  '기존': 14,
#  '법인': 14,
#  '완화': 14,
#  '상의': 14,
#  '현실': 14,
#  '특별회계': 14,
#  '치료': 14,
#  '배당': 14,
#  '예비': 14,
#  '자등': 14,
#  '재산': 14,
#  '세법': 14,
#  '소방': 14,
#  '재심': 14,
#  '연명': 14,
#  '측정': 14,
#  '사관': 14,
#  '방위산업': 14,
#  '즉시': 13,
#  '실제': 13,
#  '차지': 13,
#  '주체': 13,
#  '개월': 13,
#  '기금': 13,
#  '건강': 13,
#  '취지': 13,
#  '생계': 13,
#  '보수': 13,
#  '인권': 13,
#  '당시': 13,
#  '온라인': 13,
#  '면제': 13,
#  '국제': 13,
#  '위원': 13,
#  '방식': 13,
#  '기록': 13,
#  '참고': 13,
#  '동원': 13,
#  '지자체': 13,
#  '재해': 13,
#  '군인': 13,
#  '직무': 13,
#  '가입': 13,
#  '합리': 13,
#  '은행': 13,
#  '게임': 13,
#  '발의': 13,
#  '안이': 13,
#  '수정': 13,
#  '부품': 13,
#  '도달': 13,
#  '누진': 13,
#  '발휘': 13,
#  '녹음': 13,
#  '국방부': 12,
#  '자원': 12,
#  '회의': 12,
#  '단절': 12,
#  '인식': 12,
#  '미비': 12,
#  '프로그램': 12,
#  '정비': 12,
#  '긴급': 12,
#  '아동': 12,
#  '표시': 12,
#  '교원': 12,
#  '중인': 12,
#  '특성': 12,
#  '면허': 12,
#  '보육': 12,
#  '자녀': 12,
#  '지난': 12,
#  '매년': 12,
#  '생산': 12,
#  '투자자': 12,
#  '용도': 12,
#  '고하': 12,
#  '형사': 12,
#  '자로': 12,
#  '간접흡연': 12,
#  '보상': 12,
#  '화학물질': 12,
#  '물질': 12,
#  '산정': 12,
#  '기한': 12,
#  '개시': 12,
#  '대리': 12,
#  '경찰': 12,
#  '결함': 12,
#  '정거': 12,
#  '공정': 12,
#  '시정': 12,
#  '협력': 12,
#  '의사': 12,
#  '차별': 12,
#  '집행': 12,
#  '교육부': 12,
#  '권리': 12,
#  '취득세': 12,
#  '연구개발': 12,
#  '고엽제': 12,
#  '의안': 12,
#  '전제': 12,
#  '조합원': 12,
#  '재난': 12,
#  '창설': 12,
#  '평시': 12,
#  '구청': 12,
#  '약사': 12,
#  '명령': 11,
#  '축소': 11,
#  '감소': 11,
#  '농촌': 11,
#  '보급': 11,
#  '강화': 11,
#  '이로': 11,
#  '종료': 11,
#  '방해': 11,
#  '허용': 11,
#  '휴가': 11,
#  '수당': 11,
#  '경쟁력': 11,
#  '이바지': 11,
#  '전문': 11,
#  '설립': 11,
#  '품질': 11,
#  '현황': 11,
#  '향상': 11,
#  '대기업': 11,
#  '과정': 11,
#  '구성': 11,
#  '파악': 11,
#  '시간': 11,
#  '입장권': 11,
#  '구매': 11,
#  '수요': 11,
#  '소음': 11,
#  '현장': 11,
#  '거부': 11,
#  '협정': 11,
#  '원칙': 11,
#  '형태': 11,
#  '매우': 11,
#  '성격': 11,
#  '결격': 11,
#  '연간': 11,
#  '미만': 11,
#  '기능': 11,
#  '유족': 11,
#  '소비': 11,
#  '의료인': 11,
#  '형벌': 11,
#  '책임': 11,
#  '신체': 11,
#  '가스': 11,
#  '이전': 11,
#  '결핵': 11,
#  '가해': 11,
#  '편입': 11,
#  '상대방': 11,
#  '요양': 11,
#  '세율': 11,
#  '소한': 11,
#  '한약사': 11,
#  '군사': 10,
#  '지장': 10,
#  '세액': 10,
#  '하나': 10,
#  '직장': 10,
#  '자체': 10,
#  '회사': 10,
#  '본인': 10,
#  '금융기관': 10,
#  '신분': 10,
#  '제정': 10,
#  '교통사고': 10,
#  '벌칙': 10,
#  '표준': 10,
#  '단축': 10,
#  '휴업': 10,
#  '연구기관': 10,
#  '제품': 10,
#  '공유': 10,
#  '향교': 10,
#  '단서': 10,
#  '매크로': 10,
#  '폐광': 10,
#  '일자리': 10,
#  '청년': 10,
#  '특별법': 10,
#  '이자': 10,
#  '해소': 10,
#  '광고': 10,
#  '인상': 10,
#  '안전성': 10,
#  '금융업': 10,
#  '군경': 10,
#  '토지': 10,
#  '희망': 10,
#  '반환': 10,
#  '장구': 10,
#  '소방대': 10,
#  '원장': 10,
#  '노무': 10,
#  '외국인': 10,
#  '징계': 10,
#  '피의자': 10,
#  '대부': 10,
#  '택용': 10,
#  '협동조합': 10,
#  '전자거래': 10,
#  '의관': 10,
#  '부가가치': 10,
#  '최고': 9,
#  '주요': 9,
#  '수단': 9,
#  '도시': 9,
#  '정도': 9,
#  '별로': 9,
#  '모두': 9,
#  '적응': 9,
#  '이익': 9,
#  '제조업': 9,
#  '참여': 9,
#  '석유': 9,
#  '군사기지': 9,
#  '여객': 9,
#  '운수': 9,
#  '음주': 9,
#  '판단': 9,
#  '육아휴직': 9,
#  '아기': 9,
#  '입법': 9,
#  '해외진출': 9,
#  '위험': 9,
#  '수가': 9,
#  '환수': 9,
#  '유형': 9,
#  '방안': 9,
#  '원인': 9,
#  '제시': 9,
#  '정신': 9,
#  '진단': 9,
#  '특수': 9,
#  '기밀': 9,
#  '주의': 9,
#  '주자': 9,
#  '정기': 9,
#  '통보': 9,
#  '논란': 9,
#  '병역': 9,
#  '유해': 9,
#  '체육회': 9,
#  '가능성': 9,
#  '구분': 9,
#  '제작': 9,
#  '원료': 9,
#  '환경부': 9,
#  '적합': 9,
#  '추정': 9,
#  '서류': 9,
#  '단계': 9,
#  '학령': 9,
#  '경감': 9,
#  '좌석': 9,
#  '명의': 9,
#  '동물': 9,
#  '서민': 9,
#  '일몰': 9,
#  '안심': 9,
#  '폭염': 9,
#  '재산세': 9,
#  '농어촌': 9,
#  '합법': 9,
#  '마약': 9,
#  '대한': 9,
#  '재범': 8,
#  '수사': 8,
#  '이해': 8,
#  '지출': 8,
#  '중소': 8,
#  '유효': 8,
#  '보조금': 8,
#  '교부': 8,
#  '해석': 8,
#  '아동학대': 8,
#  '국민연금': 8,
#  '투명': 8,
#  '도매시장': 8,
#  '선택': 8,
#  '동안': 8,
#  '설비': 8,
#  '지원이': 8,
#  '성장': 8,
#  '대비': 8,
#  '선정': 8,
#  '규칙': 8,
#  '주식': 8,
#  '집중': 8,
#  '징역형': 8,
#  '복리': 8,
#  '증대': 8,
#  '민지원': 8,
#  '미국': 8,
#  '부분': 8,
#  '한계': 8,
#  '취약': 8,
#  '구성원': 8,
#  '차원': 8,
#  '지방의회': 8,
#  '정치': 8,
#  '행사': 8,
#  '공익': 8,
#  '항공': 8,
#  '부업': 8,
#  '소요': 8,
#  '가중': 8,
#  '통계': 8,
#  '내진': 8,
#  '세부': 8,
#  '시작': 8,
#  '즉각': 8,
#  '빈번': 8,
#  '시스템': 8,
#  '일로': 8,
#  '전국': 8,
#  '연금': 8,
#  '타인': 8,
#  '정신과': 8,
#  '중독': 8,
#  '개설': 8,
#  '생명': 8,
#  '가운데': 8,
#  '구호': 8,
#  '정보통': 8,
#  '경과': 8,
#  '마일리지': 8,
#  '노동': 8,
#  '매매': 8,
#  '분산': 8,
#  '후유': 8,
#  '집행유예': 8,
#  '유지관리': 8,
#  '감염병': 8,
#  '전직': 8,
#  '방산': 8,
#  '카시트': 8,
#  '우편': 8,
#  '것임': 8,
#  '약국': 8,
#  '교육활동': 8,
#  '사법': 7,
#  '대부분': 7,
#  '여건': 7,
#  '보유': 7,
#  '시점': 7,
#  '여성': 7,
#  '특별자치시': 7,
#  '직업': 7,
#  '경찰관': 7,
#  '보임': 7,
#  '권고': 7,
#  '지체': 7,
#  '안전보장': 7,
#  '군사시설': 7,
#  '통합': 7,
#  '초등학교': 7,
#  '양육': 7,
#  '출산': 7,
#  '불합리': 7,
#  '반면': 7,
#  '가정폭력': 7,
#  '부령': 7,
#  '평균': 7,
#  '사채': 7,
#  '질서': 7,
#  '불공정': 7,
#  '계승': 7,
#  '유원': 7,
#  '관리자': 7,
#  '사전': 7,
#  '대형': 7,
#  '동시': 7,
#  '경비': 7,
#  '노출': 7,
#  '용어': 7,
#  '미사일': 7,
#  '연도': 7,
#  '계속': 7,
#  '유출': 7,
#  '생산자': 7,
#  '이탈': 7,
#  '조례': 7,
#  '서로': 7,
#  '관서': 7,
#  '금리': 7,
#  '기반시설': 7,
#  '것이므': 7,
#  '불법': 7,
#  '화재': 7,
#  '지진': 7,
#  '초과': 7,
#  '국무총리': 7,
#  '의약품': 7,
#  '예정': 7,
#  '역할': 7,
#  '자치': 7,
#  '수익': 7,
#  '임차': 7,
#  '특허': 7,
#  '출원': 7,
#  '기계': 7,
#  '편의': 7,
#  '추이': 7,
#  '명문': 7,
#  '자신': 7,
#  '접수': 7,
#  '진료': 7,
#  '대상자': 7,
#  '이사회': 7,
#  '결의': 7,
#  '수신료': 7,
#  '약관': 7,
#  '시기': 7,
#  '택시': 7,
#  '서도': 7,
#  '확충': 7,
#  '봉안': 7,
#  '상담': 7,
#  '산지': 7,
#  '대행': 7,
#  '회원': 7,
#  '폭행': 7,
#  '동의': 7,
#  '놀이기구': 7,
#  '괴롭힘': 7,
#  '승강기': 7,
#  '전역': 7,
#  '장병': 7,
#  '물자': 7,
#  '전투': 7,
#  '광역': 7,
#  '공보': 7,
#  '전자문서': 7,
#  '소독': 7,
#  '건축': 6,
#  '훼손': 6,
#  '접근': 6,
#  '준수': 6,
#  '전담': 6,
#  '부여': 6,
#  '공제': 6,
#  '국회': 6,
#  '혼선': 6,
#  '경제활동': 6,
#  '위임': 6,
#  '행위자': 6,
#  '필수': 6,
#  '유발': 6,
#  '자주': 6,
#  '대학': 6,
#  '재직': 6,
#  '유예': 6,
#  '차단': 6,
#  '운행': 6,
#  '운전': 6,
#  '출산휴가': 6,
#  '체당': 6,
#  '사용자': 6,
#  '임신': 6,
#  '양성': 6,
#  '발행': 6,
#  '허위': 6,
#  '세대': 6,
#  '마트': 6,
#  '과도': 6,
#  '건물': 6,
#  '의심': 6,
#  '누설': 6,
#  '보안': 6,
#  '문서': 6,
#  '증명서': 6,
#  '촬영': 6,
#  '담보': 6,
#  '북한': 6,
#  '일본': 6,
#  '파기': 6,
#  '회계': 6,
#  '노력': 6,
#  '문제점': 6,
#  '사이': 6,
#  '분쟁': 6,
#  '첨단': 6,
#  '균형': 6,
#  '주거': 6,
#  '현저': 6,
#  '회복': 6,
#  '국방': 6,
#  '회장': 6,
#  '정성': 6,
#  '공직': 6,
#  '도로': 6,
#  '성범죄': 6,
#  '매출': 6,
#  '분할': 6,
#  '지방세': 6,
#  '분석': 6,
#  '한국은행': 6,
#  '수집': 6,
#  '탄력': 6,
#  '영위': 6,
#  '검토': 6,
#  '융자': 6,
#  '상이': 6,
#  '순직': 6,
#  '소유자': 6,
#  '리콜': 6,
#  '사기': 6,
#  '지식': 6,
#  '적정': 6,
#  '여야': 6,
#  '약물': 6,
#  '발명': 6,
#  '수용': 6,
#  '배치': 6,
#  '공시지가': 6,
#  '의뢰': 6,
#  '도로공사': 6,
#  '철도공사': 6,
#  '담당': 6,
#  '변호사': 6,
#  '공공기관': 6,
#  '건의': 6,
#  '형식': 6,
#  '통화': 6,
#  '정주': 6,
#  '농가': 6,
#  '경영': 6,
#  '고발': 6,
#  '검찰': 6,
#  '투표': 6,
#  '해결': 6,
#  '소집': 6,
#  '농업': 6,
#  '안전띠': 6,
#  '착용': 6,
#  '운송': 6,
#  '도움': 6,
#  '예술': 6,
#  '임상시험': 6,
#  '농협': 6,
#  '출자': 6,
#  '실내': 6,
#  '임기': 6,
#  '악화': 6,
#  '점자': 6,
#  '고도화': 6,
#  '북핵': 6,
#  '정예': 6,
#  '긴요': 6,
#  '직위': 6,
#  '정직': 6,
#  '골재': 6,
#  '착공': 6,
#  '고사항': 6,
#  '자원봉사': 6,
#  '재산권': 5,
#  '피해자': 5,
#  '이원화': 5,
#  '시대': 5,
#  '고령화': 5,
#  '농산물': 5,
#  '측면': 5,
#  '조직': 5,
#  '성지': 5,
#  '조기': 5,
#  '창고': 5,
#  '수산물': 5,
#  '식품': 5,
#  '처우': 5,
#  '도로교통법': 5,
#  '가정': 5,
#  '학년': 5,
#  '용기': 5,
#  '유급': 5,
#  '목소리': 5,
#  ...}

# %%
# 정의당 20
wordcloud(JE)
# Out:
# {'위원회': 992,
#  '지원': 947,
#  '국가': 779,
#  '기관': 706,
#  '사항': 698,
#  '관리': 698,
#  '근로자': 678,
#  '보호': 643,
#  '관련': 612,
#  '의결': 587,
#  '의료': 583,
#  '시설': 577,
#  '해당': 575,
#  '행위': 572,
#  '업무': 565,
#  '장관': 561,
#  '발생': 544,
#  '교육': 541,
#  '이상': 539,
#  '국민': 537,
#  '운영': 507,
#  '기준': 495,
#  '설치': 491,
#  '장애인': 481,
#  '의무': 480,
#  '사회': 477,
#  '대하': 476,
#  '지역': 472,
#  '피해': 440,
#  '이하': 438,
#  '지방자치단체': 436,
#  '기간': 427,
#  '대상': 427,
#  '사용': 422,
#  '계획': 409,
#  '제도': 403,
#  '조사': 400,
#  '일부': 400,
#  '개정': 395,
#  '안전': 393,
#  '포함': 392,
#  '신설': 389,
#  '마련': 384,
#  '거나': 377,
#  '제공': 373,
#  '사람': 366,
#  '시행': 361,
#  '건강': 361,
#  '조치': 357,
#  '학교': 345,
#  '항제': 345,
#  '근거': 342,
#  '수행': 342,
#  '현행법': 341,
#  '금지': 340,
#  '활동': 339,
#  '위해': 336,
#  '지급': 334,
#  '목적': 330,
#  '고용': 328,
#  '조정': 326,
#  '지정': 325,
#  '정보': 323,
#  '부담': 323,
#  '제한': 320,
#  '현행': 311,
#  '이용': 294,
#  '정책': 292,
#  '대해': 291,
#  '보장': 289,
#  '적용': 286,
#  '개선': 284,
#  '신고': 284,
#  '산업': 282,
#  '사업자': 280,
#  '심의': 280,
#  '금액': 278,
#  '상황': 278,
#  '실정': 277,
#  '보험': 276,
#  '필요': 276,
#  '또한': 271,
#  '수립': 270,
#  '번호': 269,
#  '범위': 268,
#  '최근': 268,
#  '위반': 266,
#  '아동': 266,
#  '부과': 266,
#  '의안': 263,
#  '문화': 262,
#  '국회': 261,
#  '환경': 260,
#  '소득': 259,
#  '공무원': 259,
#  '실시': 256,
#  '복지': 254,
#  '비용': 253,
#  '문제': 248,
#  '보건': 247,
#  '대표': 247,
#  '사건': 245,
#  '제기': 244,
#  '피해자': 243,
#  '방지': 242,
#  '단체': 241,
#  '관계': 238,
#  '보건복지부': 235,
#  '결정': 234,
#  '내용': 232,
#  '제출': 228,
#  '신청': 227,
#  '정부': 224,
#  '요구': 223,
#  '처벌': 222,
#  '지적': 219,
#  '인정': 219,
#  '변경': 218,
#  '확보': 217,
#  '의원': 216,
#  '평가': 215,
#  '사유': 215,
#  '자료': 214,
#  '위원': 212,
#  '서비스': 212,
#  '급여': 211,
#  '참고': 207,
#  '법인': 206,
#  '결과': 204,
#  '삭제': 204,
#  '소속': 203,
#  '확대': 202,
#  '재산': 202,
#  '범죄': 202,
#  '대통령령': 199,
#  '기업': 198,
#  '예방': 196,
#  '다른': 196,
#  '발전': 195,
#  '수급': 195,
#  '의견': 194,
#  '이내': 193,
#  '사실': 193,
#  '명시': 189,
#  '수정': 189,
#  '추가': 188,
#  '발의': 185,
#  '처분': 180,
#  '근로': 180,
#  '임금': 180,
#  '과징금': 180,
#  '구성': 179,
#  '책임': 178,
#  '제외': 178,
#  '기금': 178,
#  '등록': 178,
#  '직접': 178,
#  '어린이': 177,
#  '생활': 176,
#  '안정': 176,
#  '학생': 175,
#  '판매': 173,
#  '방법': 172,
#  '설립': 171,
#  '과정': 170,
#  '연금': 170,
#  '전제': 170,
#  '현재': 169,
#  '허가': 168,
#  '고려': 168,
#  '청소년': 168,
#  '안이': 168,
#  '계약': 167,
#  '검사': 166,
#  '대학': 166,
#  '참여': 164,
#  '한편': 164,
#  '경제': 164,
#  '개발': 163,
#  '요청': 162,
#  '증진': 161,
#  '추천': 160,
#  '주택': 160,
#  '것이므': 160,
#  '자격': 159,
#  '우려': 159,
#  '불구': 159,
#  '환자': 159,
#  '수준': 158,
#  '방송': 158,
#  '협의': 157,
#  '권리': 157,
#  '의약품': 157,
#  '성희롱': 157,
#  '통해': 155,
#  '회의': 154,
#  '절차': 153,
#  '동물': 153,
#  '공공기관': 153,
#  '직무': 153,
#  '병원': 153,
#  '재정': 152,
#  '요건': 150,
#  '정의': 150,
#  '구역': 149,
#  '특별': 148,
#  '행정기관': 147,
#  '후보자': 146,
#  '중앙': 146,
#  '체계': 145,
#  '예산': 145,
#  '기본': 145,
#  '추진': 143,
#  '한국': 143,
#  '정지': 143,
#  '영향': 142,
#  '업자': 141,
#  '수입': 141,
#  '인권': 140,
#  '성폭력': 140,
#  '종합': 139,
#  '직원': 139,
#  '기여': 138,
#  '과태료': 137,
#  '거래': 137,
#  '대통령': 136,
#  '작성': 136,
#  '공익': 136,
#  '제재': 136,
#  '지속': 136,
#  '회사': 135,
#  '증가': 135,
#  '법적': 134,
#  '주민': 133,
#  '인력': 133,
#  '식품': 133,
#  '지방': 133,
#  '임원': 132,
#  '선거': 132,
#  '공개': 132,
#  '기술': 132,
#  '차별': 130,
#  '보험료': 130,
#  '심사': 129,
#  '산정': 129,
#  '유지': 128,
#  '센터': 128,
#  '정당': 128,
#  '자녀': 128,
#  '도록': 127,
#  '보고': 127,
#  '청구': 126,
#  '협력': 126,
#  '청년': 126,
#  '처리': 125,
#  '직장': 125,
#  '집행': 124,
#  '납부': 124,
#  '확인': 124,
#  '영업': 123,
#  '사고': 123,
#  '이유': 123,
#  '보상': 122,
#  '채용': 122,
#  '금융': 121,
#  '부금': 121,
#  '가족': 120,
#  '주거': 120,
#  '법령': 120,
#  '실효': 120,
#  '신체': 120,
#  '진흥': 119,
#  '의료인': 119,
#  '호의': 118,
#  '교통': 118,
#  '명령': 117,
#  '이행': 117,
#  '대책': 117,
#  '벌금': 116,
#  '반영': 115,
#  '사법': 115,
#  '침해': 115,
#  '기초': 114,
#  '재해': 114,
#  '장애': 114,
#  '의사': 113,
#  '소비자': 113,
#  '징역': 113,
#  '여부': 112,
#  '일정': 111,
#  '민간': 111,
#  '시장': 111,
#  '도입': 110,
#  '효과': 110,
#  '종사': 110,
#  '경영': 109,
#  '원칙': 109,
#  '개월': 109,
#  '가입자': 109,
#  '초과': 108,
#  '재난': 108,
#  '비율': 108,
#  '사망': 108,
#  '취소': 108,
#  '감독': 107,
#  '불법': 107,
#  '공급': 106,
#  '향상': 106,
#  '사용자': 106,
#  '이후': 105,
#  '행사': 103,
#  '규제': 103,
#  '취업': 102,
#  '어린이집': 101,
#  '로서': 101,
#  '자동차': 101,
#  '사례': 100,
#  '계속': 100,
#  '군인': 100,
#  '표시': 100,
#  '효율': 99,
#  '상의': 98,
#  '분야': 98,
#  '가입': 98,
#  '대상자': 97,
#  '건설': 97,
#  '편의': 96,
#  '임명': 96,
#  '능력': 96,
#  '교원': 96,
#  '치료': 96,
#  '회복': 96,
#  '투표': 95,
#  '법원': 95,
#  '관할': 95,
#  '우리나라': 95,
#  '조건': 95,
#  '국내': 94,
#  '인증': 93,
#  '이익': 92,
#  '기능': 91,
#  '자의': 91,
#  '대응': 91,
#  '개인': 91,
#  '정신': 91,
#  '보수': 90,
#  '도모': 90,
#  '연구': 90,
#  '따라서': 90,
#  '장기': 90,
#  '고객': 90,
#  '업주': 90,
#  '해소': 89,
#  '상태': 89,
#  '노동': 89,
#  '소방': 89,
#  '활용': 88,
#  '매년': 88,
#  '소관': 88,
#  '취지': 88,
#  '전문': 88,
#  '물질': 88,
#  '노인': 88,
#  '형태': 87,
#  '구체': 87,
#  '훈련': 87,
#  '부정': 87,
#  '조항': 87,
#  '생산': 87,
#  '실질': 87,
#  '규모': 86,
#  '운용': 86,
#  '연장': 85,
#  '사무': 85,
#  '도지사': 85,
#  '복무': 85,
#  '유공': 85,
#  '조성': 84,
#  '수사': 84,
#  '파견': 84,
#  '등록금': 84,
#  '성과': 83,
#  '별도': 83,
#  '실태': 83,
#  '촉진': 83,
#  '로부터': 83,
#  '규정': 83,
#  '활성화': 82,
#  '한정': 82,
#  '근무': 82,
#  '기록': 81,
#  '전부': 81,
#  '현장': 81,
#  '유통': 81,
#  '재원': 81,
#  '선정': 81,
#  '질병': 80,
#  '제조': 80,
#  '직업': 80,
#  '진료': 80,
#  '재활': 80,
#  '허용': 79,
#  '적극': 79,
#  '특정': 79,
#  '회계': 79,
#  '일반': 79,
#  '어려움': 79,
#  '보조': 79,
#  '시간': 79,
#  '미만': 79,
#  '승인': 78,
#  '특수': 78,
#  '위험': 78,
#  '국회의원': 78,
#  '현황': 77,
#  '판단': 77,
#  '가정': 77,
#  '광고': 77,
#  '권고': 76,
#  '정비': 76,
#  '외국인': 76,
#  '주가': 76,
#  '연간': 75,
#  '각각': 75,
#  '자가': 75,
#  '주체': 75,
#  '정치': 75,
#  '전체': 74,
#  '고용노동부': 74,
#  '개설': 74,
#  '촬영': 74,
#  '국민연금': 74,
#  '과세': 74,
#  '통상': 74,
#  '수단': 73,
#  '관광': 73,
#  '현실': 73,
#  '이용자': 73,
#  '이사회': 72,
#  '방식': 72,
#  '공직자': 72,
#  '감사': 71,
#  '완화': 71,
#  '수당': 71,
#  '징계': 71,
#  '여성': 71,
#  '행정': 71,
#  '상한': 71,
#  '본인': 71,
#  '동의': 71,
#  '육아휴직': 71,
#  '유족': 71,
#  '업체': 71,
#  '공사': 71,
#  '휴가': 71,
#  '규명': 70,
#  '국제': 70,
#  '시책': 70,
#  '상향': 70,
#  '특례': 70,
#  '민주': 69,
#  '퇴직': 69,
#  '인사': 69,
#  '주식': 68,
#  '권한': 68,
#  '급식': 68,
#  '실제': 68,
#  '취득': 67,
#  '이사': 67,
#  '보유': 67,
#  '각종': 67,
#  '필요성': 67,
#  '차량': 67,
#  '구제': 67,
#  '변호사': 67,
#  '윤리': 66,
#  '공직': 66,
#  '아동학대': 66,
#  '역할': 66,
#  '방안': 66,
#  '임대': 66,
#  '손해': 66,
#  '출산': 66,
#  '가치': 65,
#  '대여': 65,
#  '교육부': 65,
#  '지위': 65,
#  '도로': 65,
#  '징수': 65,
#  '제품': 65,
#  '선임': 64,
#  '연도': 64,
#  '공단': 64,
#  '노력': 64,
#  '거부': 64,
#  '주의': 63,
#  '원인': 63,
#  '보육': 63,
#  '자격증': 63,
#  '때문': 63,
#  '보전': 63,
#  '노동조합': 63,
#  '경찰': 63,
#  '재판': 63,
#  '농어': 63,
#  '특성': 63,
#  '주변': 63,
#  '에너지': 63,
#  '진상': 62,
#  '우선': 62,
#  '예술': 62,
#  '배우자': 61,
#  '행위자': 61,
#  '이바지': 61,
#  '연령': 61,
#  '해외': 61,
#  '약자': 61,
#  '최저임금': 61,
#  '보고서': 60,
#  '위탁': 60,
#  '학대': 60,
#  '명칭': 60,
#  '확정': 60,
#  '헌법': 60,
#  '장치': 60,
#  '단서': 60,
#  '부여': 60,
#  '생명': 60,
#  '수련': 60,
#  '면제': 60,
#  '배분': 60,
#  '이전': 59,
#  '서류': 59,
#  '담당': 59,
#  '사전': 59,
#  '성범죄': 59,
#  '군수': 58,
#  '동안': 58,
#  '공제': 58,
#  '처우': 58,
#  '통한': 58,
#  '불이익': 58,
#  '인식': 58,
#  '주요': 57,
#  '결산': 57,
#  '공동': 57,
#  '모든': 57,
#  '소송': 57,
#  '준수': 57,
#  '폐지': 57,
#  '제정': 57,
#  '조직': 57,
#  '채권': 57,
#  '상임': 56,
#  '강화': 56,
#  '선고': 56,
#  '고하': 56,
#  '문화재': 56,
#  '대리': 56,
#  '국방부': 56,
#  '신용': 55,
#  '명의': 55,
#  '통신': 55,
#  '실현': 55,
#  '분석': 55,
#  '교부': 55,
#  '자유': 55,
#  '전환': 55,
#  '소유': 54,
#  '거짓': 54,
#  '대부분': 54,
#  '별표': 54,
#  '신뢰': 54,
#  '용도': 54,
#  '벌칙': 54,
#  '이상인': 54,
#  '가맹': 54,
#  '대한민국': 53,
#  '대규모': 53,
#  '제대로': 53,
#  '상담': 53,
#  '정함': 53,
#  '점검': 53,
#  '부모': 53,
#  '기후변화': 53,
#  '동시': 52,
#  '정기': 52,
#  '예외': 52,
#  '경찰관': 52,
#  '육성': 52,
#  '집단': 52,
#  '기반': 52,
#  '시정': 52,
#  '세액': 52,
#  '보증': 52,
#  '매출': 52,
#  '별로': 51,
#  '당사자': 51,
#  '지도': 51,
#  '자로': 51,
#  '역사': 51,
#  '의미': 51,
#  '평균': 51,
#  '형사': 51,
#  '선거운동': 51,
#  '대체복무': 51,
#  '위임': 50,
#  '제시': 50,
#  '위원장': 50,
#  '담배': 50,
#  '수술': 50,
#  '알선': 50,
#  '청장': 49,
#  '성별': 49,
#  '과도': 49,
#  '요양': 49,
#  '연구개발': 49,
#  '형평성': 49,
#  '경비': 49,
#  '면허': 49,
#  '도시': 49,
#  '단계': 49,
#  '구조': 49,
#  '용어': 49,
#  '한계': 49,
#  '가능성': 49,
#  '체결': 49,
#  '어업': 49,
#  '저출산': 49,
#  '주주': 48,
#  '명예': 48,
#  '통합': 48,
#  '보존': 48,
#  '상속': 48,
#  '유발': 48,
#  '운전': 48,
#  '시험': 48,
#  '교사': 48,
#  '영상': 48,
#  '경력': 48,
#  '통보': 48,
#  '지원이': 48,
#  '상호': 48,
#  '하나': 48,
#  '정성': 48,
#  '모집': 48,
#  '사업': 48,
#  '인터넷': 47,
#  '중심': 47,
#  '구매': 47,
#  '대비': 47,
#  '중소기업': 47,
#  '체납': 47,
#  '투자': 47,
#  '예산안': 46,
#  '발급': 46,
#  '최소': 46,
#  '권익': 46,
#  '해결': 46,
#  '외국': 46,
#  '목표': 46,
#  '운동': 46,
#  '세율': 46,
#  '출자': 46,
#  '중소': 46,
#  '채무자': 46,
#  '입양': 46,
#  '기존': 45,
#  '전문성': 45,
#  '국무총리': 45,
#  '방송통신': 45,
#  '사립학교': 45,
#  '유치원': 45,
#  '성적': 45,
#  '가격': 45,
#  '보완': 45,
#  '비밀': 45,
#  '부분': 45,
#  '국회법': 45,
#  '부상': 45,
#  '임대주택': 45,
#  '학부모': 45,
#  '농업': 45,
#  '중인': 44,
#  '강제': 44,
#  '공유': 44,
#  '확산': 44,
#  '거주': 44,
#  '고시': 44,
#  '갱신': 44,
#  '운행': 44,
#  '장소': 44,
#  '위생': 44,
#  '투명': 44,
#  '진행': 44,
#  '의료법': 44,
#  '운송': 44,
#  '제조업': 44,
#  '소요': 44,
#  '축산물': 44,
#  '가습기': 44,
#  '살균제': 44,
#  '전담': 44,
#  '성장': 44,
#  '통지': 43,
#  '세대': 43,
#  '개별': 43,
#  '양도': 43,
#  '질환': 43,
#  '임산부': 43,
#  '최저': 43,
#  '유해': 43,
#  '금품': 43,
#  '지배': 43,
#  '필수': 43,
#  '간호': 43,
#  '괴롭힘': 43,
#  '진술': 42,
#  '정도': 42,
#  '대법원': 42,
#  '전국': 42,
#  '식품의약품안전처': 42,
#  '시스템': 42,
#  '계층': 42,
#  '화장품': 42,
#  '더욱': 42,
#  '노출': 42,
#  '고등학교': 42,
#  '원자력': 42,
#  '평등': 42,
#  '법안': 42,
#  '은행': 42,
#  '교류': 42,
#  '홍보': 41,
#  '환수': 41,
#  '합리': 41,
#  '저해': 41,
#  '가중': 41,
#  '자신': 41,
#  '비상': 41,
#  '구분': 41,
#  '국외': 41,
#  '특별회계': 41,
#  '기한': 41,
#  '지난': 41,
#  '선택': 41,
#  '유아': 41,
#  '표현': 41,
#  '간의': 41,
#  '요금': 41,
#  '스토킹': 41,
#  '기구': 40,
#  '남녀': 40,
#  '임기': 40,
#  '보급': 40,
#  '국토교통부': 40,
#  '설정': 40,
#  '국가인권위': 40,
#  '접근성': 40,
#  '원금': 40,
#  '준용': 40,
#  '정신질환': 40,
#  '긴급': 40,
#  '위기': 40,
#  '손실': 40,
#  '손해배상': 40,
#  '벌금형': 40,
#  '성매매': 40,
#  '남북': 40,
#  '응대': 40,
#  '대한': 40,
#  '달리': 39,
#  '독립': 39,
#  '파악': 39,
#  '품질': 39,
#  '폭행': 39,
#  '구축': 39,
#  '무상': 39,
#  '취약': 39,
#  '휴직': 39,
#  '정신건강': 39,
#  '간호사': 39,
#  '수도권': 39,
#  '노동자': 39,
#  '공시': 39,
#  '유형': 39,
#  '분쟁': 39,
#  '자살': 39,
#  '최대': 38,
#  '분리': 38,
#  '검토': 38,
#  '당시': 38,
#  '증인': 38,
#  '근절': 38,
#  '질서': 38,
#  '수요': 38,
#  '수집': 38,
#  '입법': 38,
#  '감소': 38,
#  '존재': 38,
#  '측면': 38,
#  '세입': 38,
#  '최고': 38,
#  '공표': 38,
#  '성차별': 38,
#  '위촉': 37,
#  '유효': 37,
#  '담보': 37,
#  '역시': 37,
#  '정법': 37,
#  '지휘': 37,
#  '관행': 37,
#  '접근': 37,
#  '인구': 37,
#  '임용': 37,
#  '부합': 37,
#  '공정': 37,
#  '희생': 37,
#  '오염': 37,
#  '업종': 37,
#  '정착': 37,
#  '자립': 37,
#  '지주회사': 37,
#  '개인정보': 37,
#  '음주운전': 37,
#  '안건': 36,
#  '배제': 36,
#  '과학기술': 36,
#  '전기통신': 36,
#  '운전자': 36,
#  '시민': 36,
#  '고등교육': 36,
#  '수익': 36,
#  '매우': 36,
#  '임의': 36,
#  '체불': 36,
#  '유급': 36,
#  '점포': 36,
#  '국가정보원': 36,
#  '기본권': 36,
#  '전자': 35,
#  '예비': 35,
#  '고지': 35,
#  '수가': 35,
#  '다수': 35,
#  '반려동물': 35,
#  '자등': 35,
#  '양성': 35,
#  '학교법인': 35,
#  '교직원': 35,
#  '포괄': 35,
#  '소음': 35,
#  '반면': 35,
#  '부칙': 35,
#  '비판': 35,
#  '세계': 35,
#  '이외': 35,
#  '대체': 35,
#  '교통사고': 35,
#  '차지': 35,
#  '근로시간': 35,
#  '이동': 35,
#  '재료': 35,
#  '배상': 35,
#  '감염병': 35,
#  '바이오': 35,
#  '임대차': 35,
#  '첨단': 35,
#  '출석': 34,
#  '농림축산식품부': 34,
#  '중요': 34,
#  '교육감': 34,
#  '배출': 34,
#  '건물': 34,
#  '자치': 34,
#  '외부': 34,
#  '전문가': 34,
#  '자금': 34,
#  '누구': 34,
#  '수령': 34,
#  '국립': 34,
#  '우리': 34,
#  '기회': 34,
#  '마약': 34,
#  '구직': 34,
#  '분할': 33,
#  '선출': 33,
#  '폭력': 33,
#  '부터': 33,
#  '보관': 33,
#  '취하': 33,
#  '만료': 33,
#  '보호자': 33,
#  '실적': 33,
#  '빈번': 33,
#  '입학': 33,
#  '가지': 33,
#  '공공': 33,
#  '부패': 33,
#  '음성': 33,
#  '규칙': 33,
#  '기부': 33,
#  '부수': 33,
#  '예술인': 33,
#  '중단': 33,
#  '애인': 33,
#  '교육재정': 33,
#  '회원': 33,
#  '주장': 33,
#  '위안부': 33,
#  '법률': 33,
#  '남용': 32,
#  '정원': 32,
#  '확립': 32,
#  '안전성': 32,
#  '품목': 32,
#  '가운데': 32,
#  '방해': 32,
#  '위협': 32,
#  '모두': 32,
#  '법무부': 32,
#  '혁신': 32,
#  '영화': 32,
#  '합의': 32,
#  '임차': 32,
#  '차원': 32,
#  '환경부': 32,
#  '적립금': 32,
#  '소재': 32,
#  '친족': 32,
#  '표준': 32,
#  '학습': 32,
#  '보조금': 32,
#  '미국': 32,
#  '의료기기': 32,
#  '방향': 32,
#  '논란': 32,
#  '지침': 32,
#  '수신료': 32,
#  '상환': 32,
#  '양육': 32,
#  '집회': 31,
#  '경과': 31,
#  '남성': 31,
#  '판결': 31,
#  '배치': 31,
#  '폐업': 31,
#  '문제점': 31,
#  '제작': 31,
#  '운영자': 31,
#  '도의': 31,
#  '헌법재판소': 31,
#  '설비': 31,
#  '전용': 31,
#  '고령자': 31,
#  '협조': 31,
#  '한도': 31,
#  '건축물': 31,
#  '용역': 31,
#  '산입': 31,
#  '자기': 30,
#  '종료': 30,
#  '부가': 30,
#  '가공': 30,
#  '서도': 30,
#  '충족': 30,
#  '진단': 30,
#  '다시': 30,
#  '초래': 30,
#  '특별자치도': 30,
#  '특별법': 30,
#  '출연': 30,
#  '검찰': 30,
#  '예정': 30,
#  '점자': 30,
#  '재단': 30,
#  '감염': 30,
#  '기재': 30,
#  '미성년': 30,
#  '구성원': 30,
#  '자산': 30,
#  '개시': 30,
#  '과세표준': 30,
#  '회수': 30,
#  '라돈': 30,
#  '제청': 30,
#  '할당': 30,
#  '영향력': 30,
#  '변동': 29,
#  '집중': 29,
#  '현저': 29,
#  '의식': 29,
#  '북한': 29,
#  '이자': 29,
#  '이로': 29,
#  '여건': 29,
#  '교섭단체': 29,
#  '비영리': 29,
#  '해고': 29,
#  '인상': 29,
#  ...}

# %%
# 국민의당 20
wordcloud(KM)
# Out:
# {'위원회': 2351,
#  '관리': 1902,
#  '지원': 1879,
#  '국가': 1757,
#  '관련': 1570,
#  '사항': 1529,
#  '발생': 1451,
#  '지역': 1403,
#  '기관': 1353,
#  '시설': 1351,
#  '해당': 1349,
#  '개정': 1335,
#  '의결': 1307,
#  '국민': 1306,
#  '보호': 1299,
#  '안전': 1267,
#  '지방자치단체': 1250,
#  '장관': 1226,
#  '제도': 1223,
#  '기준': 1206,
#  '시행': 1180,
#  '대상': 1174,
#  '운영': 1162,
#  '계획': 1160,
#  '대하': 1147,
#  '행위': 1147,
#  '설치': 1134,
#  '사회': 1115,
#  '업무': 1110,
#  '기간': 1065,
#  '의무': 1064,
#  '마련': 1061,
#  '사용': 1041,
#  '이상': 1036,
#  '일부': 1012,
#  '산업': 993,
#  '신설': 991,
#  '교육': 968,
#  '조정': 951,
#  '근거': 944,
#  '항제': 938,
#  '대해': 936,
#  '현행법': 902,
#  '근로자': 897,
#  '이용': 894,
#  '지급': 894,
#  '이하': 886,
#  '위해': 883,
#  '부담': 881,
#  '거나': 877,
#  '정보': 871,
#  '피해': 863,
#  '지정': 857,
#  '포함': 841,
#  '제공': 833,
#  '기업': 826,
#  '위반': 822,
#  '조사': 818,
#  '현행': 806,
#  '필요': 802,
#  '공무원': 780,
#  '수행': 774,
#  '적용': 763,
#  '사업자': 758,
#  '사람': 745,
#  '목적': 744,
#  '상황': 741,
#  '문제': 736,
#  '신고': 723,
#  '환경': 722,
#  '실정': 716,
#  '제한': 707,
#  '처벌': 693,
#  '범위': 691,
#  '정책': 686,
#  '소득': 680,
#  '심의': 675,
#  '범죄': 675,
#  '확보': 671,
#  '정부': 669,
#  '발전': 669,
#  '수립': 660,
#  '개발': 654,
#  '부과': 650,
#  '금융': 640,
#  '실시': 639,
#  '보험': 637,
#  '주택': 635,
#  '또한': 634,
#  '금액': 632,
#  '최근': 628,
#  '대표': 625,
#  '조치': 595,
#  '번호': 585,
#  '제기': 585,
#  '개선': 583,
#  '의안': 580,
#  '신청': 572,
#  '의원': 572,
#  '보장': 565,
#  '활동': 564,
#  '사유': 561,
#  '요구': 557,
#  '의료': 556,
#  '내용': 549,
#  '고용': 538,
#  '지적': 538,
#  '건강': 536,
#  '관계': 535,
#  '국회': 531,
#  '대통령령': 529,
#  '인정': 525,
#  '경제': 521,
#  '방지': 516,
#  '단체': 512,
#  '제출': 512,
#  '자료': 512,
#  '금지': 511,
#  '비용': 508,
#  '위원': 508,
#  '확대': 505,
#  '학교': 505,
#  '기술': 504,
#  '결정': 504,
#  '회의': 501,
#  '중소기업': 499,
#  '피해자': 499,
#  '등록': 496,
#  '평가': 493,
#  '추진': 486,
#  '다른': 486,
#  '증가': 478,
#  '거래': 477,
#  '기금': 469,
#  '현재': 469,
#  '이내': 469,
#  '추가': 464,
#  '사건': 463,
#  '체계': 462,
#  '고려': 462,
#  '변경': 461,
#  '결과': 460,
#  '허가': 456,
#  '문화': 455,
#  '예방': 455,
#  '서비스': 454,
#  '시장': 451,
#  '구역': 449,
#  '공공기관': 445,
#  '제외': 444,
#  '자동차': 444,
#  '장애인': 437,
#  '절차': 433,
#  '참고': 430,
#  '검사': 425,
#  '불구': 424,
#  '직무': 422,
#  '지속': 422,
#  '발의': 421,
#  '사실': 413,
#  '수준': 412,
#  '재산': 411,
#  '과정': 410,
#  '계약': 409,
#  '명시': 408,
#  '생활': 406,
#  '지방': 406,
#  '급여': 400,
#  '안정': 399,
#  '기여': 399,
#  '근로': 398,
#  '확인': 397,
#  '복지': 395,
#  '주민': 395,
#  '규제': 395,
#  '유지': 394,
#  '재정': 394,
#  '협력': 390,
#  '보상': 385,
#  '통해': 382,
#  '한편': 380,
#  '활성화': 379,
#  '판매': 378,
#  '사고': 377,
#  '우려': 376,
#  '수정': 375,
#  '영향': 374,
#  '직접': 373,
#  '방법': 372,
#  '심사': 371,
#  '중앙': 368,
#  '효율': 368,
#  '대통령': 368,
#  '진흥': 367,
#  '전제': 366,
#  '비율': 365,
#  '활용': 364,
#  '후보자': 361,
#  '도입': 360,
#  '소속': 359,
#  '대책': 355,
#  '회사': 353,
#  '이유': 352,
#  '예산': 352,
#  '삭제': 351,
#  '의견': 351,
#  '안이': 350,
#  '협의': 350,
#  '요청': 349,
#  '책임': 344,
#  '소비자': 343,
#  '노인': 343,
#  '청년': 342,
#  '처분': 342,
#  '아동': 342,
#  '청소년': 341,
#  '공급': 341,
#  '업자': 340,
#  '학생': 339,
#  '처리': 338,
#  '기본': 337,
#  '권리': 337,
#  '정의': 336,
#  '법적': 336,
#  '구성': 335,
#  '노동': 335,
#  '법인': 334,
#  '요건': 334,
#  '징역': 332,
#  '교통': 332,
#  '설립': 331,
#  '실효': 330,
#  '정비': 330,
#  '법령': 329,
#  '여부': 329,
#  '투자': 329,
#  '한국': 328,
#  '촉진': 325,
#  '이행': 323,
#  '것이므': 323,
#  '세액': 323,
#  '반영': 322,
#  '우리나라': 321,
#  '종합': 321,
#  '기능': 318,
#  '행정기관': 313,
#  '작성': 311,
#  '따라서': 310,
#  '규정': 310,
#  '이후': 309,
#  '공개': 309,
#  '로서': 309,
#  '선거': 308,
#  '민간': 305,
#  '생산': 305,
#  '참여': 300,
#  '침해': 300,
#  '수급': 300,
#  '방송': 299,
#  '특별': 299,
#  '공제': 298,
#  '자의': 294,
#  '특정': 294,
#  '호의': 290,
#  '자격': 290,
#  '연금': 289,
#  '수단': 289,
#  '개인': 288,
#  '도지사': 285,
#  '증진': 285,
#  '토지': 285,
#  '직원': 285,
#  '종사': 284,
#  '청구': 284,
#  '성과': 281,
#  '효과': 281,
#  '건축물': 280,
#  '현실': 280,
#  '납부': 279,
#  '과태료': 278,
#  '행사': 278,
#  '채용': 278,
#  '위탁': 277,
#  '창업': 274,
#  '추천': 274,
#  '자녀': 272,
#  '건설': 272,
#  '임금': 272,
#  '재해': 268,
#  '보고': 268,
#  '인력': 268,
#  '형사': 268,
#  '대학': 265,
#  '규모': 265,
#  '도로': 264,
#  '일정': 264,
#  '벌금': 263,
#  '행정': 262,
#  '국내': 262,
#  '가맹': 262,
#  '벌금형': 261,
#  '분쟁': 260,
#  '취지': 260,
#  '도모': 259,
#  '도록': 258,
#  '명령': 258,
#  '공익': 258,
#  '과세': 256,
#  '어려움': 254,
#  '때문': 254,
#  '조성': 253,
#  '승인': 253,
#  '임명': 253,
#  '가족': 251,
#  '불법': 251,
#  '특례': 250,
#  '연구': 248,
#  '조항': 247,
#  '공사': 246,
#  '보건': 245,
#  '분야': 245,
#  '수입': 245,
#  '임원': 244,
#  '손해': 240,
#  '센터': 240,
#  '우선': 240,
#  '취소': 240,
#  '원칙': 239,
#  '필요성': 236,
#  '감독': 235,
#  '향상': 232,
#  '집단': 232,
#  '표시': 232,
#  '권고': 231,
#  '위험': 231,
#  '일반': 229,
#  '사례': 229,
#  '노력': 228,
#  '각종': 228,
#  '징계': 228,
#  '제품': 228,
#  '동의': 227,
#  '상의': 226,
#  '로부터': 226,
#  '집행': 226,
#  '취득': 225,
#  '관할': 224,
#  '인증': 223,
#  '실질': 221,
#  '영업': 221,
#  '합리': 220,
#  '초과': 219,
#  '이용자': 219,
#  '해소': 219,
#  '자가': 218,
#  '대상자': 218,
#  '공정': 217,
#  '통한': 216,
#  '이익': 216,
#  '해양': 216,
#  '조직': 215,
#  '법원': 214,
#  '제재': 214,
#  '연장': 214,
#  '매년': 213,
#  '권한': 213,
#  '농업': 213,
#  '징수': 212,
#  '국토교통부': 212,
#  '부정': 212,
#  '어린이': 211,
#  '실태': 209,
#  '장기': 209,
#  '완화': 209,
#  '경영': 207,
#  '어업': 206,
#  '상향': 205,
#  '소음': 205,
#  '능력': 204,
#  '인사': 204,
#  '전문': 204,
#  '개월': 203,
#  '부여': 203,
#  '소유자': 203,
#  '국제': 202,
#  '차별': 202,
#  '구매': 201,
#  '구체': 197,
#  '공단': 197,
#  '실제': 196,
#  '농어': 196,
#  '보상금': 195,
#  '여성': 194,
#  '군수': 194,
#  '도시': 194,
#  '현장': 192,
#  '주거': 191,
#  '보건복지부': 191,
#  '이전': 190,
#  '대기업': 190,
#  '기반': 189,
#  '가입': 189,
#  '장치': 189,
#  '정도': 189,
#  '혜택': 189,
#  '시험': 188,
#  '허용': 188,
#  '수사': 188,
#  '상품': 188,
#  '재난': 187,
#  '해결': 186,
#  '광고': 186,
#  '주변': 186,
#  '통상': 186,
#  '임용': 186,
#  '소방': 186,
#  '해외': 186,
#  '적극': 185,
#  '구축': 185,
#  '전체': 185,
#  '소관': 184,
#  '상임': 184,
#  '회복': 183,
#  '각각': 183,
#  '보험료': 182,
#  '기록': 182,
#  '육성': 181,
#  '사용자': 181,
#  '재원': 180,
#  '계속': 180,
#  '자율': 180,
#  '거주': 179,
#  '감소': 179,
#  '대응': 178,
#  '사무': 178,
#  '유공': 177,
#  '휴가': 177,
#  '용어': 177,
#  '장애': 176,
#  '유족': 176,
#  '취업': 176,
#  '유통': 176,
#  '가격': 176,
#  '업체': 175,
#  '정당': 174,
#  '기한': 174,
#  '위임': 174,
#  '과도': 174,
#  '기초': 174,
#  '지위': 174,
#  '운용': 173,
#  '의사': 173,
#  '상태': 172,
#  '인터넷': 172,
#  '모든': 172,
#  '가능성': 171,
#  '통합': 171,
#  '강화': 171,
#  '체결': 169,
#  '질병': 169,
#  '변화': 168,
#  '인권': 168,
#  '식품': 168,
#  '부동산': 167,
#  '별도': 166,
#  '최저임금': 166,
#  '감사': 166,
#  '신체': 165,
#  '우리': 165,
#  '출자': 165,
#  '체육': 165,
#  '방안': 162,
#  '판단': 162,
#  '대행': 162,
#  '주체': 162,
#  '교원': 162,
#  '사법': 161,
#  '기존': 161,
#  '면제': 160,
#  '시간': 160,
#  '방식': 159,
#  '정치': 159,
#  '편의': 159,
#  '반면': 158,
#  '일자리': 158,
#  '선임': 158,
#  '가정': 158,
#  '존재': 158,
#  '사망': 157,
#  '보수': 156,
#  '건축': 156,
#  '배우자': 156,
#  '단지': 156,
#  '산정': 156,
#  '관광': 156,
#  '보조': 155,
#  '시정': 155,
#  '물질': 155,
#  '미만': 155,
#  '보유': 155,
#  '형평성': 155,
#  '분할': 155,
#  '통일': 155,
#  '훈련': 154,
#  '단서': 154,
#  '정신': 154,
#  '의미': 154,
#  '설비': 154,
#  '개별': 153,
#  '한정': 153,
#  '평균': 153,
#  '구제': 153,
#  '구조': 153,
#  '보전': 153,
#  '이바지': 153,
#  '지방의회': 153,
#  '배출': 153,
#  '에너지': 153,
#  '제정': 151,
#  '체납': 150,
#  '시책': 150,
#  '과징금': 150,
#  '차량': 150,
#  '폐지': 150,
#  '임차': 150,
#  '특수': 150,
#  '문화재': 149,
#  '가치': 148,
#  '임대주택': 148,
#  '인구': 147,
#  '원인': 147,
#  '조합': 147,
#  '사전': 146,
#  '청장': 146,
#  '대한민국': 146,
#  '장소': 145,
#  '확정': 145,
#  '선박': 145,
#  '한계': 145,
#  '퇴직': 145,
#  '사업': 145,
#  '복무': 144,
#  '정지': 144,
#  '제대로': 144,
#  '준수': 143,
#  '임대': 143,
#  '국민연금': 142,
#  '현황': 142,
#  '공동': 142,
#  '주의': 142,
#  '제조': 142,
#  '품질': 142,
#  '기부': 142,
#  '발급': 141,
#  '본인': 141,
#  '한도': 141,
#  '운행': 141,
#  '소송': 141,
#  '수익': 141,
#  '농어촌': 141,
#  '거짓': 139,
#  '누구': 139,
#  '자금': 139,
#  '투표': 138,
#  '선고': 138,
#  '헌법': 138,
#  '상호': 138,
#  '국민권익위': 138,
#  '출연': 138,
#  '중심': 137,
#  '특성': 137,
#  '서류': 137,
#  '주요': 137,
#  '고하': 137,
#  '대비': 137,
#  '위원장': 137,
#  '형태': 136,
#  '역할': 136,
#  '성폭력': 136,
#  '관리자': 136,
#  '인식': 135,
#  '경찰': 135,
#  '발행': 135,
#  '출산': 135,
#  '국무총리': 135,
#  '군인': 135,
#  '운전자': 134,
#  '보완': 134,
#  '이로': 134,
#  '가축': 134,
#  '진행': 133,
#  '비밀': 133,
#  '성장': 133,
#  '조건': 133,
#  '주식': 133,
#  '운송': 132,
#  '공직': 132,
#  '당사자': 131,
#  '손해배상': 131,
#  '고용노동부': 131,
#  '다수': 131,
#  '동시': 131,
#  '가구': 131,
#  '편성': 131,
#  '금품': 131,
#  '기회': 130,
#  '보급': 130,
#  '직업': 130,
#  '국회의원': 130,
#  '거부': 130,
#  '대부분': 129,
#  '간의': 129,
#  '달성': 129,
#  '의제': 129,
#  '전부': 128,
#  '교통사고': 128,
#  '여건': 128,
#  '자원': 128,
#  '달리': 128,
#  '소유': 127,
#  '별로': 127,
#  '생명': 127,
#  '예비': 127,
#  '경쟁력': 127,
#  '근무': 126,
#  '자산': 126,
#  '해양수산부': 126,
#  '과학기술': 126,
#  '수요': 126,
#  '보고서': 125,
#  '질서': 125,
#  '모집': 125,
#  '측면': 125,
#  '전문성': 125,
#  '대한': 125,
#  '투명': 124,
#  '통계': 124,
#  '대규모': 124,
#  '보존': 123,
#  '파악': 123,
#  '차원': 123,
#  '수집': 123,
#  '가입자': 123,
#  '연도': 122,
#  '역사': 122,
#  '전환': 122,
#  '지난': 121,
#  '회계': 121,
#  '요금': 121,
#  '환자': 121,
#  '연구개발': 121,
#  '협회': 121,
#  '국세': 121,
#  '기재': 119,
#  '개인정보': 119,
#  '경비': 119,
#  '부칙': 119,
#  '취약': 119,
#  '가중': 119,
#  '매출': 119,
#  '결격': 119,
#  '생계': 119,
#  '통신': 118,
#  '구분': 118,
#  '미세먼지': 118,
#  '이사': 118,
#  '의약품': 118,
#  '택시': 118,
#  '진료': 118,
#  '설정': 118,
#  '보증': 118,
#  '명의': 117,
#  '매우': 117,
#  '공유': 117,
#  '과학기술원': 117,
#  '세계': 117,
#  '규명': 117,
#  '벌칙': 117,
#  '과소': 117,
#  '채권': 117,
#  '어린이집': 116,
#  '시효': 116,
#  '경력': 115,
#  '도서': 115,
#  '전국': 115,
#  '화재': 115,
#  '담보': 115,
#  '외국': 115,
#  '일몰': 115,
#  '무상': 115,
#  '종류': 114,
#  '치료': 114,
#  '자유': 114,
#  '감안': 114,
#  '강제': 114,
#  '별표': 114,
#  '시스템': 113,
#  '종료': 113,
#  '통지': 113,
#  '희생': 113,
#  '구직': 113,
#  '형벌': 113,
#  '자원부': 113,
#  '공간': 112,
#  '재판': 112,
#  '고시': 112,
#  '일본': 112,
#  '정성': 111,
#  '기구': 111,
#  '물품': 111,
#  '용역': 111,
#  '예외': 111,
#  '부모': 111,
#  '통보': 111,
#  '자로': 111,
#  '자등': 111,
#  '분양': 111,
#  '법정형': 111,
#  '변호사': 111,
#  '동안': 110,
#  '담당': 110,
#  '양육': 110,
#  '입법': 110,
#  '선정': 109,
#  '경쟁': 109,
#  '부금': 109,
#  '배분': 109,
#  '용도': 108,
#  '유해': 108,
#  '전력': 108,
#  '계층': 108,
#  '비교': 108,
#  '유아': 108,
#  '교육부': 107,
#  '정거': 107,
#  '자치': 107,
#  '양성': 107,
#  '당시': 107,
#  '세율': 107,
#  '파견': 107,
#  '더욱': 106,
#  '비상': 106,
#  '선택': 106,
#  '상담': 106,
#  '은행': 106,
#  '표현': 105,
#  '출석': 105,
#  '지원이': 105,
#  '주주': 105,
#  '손실': 105,
#  '정함': 104,
#  '운전': 104,
#  '전용': 104,
#  '단계': 104,
#  '지도': 104,
#  '인상': 104,
#  '외국인': 104,
#  '가스': 104,
#  '소득세': 104,
#  '경감': 103,
#  '진단': 103,
#  '확립': 103,
#  '결산': 103,
#  '보조금': 103,
#  '소비': 103,
#  '점검': 102,
#  '대출': 102,
#  '지방세': 102,
#  '업주': 102,
#  '제조업': 102,
#  '이해': 102,
#  '연구원': 102,
#  '살균제': 102,
#  '물의': 101,
#  '임기': 101,
#  '훼손': 101,
#  '수도권': 101,
#  '수산물': 101,
#  '가습기': 101,
#  '농지': 100,
#  '분석': 100,
#  '담배': 100,
#  '정보통': 100,
#  '편차': 100,
#  '동물': 100,
#  '법률': 100,
#  '배제': 99,
#  '공기업': 99,
#  '가장': 99,
#  '불공정': 99,
#  '원자력': 99,
#  '징역형': 99,
#  '원금': 98,
#  '정기': 98,
#  '저해': 98,
#  '논란': 98,
#  '신용카드': 98,
#  '부처': 98,
#  '특별법': 98,
#  '방송통신': 97,
#  '판결': 97,
#  '예정': 97,
#  '문제점': 97,
#  '긴급': 97,
#  '전통': 97,
#  '국유재산': 97,
#  '예규': 97,
#  '불이익': 96,
#  '표준': 96,
#  '수용': 96,
#  '최소': 96,
#  '홍보': 96,
#  '확충': 96,
#  '진상': 96,
#  '국회사무처': 96,
#  '유효': 95,
#  '부문': 95,
#  '국립': 95,
#  '교류': 95,
#  '급식': 95,
#  '서면': 94,
#  '교부': 94,
#  '자체': 94,
#  '증대': 94,
#  '제시': 94,
#  '장려': 94,
#  '도의': 94,
#  '검토': 94,
#  '벤처기업': 94,
#  '가지': 93,
#  '형법': 93,
#  '생태계': 93,
#  '검증': 93,
#  '중앙회': 93,
#  '전자': 92,
#  '이상인': 92,
#  '면허': 92,
#  '초래': 92,
#  '산림': 92,
#  '일시': 91,
#  '세법': 91,
#  '노후': 91,
#  '근로기준법': 91,
#  '가정폭력': 91,
#  '대체': 91,
#  '역시': 91,
#  '납세': 91,
#  '예산안': 91,
#  '최대': 91,
#  '수당': 91,
#  '공인': 90,
#  '양도': 90,
#  '지구': 90,
#  '부분': 90,
#  '비판': 90,
#  '차이': 90,
#  '취급': 90,
#  '단위': 90,
#  '연령': 90,
#  '의료기기': 90,
#  '연구기관': 90,
#  '점포': 90,
#  '이자': 90,
#  '환경부': 90,
#  '명칭': 89,
#  '확산': 89,
#  '연간': 89,
#  '실현': 89,
#  '개설': 89,
#  '명예': 89,
#  '신규': 89,
#  '소요': 88,
#  '농촌': 88,
#  '프로그램': 87,
#  '합의': 87,
#  '지식': 87,
#  '통제': 87,
#  '실적': 87,
#  '유도': 87,
#  '음주운전': 87,
#  '중소': 87,
#  '배상': 87,
#  '육아휴직': 87,
#  '농림축산식품부': 87,
#  '하나': 86,
#  '고자': 86,
#  '중단': 86,
#  '모두': 86,
#  '공원': 86,
#  '경찰관': 85,
#  '민주': 85,
#  '상품권': 85,
#  '보육': 85,
#  '중인': 85,
#  '서도': 85,
#  '안건': 85,
#  '아동학대': 85,
#  '재단': 85,
#  '위촉': 84,
#  '만료': 84,
#  '항만': 84,
#  '최고': 84,
#  '조합원': 84,
#  '재산권': 84,
#  '의료인': 84,
#  '신뢰': 84,
#  '임시': 84,
#  '서민': 84,
#  '특별자치도': 83,
#  '중지': 83,
#  '보호자': 83,
#  '선출': 83,
#  '체육관': 83,
#  '국방부': 83,
#  '저출산': 83,
#  '지니': 83,
#  '폐기물': 82,
#  '복합': 82,
#  '계열': 82,
#  '공공': 82,
#  '지체': 81,
#  '규칙': 81,
#  '자신': 81,
#  '사정': 81,
#  '협조': 81,
#  '차지': 81,
#  '추세': 81,
#  '광부': 81,
#  '국토': 81,
#  '첨부': 80,
#  '시기': 80,
#  '공표': 80,
#  '제명': 80,
#  '국회법': 80,
#  '이동통신': 80,
#  '열람': 79,
#  '위협': 79,
#  '수수료': 79,
#  '취하': 79,
#  '증거': 79,
#  '지주회사': 79,
#  '영상': 79,
#  '국가정보원': 79,
#  '특별검사': 79,
#  '대가': 79,
#  '성범죄': 78,
#  '직장': 78,
#  '농업인': 78,
#  '지자체': 78,
#  '본부': 78,
#  '병원': 77,
#  '제작': 77,
#  '청문': 77,
#  '이외': 77,
#  '회원': 77,
#  '지출': 77,
#  '업종': 77,
#  '요인': 77,
#  '종전': 77,
#  '전담': 77,
#  '증인': 77,
#  '임대차': 77,
#  '하위': 76,
#  '외부': 76,
#  '발표': 76,
#  '권익': 76,
#  '근절': 76,
#  '질환': 76,
#  '억지': 76,
#  '조세': 76,
#  '집중': 76,
#  '허위': 75,
#  '경과': 75,
#  '미래': 75,
#  '위치': 75,
#  '협약': 75,
#  '금고': 75,
#  '전문가': 75,
#  '상대': 75,
#  '격차': 75,
#  '약자': 75,
#  '결함': 75,
#  '축소': 75,
#  '의결권': 75,
#  '대리': 75,
#  '전반': 74,
#  '부상': 74,
#  '자재': 74,
#  '노출': 74,
#  '발견': 74,
#  '온라인': 73,
#  '하나로': 73,
#  '이동': 73,
#  '분류': 73,
#  '안전성': 73,
#  '헌법재판소': 73,
#  '혼인': 73,
#  '학력': 73,
#  '독립': 73,
#  '세입': 73,
#  ...}

# %%
# 새누리당 20
wordcloud(SN)
# Out:
# {'관리': 538,
#  '지원': 448,
#  '시설': 438,
#  '지역': 413,
#  '위원회': 363,
#  '관련': 333,
#  '기관': 326,
#  '운영': 291,
#  '국가': 290,
#  '국민': 288,
#  '발생': 286,
#  '지방자치단체': 282,
#  '교육': 276,
#  '계획': 274,
#  '안전': 274,
#  '장관': 273,
#  '행위': 272,
#  '산업': 270,
#  '해당': 269,
#  '시행': 259,
#  '보호': 254,
#  '업무': 246,
#  '사항': 241,
#  '설치': 228,
#  '항제': 224,
#  '지정': 222,
#  '대하': 220,
#  '기준': 212,
#  '이상': 212,
#  '마련': 212,
#  '기업': 201,
#  '개발': 201,
#  '의무': 200,
#  '근거': 199,
#  '이하': 194,
#  '보험': 194,
#  '위해': 192,
#  '적용': 185,
#  '신설': 184,
#  '서비스': 182,
#  '부과': 180,
#  '사용': 180,
#  '대상': 179,
#  '의결': 176,
#  '위반': 175,
#  '개정': 173,
#  '실정': 173,
#  '수립': 171,
#  '대해': 171,
#  '조사': 170,
#  '정보': 168,
#  '조정': 164,
#  '제도': 164,
#  '정책': 164,
#  '범죄': 164,
#  '기간': 163,
#  '일부': 160,
#  '사회': 160,
#  '수행': 156,
#  '부담': 156,
#  '거나': 151,
#  '노인': 150,
#  '사업자': 149,
#  '진흥': 147,
#  '목적': 146,
#  '신고': 146,
#  '공무원': 145,
#  '주택': 145,
#  '실시': 144,
#  '이용': 143,
#  '고용': 143,
#  '기술': 142,
#  '피해': 140,
#  '구역': 139,
#  '제출': 137,
#  '제공': 137,
#  '등록': 136,
#  '변경': 136,
#  '처벌': 134,
#  '상황': 132,
#  '개선': 131,
#  '과태료': 131,
#  '확보': 129,
#  '평가': 128,
#  '현행': 128,
#  '포함': 128,
#  '심의': 128,
#  '비용': 127,
#  '시장': 127,
#  '정부': 124,
#  '발전': 122,
#  '투자': 122,
#  '제한': 120,
#  '지급': 120,
#  '자동차': 120,
#  '문화': 118,
#  '환경': 118,
#  '추진': 117,
#  '주민': 117,
#  '현행법': 117,
#  '체계': 115,
#  '지방': 115,
#  '필요': 115,
#  '금지': 115,
#  '범위': 114,
#  '재산': 113,
#  '활동': 110,
#  '의료': 110,
#  '규제': 110,
#  '대통령령': 109,
#  '사람': 109,
#  '방지': 108,
#  '절차': 108,
#  '정비': 107,
#  '설립': 107,
#  '한국': 107,
#  '중앙': 105,
#  '최근': 105,
#  '거래': 105,
#  '관계': 103,
#  '경제': 103,
#  '공유': 103,
#  '결정': 100,
#  '문제': 99,
#  '예방': 99,
#  '의원': 98,
#  '자료': 98,
#  '조치': 98,
#  '효율': 97,
#  '협력': 97,
#  '학교': 96,
#  '촉진': 96,
#  '국제': 95,
#  '확대': 94,
#  '복지': 94,
#  '제외': 93,
#  '활성화': 93,
#  '결과': 90,
#  '법인': 90,
#  '업자': 90,
#  '위탁': 90,
#  '인증': 90,
#  '우려': 89,
#  '허가': 88,
#  '재정': 88,
#  '또한': 88,
#  '이내': 88,
#  '청년': 88,
#  '소득': 87,
#  '불구': 87,
#  '점검': 87,
#  '사유': 87,
#  '생활': 87,
#  '단체': 86,
#  '기금': 86,
#  '부동산': 85,
#  '현재': 85,
#  '다른': 84,
#  '인정': 84,
#  '장애인': 84,
#  '방법': 83,
#  '기본': 83,
#  '급여': 83,
#  '대표': 81,
#  '신청': 80,
#  '행정기관': 79,
#  '대책': 79,
#  '내용': 78,
#  '사고': 77,
#  '센터': 77,
#  '심사': 76,
#  '수면': 75,
#  '삭제': 75,
#  '인력': 75,
#  '추가': 75,
#  '자격': 74,
#  '선거': 74,
#  '폐지': 74,
#  '납부': 74,
#  '증가': 73,
#  '따라서': 73,
#  '공공기관': 73,
#  '정의': 72,
#  '안정': 72,
#  '종사': 72,
#  '아동': 71,
#  '요구': 71,
#  '국내': 71,
#  '협의': 70,
#  '육성': 70,
#  '인터넷': 70,
#  '건강': 69,
#  '활용': 69,
#  '승인': 69,
#  '공익': 69,
#  '종합': 68,
#  '도지사': 68,
#  '근로자': 68,
#  '공급': 68,
#  '금액': 68,
#  '기여': 67,
#  '번호': 67,
#  '지속': 67,
#  '제정': 66,
#  '스포츠': 66,
#  '통해': 66,
#  '소속': 66,
#  '재해': 66,
#  '의안': 65,
#  '요건': 65,
#  '검사': 65,
#  '금융': 65,
#  '자원': 64,
#  '한편': 64,
#  '회사': 64,
#  '확인': 64,
#  '외국인': 64,
#  '특별': 64,
#  '작성': 63,
#  '고려': 63,
#  '우리나라': 63,
#  '수급': 63,
#  '범죄예방': 63,
#  '발의': 62,
#  '회의': 62,
#  '조성': 62,
#  '지구': 62,
#  '처리': 62,
#  '토지': 61,
#  '중소기업': 61,
#  '참여': 61,
#  '물의': 61,
#  '규정': 61,
#  '증진': 60,
#  '징수': 60,
#  '법적': 60,
#  '혼란': 60,
#  '도모': 60,
#  '책임': 60,
#  '민간': 60,
#  '부정': 60,
#  '보험료': 59,
#  '학생': 59,
#  '국회의원': 59,
#  '건설': 59,
#  '시험': 59,
#  '법령': 59,
#  '참고': 58,
#  '유지': 58,
#  '명시': 58,
#  '규모': 58,
#  '전문': 58,
#  '원칙': 58,
#  '보장': 57,
#  '것이므': 57,
#  '사실': 57,
#  '강화': 57,
#  '호의': 57,
#  '이행': 57,
#  '전제': 56,
#  '수정': 56,
#  '상태': 56,
#  '보건복지부': 56,
#  '행사': 56,
#  '훈련': 56,
#  '실효': 55,
#  '예산': 55,
#  '일정': 55,
#  '직접': 55,
#  '장치': 55,
#  '일반': 55,
#  '자의': 55,
#  '권리': 55,
#  '판매': 55,
#  '창업': 55,
#  '임대': 55,
#  '안이': 54,
#  '대학': 54,
#  '국토교통부': 54,
#  '요청': 54,
#  '자유': 54,
#  '영향': 54,
#  '개인': 54,
#  '장기': 54,
#  '자율': 53,
#  '운송': 53,
#  '계약': 53,
#  '벌금': 53,
#  '직무': 53,
#  '집행': 53,
#  '사건': 52,
#  '조항': 52,
#  '참전': 52,
#  '조직': 52,
#  '연구개발': 52,
#  '취소': 52,
#  '통한': 52,
#  '관광': 52,
#  '도시': 51,
#  '매년': 51,
#  '질서': 51,
#  '감독': 51,
#  '유공': 51,
#  '반영': 51,
#  '제기': 51,
#  '의견': 50,
#  '공동체': 50,
#  '피해자': 50,
#  '위원': 50,
#  '경찰': 50,
#  '면제': 50,
#  '소음': 50,
#  '구성': 49,
#  '수준': 49,
#  '농어촌': 49,
#  '특정': 49,
#  '보상': 49,
#  '위험': 49,
#  '소비자': 49,
#  '실태': 49,
#  '차량': 49,
#  '각종': 48,
#  '구축': 48,
#  '행정': 48,
#  '산학': 48,
#  '상담': 48,
#  '명령': 48,
#  '이익': 48,
#  '재난': 48,
#  '전체': 47,
#  '운용': 47,
#  '필요성': 47,
#  '기초': 47,
#  '국회': 47,
#  '징역': 47,
#  '제품': 47,
#  '근로': 47,
#  '교육부': 47,
#  '통합': 46,
#  '관할': 46,
#  '도입': 46,
#  '어려움': 46,
#  '재원': 46,
#  '가입': 46,
#  '허용': 46,
#  '단지': 46,
#  '보조': 45,
#  '기능': 45,
#  '특례': 45,
#  '청구': 45,
#  '부여': 45,
#  '성능': 45,
#  '공사': 45,
#  '공개': 45,
#  '군사': 45,
#  '연금': 45,
#  '과학기술': 45,
#  '향상': 44,
#  '과정': 44,
#  '보고': 44,
#  '기부': 44,
#  '과세': 44,
#  '수입': 44,
#  '거주': 44,
#  '도록': 43,
#  '소유자': 43,
#  '침해': 43,
#  '소유': 43,
#  '직원': 43,
#  '자금': 43,
#  '로서': 43,
#  '원전': 43,
#  '건축': 43,
#  '군수': 43,
#  '해체': 43,
#  '소득세': 43,
#  '입양': 43,
#  '연구': 42,
#  '이후': 42,
#  '공단': 42,
#  '자가': 42,
#  '상의': 42,
#  '기존': 42,
#  '외국': 42,
#  '이용자': 42,
#  '약관': 42,
#  '우리': 41,
#  '지적': 41,
#  '완화': 41,
#  '공동': 41,
#  '건축물': 41,
#  '거래소': 41,
#  '거짓': 40,
#  '선정': 40,
#  '여부': 40,
#  '이유': 40,
#  '국세': 40,
#  '이전': 40,
#  '기밀': 40,
#  '특수': 39,
#  '능력': 39,
#  '분야': 39,
#  '퇴직': 39,
#  '경력': 39,
#  '취업': 39,
#  '사법': 39,
#  '청소년': 39,
#  '금품': 39,
#  '비율': 39,
#  '인구': 39,
#  '조합': 38,
#  '단서': 38,
#  '사례': 38,
#  '매립': 38,
#  '환자': 38,
#  '취지': 38,
#  '대회': 38,
#  '어업': 37,
#  '체육': 37,
#  '품질': 37,
#  '제조': 37,
#  '여건': 37,
#  '납세': 37,
#  '형태': 37,
#  '처분': 36,
#  '효과': 36,
#  '근무': 36,
#  '취득': 36,
#  '출연': 36,
#  '가족': 36,
#  '로부터': 36,
#  '과징금': 36,
#  '시책': 36,
#  '방식': 36,
#  '동안': 35,
#  '실질': 35,
#  '동시': 35,
#  '대한민국': 35,
#  '업체': 35,
#  '징계': 35,
#  '지방세': 35,
#  '종류': 35,
#  '주체': 35,
#  '주식': 35,
#  '전부': 34,
#  '표시': 34,
#  '성과': 34,
#  '특별법': 34,
#  '우선': 34,
#  '감소': 34,
#  '수익': 34,
#  '위원장': 34,
#  '교부': 34,
#  '보수': 34,
#  '지진': 34,
#  '아동학대': 34,
#  '어린이집': 34,
#  '중심': 34,
#  '매매': 34,
#  '주요': 34,
#  '장비': 34,
#  '보유': 34,
#  '영업': 34,
#  '생산': 33,
#  '동의': 33,
#  '지원이': 33,
#  '신체': 33,
#  '진료': 33,
#  '조달': 33,
#  '대상자': 33,
#  '각각': 33,
#  '개인정보': 33,
#  '물질': 33,
#  '설비': 32,
#  '농업': 32,
#  '연장': 32,
#  '세법': 32,
#  '부처': 32,
#  '전자': 32,
#  '편의': 32,
#  '북한': 32,
#  '임대주택': 32,
#  '건물': 32,
#  '전담': 32,
#  '항노화': 32,
#  '청장': 31,
#  '한계': 31,
#  '권익': 31,
#  '도로': 31,
#  '증대': 31,
#  '해산': 31,
#  '치료': 31,
#  '대응': 31,
#  '보증': 31,
#  '분양': 31,
#  '평생교육': 31,
#  '연도': 30,
#  '체결': 30,
#  '권한': 30,
#  '벌칙': 30,
#  '사무': 30,
#  '교통': 30,
#  '감사': 30,
#  '한정': 30,
#  '신탁': 30,
#  '과도': 30,
#  '누설': 30,
#  '소환투표': 30,
#  '정지': 30,
#  '항공기': 30,
#  '현장': 30,
#  '상향': 30,
#  '감시': 30,
#  '불법': 30,
#  '방송': 30,
#  '긴급': 30,
#  '도제': 30,
#  '담배': 30,
#  '이바지': 29,
#  '공인': 29,
#  '계속': 29,
#  '전국': 29,
#  '거부': 29,
#  '확정': 29,
#  '교통사고': 29,
#  '추세': 29,
#  '보안': 29,
#  '허위': 29,
#  '실업': 29,
#  '재활용': 29,
#  '분쟁': 29,
#  '결격': 29,
#  '보조금': 29,
#  '부칙': 28,
#  '실제': 28,
#  '광고': 28,
#  '서류': 28,
#  '직업': 28,
#  '회복': 28,
#  '적극': 28,
#  '지위': 28,
#  '정당': 28,
#  '일본': 28,
#  '노력': 28,
#  '선고': 28,
#  '구직': 28,
#  '위임': 28,
#  '모집': 28,
#  '해외': 28,
#  '인성': 28,
#  '프로그램': 28,
#  '일자리': 28,
#  '군인': 27,
#  '교육감': 27,
#  '경쟁력': 27,
#  '수요': 27,
#  '전용': 27,
#  '혜택': 27,
#  '차별': 27,
#  '해소': 27,
#  '탄소': 27,
#  '몰수': 27,
#  '채용': 27,
#  '구조': 27,
#  '합산': 27,
#  '회원': 27,
#  '소방': 27,
#  '선출': 26,
#  '특성': 26,
#  '달리': 26,
#  '저작권': 26,
#  '별표': 26,
#  '최소': 26,
#  '반납': 26,
#  '자등': 26,
#  '측면': 26,
#  '해결': 26,
#  '입법': 26,
#  '채권': 26,
#  '개혁': 26,
#  '보존': 26,
#  '실적': 26,
#  '인사': 26,
#  '은행': 26,
#  '선택': 26,
#  '복무': 26,
#  '교원': 26,
#  '이동통신': 26,
#  '유교': 26,
#  '공자': 25,
#  '하나': 25,
#  '초래': 25,
#  '임명': 25,
#  '구체': 25,
#  '생명': 25,
#  '현황': 25,
#  '가능성': 25,
#  '임원': 25,
#  '공정': 25,
#  '기구': 25,
#  '고하': 25,
#  '가중': 25,
#  '별도': 25,
#  '개월': 25,
#  '종료': 25,
#  '현실': 25,
#  '헌법': 25,
#  '운전자': 25,
#  '통계': 25,
#  '시스템': 25,
#  '기한': 25,
#  '임차': 25,
#  '재산세': 25,
#  '체육관': 25,
#  '광부': 25,
#  '결핵': 25,
#  '과세표준': 25,
#  '헌법재판소': 25,
#  '자산': 24,
#  '대통령': 24,
#  '보건': 24,
#  '수사': 24,
#  '손해배상': 24,
#  '담당': 24,
#  '단위': 24,
#  '때문': 24,
#  '정성': 24,
#  '회계': 24,
#  '구분': 24,
#  '성장': 24,
#  '자로': 24,
#  '법인세': 24,
#  '유출': 24,
#  '차원': 24,
#  '단절': 24,
#  '변호사': 24,
#  '주변': 24,
#  '통보': 24,
#  '한도': 24,
#  '주차': 24,
#  '하자': 24,
#  '발행': 24,
#  '유해': 24,
#  '택시': 24,
#  '보육': 24,
#  '레저': 24,
#  '신용카드': 24,
#  '지주회사': 24,
#  '재단': 23,
#  '주거': 23,
#  '간의': 23,
#  '판단': 23,
#  '재직': 23,
#  '명칭': 23,
#  '우수': 23,
#  '선박': 23,
#  '별로': 23,
#  '형평성': 23,
#  '승객': 23,
#  '사전': 23,
#  '본인': 23,
#  '소관': 23,
#  '공직자': 23,
#  '추징': 23,
#  '파산': 23,
#  '여성': 23,
#  '식품': 23,
#  '사망': 23,
#  '제조업': 23,
#  '취득세': 23,
#  '대비': 23,
#  '수집': 23,
#  '음주운전': 23,
#  '향토': 23,
#  '경영': 22,
#  '인식': 22,
#  '개별': 22,
#  '중복': 22,
#  '형법': 22,
#  '의사': 22,
#  '합리': 22,
#  '정신': 22,
#  '공간': 22,
#  '기반시설': 22,
#  '공제': 22,
#  '용지': 22,
#  '정기': 22,
#  '방안': 22,
#  '의제': 22,
#  '제재': 22,
#  '환경부': 22,
#  '방해': 22,
#  '전통': 22,
#  '노인학': 22,
#  '재외국민': 22,
#  '체류': 22,
#  '단말': 22,
#  '독도': 22,
#  '매우': 21,
#  '통일': 21,
#  '가스': 21,
#  '변화': 21,
#  '전환': 21,
#  '시정': 21,
#  '자치': 21,
#  '유도': 21,
#  '대피': 21,
#  '용도': 21,
#  '외부': 21,
#  '책무': 21,
#  '학대': 21,
#  '조례': 20,
#  '협약': 20,
#  '연령': 20,
#  '경쟁': 20,
#  '역시': 20,
#  '유통': 20,
#  '지난': 20,
#  '상호': 20,
#  '보고서': 20,
#  '예외': 20,
#  '당사자': 20,
#  '국무총리': 20,
#  '고령': 20,
#  '항공': 20,
#  '위협': 20,
#  '가격': 20,
#  '장소': 20,
#  '산정': 20,
#  '권고': 20,
#  '법원': 20,
#  '기사': 20,
#  '이해': 20,
#  '여가': 20,
#  '관리자': 20,
#  '고시': 20,
#  '제대로': 20,
#  '대규모': 20,
#  '불합리': 20,
#  '양성': 20,
#  '구제': 20,
#  '방사성폐기물': 20,
#  '중앙회': 20,
#  '학교법인': 20,
#  '고엽제': 20,
#  '사업': 20,
#  '울릉도': 20,
#  '부족': 19,
#  '준용': 19,
#  '경제활동': 19,
#  '기기': 19,
#  '파악': 19,
#  '출자': 19,
#  '구조조정': 19,
#  '감사원': 19,
#  '모든': 19,
#  '결산': 19,
#  '지방의회': 19,
#  '이탈': 19,
#  '임기': 19,
#  '고자': 19,
#  '기록': 19,
#  '수가': 19,
#  '수용': 19,
#  '수수': 19,
#  '가액': 19,
#  '체납': 19,
#  '시간': 19,
#  '부금': 19,
#  '입금': 19,
#  '미비': 19,
#  '복합': 19,
#  '신뢰': 19,
#  '상환': 19,
#  '사격장': 19,
#  '배출': 19,
#  '어린이': 19,
#  '교직원': 19,
#  '행정자치부': 19,
#  '연료': 19,
#  '자원봉사': 19,
#  '대한': 19,
#  '특별회계': 18,
#  '정도': 18,
#  '지역구': 18,
#  '후보자': 18,
#  '제법': 18,
#  '물류': 18,
#  '홍보': 18,
#  '제작': 18,
#  '서도': 18,
#  '조건': 18,
#  '경과': 18,
#  '효력': 18,
#  '이상인': 18,
#  '수당': 18,
#  '전문가': 18,
#  '통상': 18,
#  '당시': 18,
#  '소규모': 18,
#  '안전성': 18,
#  '분석': 18,
#  '손실': 18,
#  '정거': 18,
#  '상한': 18,
#  '해제': 18,
#  '중단': 18,
#  '지자체': 18,
#  '역할': 18,
#  '경로당': 18,
#  '구매': 18,
#  '해양': 18,
#  '윤리': 18,
#  '중재': 18,
#  '통장': 18,
#  '이장': 18,
#  '정보보호': 18,
#  '사이버': 18,
#  '정법': 17,
#  '기반': 17,
#  '해양수산부': 17,
#  '시기': 17,
#  '문제점': 17,
#  '정보통신망': 17,
#  '성립': 17,
#  '재판': 17,
#  '원인': 17,
#  '일몰': 17,
#  '달성': 17,
#  '마약': 17,
#  '표현': 17,
#  '공표': 17,
#  '대표자': 17,
#  '비밀': 17,
#  '미만': 17,
#  '다음': 17,
#  '수단': 17,
#  '민원': 17,
#  '이로': 17,
#  '물품': 17,
#  '대행': 17,
#  '방송통신': 17,
#  '확충': 17,
#  '초과': 17,
#  '식별': 17,
#  '정보통': 17,
#  '운전': 17,
#  '관서': 17,
#  '입찰': 17,
#  '경비': 17,
#  '개최': 17,
#  '예술인': 17,
#  '소유권': 17,
#  '의장': 17,
#  '산림': 17,
#  '빈집': 17,
#  '공직': 17,
#  '법무부': 17,
#  '동계올림픽': 17,
#  '응시': 17,
#  '방범': 17,
#  '개편': 16,
#  '정치': 16,
#  '중개': 16,
#  '부분': 16,
#  '운동': 16,
#  '장려': 16,
#  '손해': 16,
#  '소송': 16,
#  '방향': 16,
#  '표준': 16,
#  '중인': 16,
#  '폭행': 16,
#  '원자력': 16,
#  '감안': 16,
#  '미래창조과학부': 16,
#  '무상': 16,
#  '청탁': 16,
#  '단계': 16,
#  '추천': 16,
#  '수선': 16,
#  '서면': 16,
#  '협조': 16,
#  '상금': 16,
#  '수도권': 16,
#  '생계': 16,
#  '조합원': 16,
#  '기타': 16,
#  '특허': 16,
#  '신용': 16,
#  '매입': 16,
#  '집합': 16,
#  '시조': 16,
#  '화재': 16,
#  '소프트웨어': 16,
#  '적재': 16,
#  '탐정': 16,
#  '한자어': 16,
#  '핵심': 15,
#  '조성하': 15,
#  '자체': 15,
#  '대부분': 15,
#  '위생': 15,
#  '저해': 15,
#  '선임': 15,
#  '지도': 15,
#  '집단': 15,
#  '즉시': 15,
#  '기록물': 15,
#  '다만': 15,
#  '융자': 15,
#  '더욱': 15,
#  '열람': 15,
#  '투명': 15,
#  '소요': 15,
#  '지출': 15,
#  '여러': 15,
#  '불법행위': 15,
#  '근절': 15,
#  '대가': 15,
#  '국민연금': 15,
#  '원금': 15,
#  '소멸': 15,
#  '부합': 15,
#  '시효': 15,
#  '연구원': 15,
#  '금전': 15,
#  '담보': 15,
#  '요금': 15,
#  '재산권': 15,
#  '혁신': 15,
#  '자녀': 15,
#  '준수': 15,
#  '주주': 15,
#  '전문성': 15,
#  '의약품': 15,
#  '보급': 15,
#  '통신': 15,
#  '유치': 15,
#  '거리': 15,
#  '기회': 15,
#  '비중': 15,
#  '세계': 15,
#  '국가경쟁력': 15,
#  '사후': 15,
#  '취급': 15,
#  '원자력발전': 15,
#  '보상금': 15,
#  '유지관리': 15,
#  '등기': 15,
#  '주인': 15,
#  '해저': 15,
#  '인접': 15,
#  '기상': 15,
#  '산재': 14,
#  '크게': 14,
#  '촉진법': 14,
#  '군사시설': 14,
#  '성폭력': 14,
#  '연구기관': 14,
#  '정상': 14,
#  '보완': 14,
#  '소환': 14,
#  '가운데': 14,
#  '유효': 14,
#  '준비': 14,
#  '운행': 14,
#  '원자력발전소': 14,
#  '발급': 14,
#  '세액': 14,
#  '기계': 14,
#  '위기': 14,
#  '법정형': 14,
#  '충당': 14,
#  '연간': 14,
#  '채권자': 14,
#  '보도': 14,
#  '불공정': 14,
#  '고용노동부': 14,
#  '명의': 14,
#  '대지': 14,
#  '교육과정': 14,
#  '노후': 14,
#  '교사': 14,
#  '상가': 14,
#  '기대': 14,
#  '등급': 14,
#  '자기': 14,
#  '장애': 14,
#  '심리': 14,
#  '장기간': 14,
#  '영위': 14,
#  '행위자': 14,
#  '호기': 14,
#  '업주': 14,
#  '복권': 14,
#  '안보': 14,
#  '단속': 14,
#  '실무': 14,
#  '매각': 14,
#  ...}

# %%
# 더불어민주당 21
wordcloud(DM_)
# Out:
# {'지원': 883,
#  '지역': 828,
#  '국가': 736,
#  '위원회': 632,
#  '관리': 601,
#  '발생': 548,
#  '관련': 542,
#  '보호': 531,
#  '사항': 523,
#  '사회': 523,
#  '지방자치단체': 515,
#  '해당': 513,
#  '운영': 510,
#  '시설': 508,
#  '국민': 504,
#  '기관': 496,
#  '의무': 481,
#  '마련': 473,
#  '제도': 467,
#  '의결': 459,
#  '산업': 446,
#  '행위': 437,
#  '근거': 434,
#  '대상': 429,
#  '기업': 416,
#  '장관': 409,
#  '계획': 393,
#  '의료': 382,
#  '이상': 377,
#  '대하': 375,
#  '교육': 375,
#  '조정': 374,
#  '기간': 365,
#  '기준': 362,
#  '설치': 357,
#  '상황': 348,
#  '업무': 346,
#  '시행': 341,
#  '항제': 341,
#  '신설': 341,
#  '지정': 338,
#  '주택': 338,
#  '사용': 337,
#  '안전': 333,
#  '일부': 330,
#  '현행법': 328,
#  '정보': 321,
#  '위해': 319,
#  '지급': 312,
#  '근로자': 308,
#  '이하': 304,
#  '거나': 302,
#  '발전': 298,
#  '부담': 295,
#  '개정': 293,
#  '피해': 292,
#  '사업자': 291,
#  '조사': 289,
#  '정책': 288,
#  '적용': 278,
#  '기술': 272,
#  '제공': 270,
#  '대해': 269,
#  '포함': 267,
#  '정부': 266,
#  '경제': 264,
#  '지적': 263,
#  '신고': 260,
#  '수립': 255,
#  '이용': 254,
#  '또한': 254,
#  '아동': 246,
#  '범위': 245,
#  '활동': 245,
#  '최근': 242,
#  '수행': 238,
#  '위반': 238,
#  '현행': 234,
#  '보장': 234,
#  '개발': 233,
#  '문제': 233,
#  '조치': 231,
#  '필요': 227,
#  '제기': 226,
#  '지방': 226,
#  '사람': 225,
#  '추진': 221,
#  '목적': 219,
#  '심의': 217,
#  '부과': 215,
#  '추가': 212,
#  '서비스': 211,
#  '제한': 210,
#  '비용': 209,
#  '실정': 207,
#  '확보': 205,
#  '기금': 204,
#  '범죄': 204,
#  '신청': 204,
#  '번호': 204,
#  '대표': 202,
#  '관계': 201,
#  '거래': 201,
#  '확대': 201,
#  '제출': 201,
#  '의안': 201,
#  '통해': 200,
#  '명시': 200,
#  '금지': 199,
#  '피해자': 198,
#  '단체': 197,
#  '생활': 197,
#  '의원': 197,
#  '중소기업': 196,
#  '개선': 196,
#  '학교': 195,
#  '투자': 195,
#  '사유': 194,
#  '실시': 193,
#  '보험': 193,
#  '금액': 191,
#  '체계': 190,
#  '인구': 190,
#  '안정': 189,
#  '구역': 189,
#  '공무원': 189,
#  '활성화': 189,
#  '인정': 187,
#  '고용': 186,
#  '지속': 182,
#  '주민': 181,
#  '방지': 181,
#  '장애인': 181,
#  '재정': 179,
#  '사건': 179,
#  '계약': 179,
#  '시장': 176,
#  '의견': 173,
#  '결과': 173,
#  '법인': 173,
#  '대응': 173,
#  '환경': 172,
#  '절차': 171,
#  '대통령령': 169,
#  '촉진': 167,
#  '회의': 164,
#  '건강': 164,
#  '참고': 162,
#  '급여': 161,
#  '협력': 158,
#  '요구': 158,
#  '예방': 156,
#  '참여': 156,
#  '위기': 156,
#  '이내': 154,
#  '활용': 153,
#  '체육': 153,
#  '소득': 153,
#  '내용': 152,
#  '한편': 152,
#  '수급': 151,
#  '문화': 150,
#  '처리': 150,
#  '심사': 149,
#  '법적': 149,
#  '발의': 149,
#  '결정': 148,
#  '삭제': 148,
#  '중소': 148,
#  '등록': 147,
#  '재산': 147,
#  '고려': 147,
#  '전제': 147,
#  '특례': 146,
#  '수정': 146,
#  '처벌': 145,
#  '창업': 145,
#  '협의': 145,
#  '설립': 144,
#  '근로': 144,
#  '국내': 143,
#  '벤처기업': 142,
#  '평가': 142,
#  '현재': 141,
#  '안이': 141,
#  '기여': 140,
#  '우려': 140,
#  '변경': 139,
#  '업자': 138,
#  '행정': 137,
#  '사실': 137,
#  '자료': 137,
#  '유지': 137,
#  '호의': 136,
#  '확인': 136,
#  '공공기관': 136,
#  '불구': 135,
#  '어린이': 135,
#  '복지': 135,
#  '허가': 133,
#  '금융': 133,
#  '국회': 132,
#  '청구': 132,
#  '코로나': 132,
#  '다른': 131,
#  '제외': 131,
#  '효율': 131,
#  '공개': 131,
#  '학생': 131,
#  '권리': 130,
#  '요청': 129,
#  '요건': 129,
#  '기본': 128,
#  '실효': 125,
#  '도입': 125,
#  '수준': 125,
#  '책임': 124,
#  '특별': 124,
#  '청년': 123,
#  '부여': 122,
#  '효과': 122,
#  '것이므': 122,
#  '예산': 121,
#  '민간': 121,
#  '제품': 121,
#  '과세': 121,
#  '반영': 120,
#  '에너지': 119,
#  '이후': 119,
#  '방법': 118,
#  '납부': 118,
#  '처분': 118,
#  '이행': 117,
#  '직접': 117,
#  '명령': 116,
#  '도시': 116,
#  '의약품': 116,
#  '진흥': 115,
#  '이유': 115,
#  '자격': 114,
#  '증진': 114,
#  '개인': 114,
#  '장기': 113,
#  '선거': 113,
#  '보건': 113,
#  '감염병': 113,
#  '검사': 112,
#  '제재': 111,
#  '조성': 111,
#  '재난': 111,
#  '공급': 111,
#  '정의': 110,
#  '시스템': 110,
#  '위원': 110,
#  '연금': 109,
#  '아동학대': 108,
#  '한국': 107,
#  '대학': 107,
#  '감소': 107,
#  '판매': 107,
#  '영업': 106,
#  '종사': 106,
#  '법령': 105,
#  '정비': 105,
#  '생산': 105,
#  '회사': 105,
#  '여부': 105,
#  '소속': 105,
#  '공익': 105,
#  '일정': 104,
#  '영향': 104,
#  '정지': 104,
#  '사고': 103,
#  '우리나라': 103,
#  '교통': 103,
#  '구성': 103,
#  '비율': 102,
#  '경찰': 102,
#  '인력': 102,
#  '증가': 101,
#  '연구': 100,
#  '과정': 100,
#  '인권': 99,
#  '도모': 99,
#  '가맹': 99,
#  '원칙': 99,
#  '우선': 99,
#  '중앙': 98,
#  '의사': 98,
#  '자동차': 98,
#  '상향': 97,
#  '구축': 97,
#  '관할': 97,
#  '조직': 97,
#  '인증': 97,
#  '채용': 96,
#  '실태': 96,
#  '징역': 95,
#  '후보자': 95,
#  '대책': 95,
#  '과징금': 95,
#  '기초': 95,
#  '감독': 94,
#  '보상': 94,
#  '성과': 93,
#  '부동산': 93,
#  '기반': 92,
#  '특정': 92,
#  '주거': 92,
#  '보건복지부': 92,
#  '남북': 92,
#  '사망': 91,
#  '임차': 91,
#  '벌금': 90,
#  '침해': 90,
#  '로서': 90,
#  '종합': 90,
#  '도지사': 90,
#  '따라서': 89,
#  '투표': 89,
#  '기능': 89,
#  '자치': 89,
#  '자금': 88,
#  '분야': 88,
#  '기한': 88,
#  '규제': 88,
#  '징계': 88,
#  '통합': 88,
#  '성폭력': 88,
#  '분쟁': 87,
#  '소비자': 87,
#  '작성': 87,
#  '가입': 87,
#  '위탁': 86,
#  '어려움': 86,
#  '세율': 86,
#  '적극': 86,
#  '필요성': 85,
#  '운용': 85,
#  '비대': 85,
#  '수단': 84,
#  '사무': 84,
#  '유통': 83,
#  '국회의원': 83,
#  '위험': 83,
#  '실질': 83,
#  '규모': 83,
#  '실제': 82,
#  '대상자': 82,
#  '선정': 82,
#  '행사': 82,
#  '임대': 82,
#  '육성': 82,
#  '보고': 81,
#  '행정기관': 81,
#  '노력': 81,
#  '물품': 81,
#  '향상': 81,
#  '가족': 81,
#  '법원': 81,
#  '수입': 81,
#  '공사': 81,
#  '부정': 80,
#  '방송': 80,
#  '센터': 80,
#  '청소년': 80,
#  '전문': 79,
#  '균형발전': 79,
#  '과태료': 79,
#  '세액': 79,
#  '노인': 79,
#  '보험료': 79,
#  '사례': 78,
#  '임금': 78,
#  '허용': 78,
#  '이전': 78,
#  '재원': 77,
#  '현장': 77,
#  '해소': 77,
#  '가격': 77,
#  '사법': 77,
#  '건설': 76,
#  '환자': 76,
#  '완화': 76,
#  '강화': 75,
#  '소송': 75,
#  '가정': 75,
#  '복귀': 75,
#  '취지': 74,
#  '단지': 74,
#  '산정': 74,
#  '해외': 73,
#  '제정': 72,
#  '미만': 72,
#  '조건': 72,
#  '보유': 72,
#  '형태': 72,
#  '지구': 72,
#  '연장': 72,
#  '취소': 72,
#  '사용자': 71,
#  '조항': 71,
#  '청원': 71,
#  '공제': 70,
#  '표시': 70,
#  '농어': 70,
#  '규정': 70,
#  '자가': 69,
#  '광고': 69,
#  '매년': 69,
#  '도록': 69,
#  '취업': 69,
#  '노동': 69,
#  '개월': 68,
#  '취득': 68,
#  '치료': 68,
#  '초과': 68,
#  '대출': 68,
#  '상의': 68,
#  '계속': 68,
#  '간이': 68,
#  '구조': 67,
#  '시책': 67,
#  '공동': 67,
#  '체결': 67,
#  '여건': 67,
#  '양도': 67,
#  '보완': 66,
#  '혁신': 66,
#  '전환': 66,
#  '퇴직': 66,
#  '수도권': 66,
#  '가입자': 66,
#  '대규모': 65,
#  '국제': 65,
#  '구체': 64,
#  '국토교통부': 64,
#  '정치': 64,
#  '방식': 64,
#  '인재': 64,
#  '주의': 64,
#  '수요': 63,
#  '재판': 63,
#  '집행': 63,
#  '청장': 63,
#  '직장': 63,
#  '면제': 63,
#  '연구개발': 63,
#  '질병': 62,
#  '각종': 61,
#  '대도시': 61,
#  '자녀': 61,
#  '역할': 61,
#  '선고': 61,
#  '확정': 61,
#  '도로': 61,
#  '임원': 61,
#  '공표': 61,
#  '통한': 61,
#  '손해': 61,
#  '손해배상': 61,
#  '재해': 61,
#  '교류': 61,
#  '건축': 61,
#  '해결': 60,
#  '경영': 60,
#  '승인': 60,
#  '모든': 60,
#  '보증': 60,
#  '정당': 60,
#  '헌법': 60,
#  '실현': 59,
#  '분석': 59,
#  '입법': 59,
#  '진행': 59,
#  '한정': 59,
#  '변화': 59,
#  '예외': 59,
#  '복합': 59,
#  '소음': 58,
#  '전부': 58,
#  '별도': 58,
#  '가치': 58,
#  '특별법': 58,
#  '현실': 58,
#  '편의': 58,
#  '담배': 58,
#  '현황': 58,
#  '이익': 58,
#  '불법': 58,
#  '직무': 57,
#  '로부터': 57,
#  '지자체': 57,
#  '전체': 57,
#  '직업': 57,
#  '저출산': 57,
#  '공중보건': 57,
#  '특성': 56,
#  '고하': 56,
#  '장소': 56,
#  '예비': 56,
#  '일반': 56,
#  '정거': 56,
#  '거주': 56,
#  '기구': 56,
#  '자의': 56,
#  '합의': 56,
#  '긴급': 56,
#  '자체': 55,
#  '때문': 55,
#  '군수': 55,
#  '확산': 55,
#  '취약': 55,
#  '학대': 55,
#  '채권': 55,
#  '경쟁력': 55,
#  '온라인': 55,
#  '주식': 55,
#  '임대료': 55,
#  '재생에너지': 54,
#  '자유': 54,
#  '국세': 54,
#  '중심': 54,
#  '수당': 54,
#  '실적': 54,
#  '철도': 54,
#  '가능성': 53,
#  '원인': 53,
#  '주요': 53,
#  '징수': 53,
#  '추천': 53,
#  '계정': 53,
#  '휴가': 53,
#  '기회': 53,
#  '행위자': 53,
#  '단서': 53,
#  '이바지': 53,
#  '연도': 53,
#  '지원이': 53,
#  '공단': 53,
#  '건축물': 53,
#  '공인': 53,
#  '국민연금': 53,
#  '특별자치시': 52,
#  '체납': 52,
#  '주체': 52,
#  '평화': 52,
#  '시정': 52,
#  '개별': 52,
#  '능력': 52,
#  '세계': 52,
#  '소관': 52,
#  '부지': 52,
#  '특수': 52,
#  '공유': 52,
#  '부금': 52,
#  '복무': 52,
#  '노동조합': 52,
#  '화재': 51,
#  '보존': 51,
#  '운동': 51,
#  '정도': 51,
#  '점검': 51,
#  '본인': 51,
#  '보조': 51,
#  '이상인': 51,
#  '자산': 51,
#  '간의': 51,
#  '성장': 51,
#  '일자리': 51,
#  '방안': 51,
#  '광역시': 50,
#  '제시': 50,
#  '차별': 50,
#  '합리': 50,
#  '상한': 50,
#  '지위': 50,
#  '소방': 50,
#  '교부': 50,
#  '기후변화': 50,
#  '임대차': 50,
#  '행정안전부': 49,
#  '판결': 49,
#  '점사': 49,
#  '매출': 49,
#  '하나': 49,
#  '업주': 49,
#  '진료': 49,
#  '소환투표': 49,
#  '권고': 48,
#  '구제': 48,
#  '당사자': 48,
#  '판단': 48,
#  '대한민국': 48,
#  '유도': 48,
#  '폐지': 48,
#  '외국인': 48,
#  '토지': 48,
#  '업체': 48,
#  '의료인': 48,
#  '식품': 48,
#  '개설': 48,
#  '수사': 47,
#  '상품': 47,
#  '집단': 47,
#  '통신': 47,
#  '위원장': 47,
#  '변호사': 47,
#  '교원': 47,
#  '설정': 47,
#  '상호': 46,
#  '시간': 46,
#  '급식': 46,
#  '고용노동부': 46,
#  '업종': 46,
#  '회계': 46,
#  '매입': 46,
#  '동시': 46,
#  '권한': 46,
#  '훈련': 46,
#  '지방의회': 46,
#  '결산': 46,
#  '혜택': 46,
#  '폭력': 46,
#  '계층': 46,
#  '가정폭력': 46,
#  '대비': 45,
#  '반면': 45,
#  '유공': 45,
#  '평균': 45,
#  '대법원': 45,
#  '각각': 45,
#  '보고서': 45,
#  '동안': 45,
#  '임용': 45,
#  '보급': 45,
#  '한계': 45,
#  '시민': 45,
#  '교육부': 45,
#  '부가가치세': 45,
#  '제조': 45,
#  '대한': 45,
#  '통상': 44,
#  '특례시': 44,
#  '장비': 44,
#  '통일': 44,
#  '근무': 44,
#  '여러': 44,
#  '신용': 44,
#  '별표': 44,
#  '수업': 44,
#  '측면': 44,
#  '등록금': 44,
#  '임대주택': 44,
#  '자원': 43,
#  '수가': 43,
#  '유족': 43,
#  '경찰관': 43,
#  '자율': 43,
#  '연령': 43,
#  '반환': 43,
#  '기존': 43,
#  '장애': 43,
#  '사전': 43,
#  '납세': 43,
#  '경기': 43,
#  '이용자': 43,
#  '발급': 43,
#  '조달': 43,
#  '윤리': 43,
#  '인사': 43,
#  '선거운동': 43,
#  '온종일': 43,
#  '기부': 42,
#  '명의': 42,
#  '형사': 42,
#  '전국': 42,
#  '종료': 42,
#  '세대': 42,
#  '시험': 42,
#  '다수': 42,
#  '부양': 42,
#  '북한': 42,
#  '결격': 42,
#  '협동조합': 42,
#  '파악': 41,
#  '신체': 41,
#  '공정': 41,
#  '고령': 41,
#  '전담': 41,
#  '열람': 41,
#  '식품의약품안전처': 41,
#  '갱신': 41,
#  '사회보장': 41,
#  '매우': 40,
#  '상태': 40,
#  '형평성': 40,
#  '고시': 40,
#  '가중': 40,
#  '준수': 40,
#  '발표': 40,
#  '선수': 40,
#  '소유': 40,
#  '용도': 40,
#  '지방세': 40,
#  '연간': 40,
#  '요양': 40,
#  '대기업': 40,
#  '고향': 40,
#  '양육비': 40,
#  '장치': 39,
#  '노출': 39,
#  '공항': 39,
#  '이로': 39,
#  '정신': 39,
#  '회복': 39,
#  '과도': 39,
#  '법정': 39,
#  '체육관': 39,
#  '이자': 39,
#  '설비': 39,
#  '조례': 39,
#  '별로': 39,
#  '세법': 39,
#  '특별자치도': 39,
#  '도시재생': 39,
#  '특허': 39,
#  '몰수': 39,
#  '물류': 39,
#  '대부분': 38,
#  '홍보': 38,
#  '정관': 38,
#  '구매': 38,
#  '인식': 38,
#  '국립묘지': 38,
#  '누구': 38,
#  '민주': 38,
#  '용역': 38,
#  '광부': 38,
#  '경쟁': 38,
#  '지난': 38,
#  '가해자': 38,
#  '예상': 38,
#  '유해': 38,
#  '수집': 38,
#  '가지': 38,
#  '조합': 38,
#  '품목': 38,
#  '비밀': 38,
#  '상생': 38,
#  '소멸': 38,
#  '광역': 38,
#  '서민': 38,
#  '도의': 38,
#  '임상시험': 38,
#  '방해': 37,
#  '담당': 37,
#  '제대로': 37,
#  '인터넷': 37,
#  '소비': 37,
#  '어린이집': 37,
#  '임의': 37,
#  '사태': 37,
#  '스포츠': 37,
#  '출연': 37,
#  '소규모': 37,
#  '의장': 37,
#  '우리': 37,
#  '퍼센트': 37,
#  '과학기술': 37,
#  '보호자': 37,
#  '영상': 37,
#  '방문': 37,
#  '동의': 37,
#  '양육': 37,
#  '소재': 37,
#  '단계': 37,
#  '위임': 37,
#  '비롯': 37,
#  '회원': 37,
#  '구성원': 37,
#  '분권': 36,
#  '최대': 36,
#  '차량': 36,
#  '초기': 36,
#  '상환': 36,
#  '접수': 36,
#  '학습': 36,
#  '검토': 36,
#  '주민등록': 36,
#  '법인세': 36,
#  '양성': 36,
#  '감염': 36,
#  '가산': 36,
#  '심화': 36,
#  '응급': 36,
#  '거부': 35,
#  '효력': 35,
#  '사랑': 35,
#  '중인': 35,
#  '명칭': 35,
#  '부터': 35,
#  '최고': 35,
#  '경감': 35,
#  '위협': 35,
#  '소득세': 35,
#  '출석': 35,
#  '대학원': 35,
#  '대리점': 35,
#  '보전': 35,
#  '부처': 34,
#  '자원부': 34,
#  '신뢰': 34,
#  '지도': 34,
#  '달리': 34,
#  '권익': 34,
#  '민주화': 34,
#  '벌칙': 34,
#  '고자': 34,
#  '여성': 34,
#  '통보': 34,
#  '단위': 34,
#  '군인': 34,
#  '점포': 34,
#  '조세': 34,
#  '성적': 34,
#  '명세서': 34,
#  '인상': 34,
#  '지주회사': 34,
#  '성희롱': 34,
#  '거짓': 33,
#  '대여': 33,
#  '생명': 33,
#  '괴롭힘': 33,
#  '불이익': 33,
#  '최소': 33,
#  '비상': 33,
#  '임기': 33,
#  '경비': 33,
#  '통지': 33,
#  '문화재': 33,
#  '협약': 33,
#  '개인정보': 33,
#  '지도자': 33,
#  '농어촌': 33,
#  '가액': 33,
#  '개정안': 32,
#  '지방자치': 32,
#  '대가': 32,
#  '확충': 32,
#  '허위': 32,
#  '미국': 32,
#  '당시': 32,
#  '경과': 32,
#  '소유자': 32,
#  '달성': 32,
#  '선임': 32,
#  '구분': 32,
#  '자재': 32,
#  '선택': 32,
#  '더욱': 32,
#  '부합': 32,
#  '감염증': 32,
#  '물의': 32,
#  '정법': 32,
#  '연구기관': 32,
#  '교육감': 32,
#  '주주': 32,
#  '상임': 32,
#  '시효': 32,
#  '다음': 32,
#  '지방자치법': 32,
#  '유출': 32,
#  '사업': 32,
#  '부칙': 31,
#  '중앙회': 31,
#  '책무': 31,
#  '전문가': 31,
#  '상담': 31,
#  '본부': 31,
#  '근절': 31,
#  '대통령': 31,
#  '영세': 31,
#  '공시': 31,
#  '세제': 31,
#  '폐업': 31,
#  '문제점': 31,
#  '서류': 31,
#  '이외': 31,
#  '중단': 31,
#  '자연': 31,
#  '규칙': 31,
#  '부모': 31,
#  '시기': 31,
#  '유통업': 31,
#  '법률': 31,
#  '미비': 30,
#  '국외': 30,
#  '목표': 30,
#  '차원': 30,
#  '기록': 30,
#  '심리': 30,
#  '생계': 30,
#  '존재': 30,
#  '공공': 30,
#  '양도소득세': 30,
#  '배상': 30,
#  '저해': 30,
#  '이동': 30,
#  '배분': 30,
#  '병원': 30,
#  '코로나바이러스': 30,
#  '전통': 30,
#  '취급': 30,
#  '시점': 30,
#  '유산': 30,
#  '시대': 30,
#  '민원': 30,
#  '이자율': 30,
#  '제작': 30,
#  '보조금': 30,
#  '작업': 30,
#  '품질': 30,
#  '재료': 30,
#  '방사성폐기물': 30,
#  '전단': 30,
#  '발굴': 29,
#  '지식': 29,
#  '적정': 29,
#  '보도': 29,
#  '훼손': 29,
#  '예정': 29,
#  '질서': 29,
#  '정보통신망': 29,
#  '투기': 29,
#  '양도소득': 29,
#  '방향': 29,
#  '약자': 29,
#  '의결권': 29,
#  '악화': 29,
#  '농산물': 29,
#  '종전': 29,
#  '필수': 29,
#  '모집': 29,
#  '특별시': 29,
#  '서면': 29,
#  '취득세': 29,
#  '미세먼지': 29,
#  '쟁의': 29,
#  '협조': 28,
#  '동물': 28,
#  '수익': 28,
#  '유치원': 28,
#  '발견': 28,
#  '출산': 28,
#  '통계': 28,
#  '민족': 28,
#  '불편': 28,
#  '격차': 28,
#  '투명': 28,
#  '차단': 28,
#  '담보': 28,
#  '산재': 28,
#  '사립학교': 28,
#  '상공': 28,
#  '출자': 28,
#  '부문': 28,
#  '무상': 28,
#  '벌금형': 28,
#  '체육회': 28,
#  '기기': 28,
#  '공통': 28,
#  '주장': 28,
#  '안전성': 28,
#  '지역구': 28,
#  '휴업': 28,
#  '마스크': 28,
#  '학자금대출': 28,
#  '살포': 28,
#  '향후': 27,
#  '재단': 27,
#  '환수': 27,
#  '배제': 27,
#  '보관': 27,
#  '의심': 27,
#  '역시': 27,
#  '통행': 27,
#  '부가': 27,
#  '표준': 27,
#  '감안': 27,
#  '집중': 27,
#  '건물': 27,
#  '외국': 27,
#  '높이': 27,
#  '안건': 27,
#  '재직': 27,
#  '보훈': 27,
#  '보증금': 27,
#  '신규': 27,
#  '관광': 27,
#  ...}

# %%
# 미래통합당 21
wordcloud(MT_)
# Out:
# {'지역': 559,
#  '지원': 476,
#  '시설': 323,
#  '국가': 317,
#  '관리': 316,
#  '발생': 282,
#  '보호': 256,
#  '위원회': 256,
#  '해당': 255,
#  '주택': 235,
#  '산업': 234,
#  '기업': 231,
#  '의결': 222,
#  '지방자치단체': 222,
#  '관련': 220,
#  '계획': 219,
#  '근로자': 212,
#  '운영': 210,
#  '지급': 210,
#  '사용': 208,
#  '사항': 202,
#  '마련': 201,
#  '국민': 196,
#  '현행법': 193,
#  '기준': 191,
#  '장관': 189,
#  '재정': 189,
#  '대하': 188,
#  '대상': 187,
#  '이상': 186,
#  '기관': 185,
#  '상황': 183,
#  '시행': 177,
#  '지정': 177,
#  '기간': 175,
#  '설치': 168,
#  '일부': 168,
#  '제도': 167,
#  '신설': 167,
#  '의무': 161,
#  '위해': 158,
#  '최근': 154,
#  '정책': 153,
#  '경제': 153,
#  '정부': 151,
#  '필요': 151,
#  '적용': 151,
#  '이하': 151,
#  '피해': 149,
#  '주민': 146,
#  '지적': 144,
#  '부담': 144,
#  '개정': 143,
#  '업무': 143,
#  '개발': 141,
#  '행위': 140,
#  '수립': 139,
#  '항제': 137,
#  '또한': 136,
#  '실시': 136,
#  '조사': 135,
#  '국내': 134,
#  '근거': 133,
#  '대해': 128,
#  '안전': 126,
#  '포함': 126,
#  '교육': 125,
#  '구역': 124,
#  '사회': 121,
#  '조정': 117,
#  '정보': 117,
#  '현행': 116,
#  '고용': 116,
#  '수행': 115,
#  '의료': 113,
#  '제기': 112,
#  '이용': 112,
#  '사업자': 111,
#  '제출': 107,
#  '거나': 106,
#  '최저임금': 106,
#  '개선': 105,
#  '의견': 105,
#  '문제': 105,
#  '금액': 105,
#  '학교': 104,
#  '안정': 104,
#  '발전': 104,
#  '실정': 103,
#  '국회': 103,
#  '복귀': 103,
#  '보험': 102,
#  '대표': 98,
#  '소득': 98,
#  '처리': 98,
#  '대통령령': 98,
#  '확보': 97,
#  '비용': 96,
#  '도시': 95,
#  '과세': 95,
#  '의원': 94,
#  '생활': 94,
#  '확대': 93,
#  '범죄': 93,
#  '번호': 92,
#  '심의': 92,
#  '아동': 92,
#  '추진': 91,
#  '의안': 90,
#  '신고': 90,
#  '제공': 90,
#  '범위': 89,
#  '결정': 88,
#  '조치': 88,
#  '제한': 88,
#  '지속': 88,
#  '고려': 88,
#  '활성화': 86,
#  '활동': 86,
#  '목적': 86,
#  '기술': 86,
#  '처벌': 86,
#  '활용': 85,
#  '시장': 85,
#  '위반': 85,
#  '특례': 85,
#  '투자': 84,
#  '감염병': 84,
#  '관계': 83,
#  '결과': 83,
#  '장애인': 82,
#  '수도권': 82,
#  '보장': 82,
#  '인구': 81,
#  '지방': 80,
#  '위기': 79,
#  '통해': 79,
#  '연장': 79,
#  '공무원': 79,
#  '피해자': 79,
#  '자료': 78,
#  '제외': 78,
#  '중소기업': 78,
#  '참전': 78,
#  '불구': 77,
#  '현재': 77,
#  '예방': 75,
#  '문화': 75,
#  '방지': 75,
#  '우려': 75,
#  '사람': 75,
#  '체육': 75,
#  '기부': 75,
#  '대응': 74,
#  '종합': 74,
#  '환경': 74,
#  '모집': 74,
#  '자녀': 73,
#  '요구': 73,
#  '사건': 72,
#  '신청': 72,
#  '이후': 71,
#  '면제': 71,
#  '수정': 71,
#  '체계': 71,
#  '건설': 71,
#  '증가': 71,
#  '참고': 70,
#  '복지': 70,
#  '서비스': 70,
#  '유공': 70,
#  '추가': 70,
#  '발의': 69,
#  '금지': 69,
#  '사유': 69,
#  '부과': 68,
#  '어려움': 67,
#  '비율': 67,
#  '규제': 67,
#  '안이': 66,
#  '공급': 66,
#  '촉진': 66,
#  '부동산': 66,
#  '절차': 66,
#  '전제': 65,
#  '내용': 65,
#  '근로': 64,
#  '청소년': 64,
#  '효율': 63,
#  '가격': 63,
#  '등록': 63,
#  '중앙': 63,
#  '예산': 63,
#  '창업': 63,
#  '규모': 61,
#  '요건': 61,
#  '호의': 61,
#  '코로나': 61,
#  '특별': 61,
#  '경력': 60,
#  '사고': 60,
#  '소속': 60,
#  '센터': 59,
#  '보상': 59,
#  '증진': 59,
#  '이내': 59,
#  '직접': 59,
#  '금품': 59,
#  '대책': 58,
#  '변경': 58,
#  '농어': 58,
#  '공공기관': 58,
#  '위원': 58,
#  '것이므': 57,
#  '법인': 57,
#  '완화': 57,
#  '공제': 57,
#  '인권': 57,
#  '재난': 56,
#  '평가': 56,
#  '학생': 56,
#  '다른': 56,
#  '근로시간': 56,
#  '도모': 56,
#  '영향': 56,
#  '반영': 56,
#  '북한': 56,
#  '판매': 55,
#  '기금': 55,
#  '감소': 55,
#  '상향': 55,
#  '장기': 55,
#  '민간': 55,
#  '선거': 55,
#  '상공': 55,
#  '허가': 55,
#  '도입': 54,
#  '일정': 54,
#  '명시': 54,
#  '건강': 54,
#  '요청': 54,
#  '기본': 54,
#  '기한': 54,
#  '법원': 54,
#  '아동학대': 54,
#  '회계': 54,
#  '효과': 53,
#  '임금': 53,
#  '권리': 53,
#  '정비': 53,
#  '확산': 53,
#  '도로': 53,
#  '사례': 52,
#  '유지': 52,
#  '청년': 52,
#  '접경': 52,
#  '의약품': 51,
#  '한편': 51,
#  '방사성폐기물': 51,
#  '인정': 51,
#  '공사': 50,
#  '여부': 50,
#  '생산': 50,
#  '인력': 50,
#  '단체': 49,
#  '현실': 49,
#  '수준': 49,
#  '가족': 49,
#  '공개': 49,
#  '심사': 49,
#  '실태': 48,
#  '교통': 48,
#  '여건': 48,
#  '세율': 48,
#  '필요성': 48,
#  '세액': 48,
#  '보고': 48,
#  '자의': 48,
#  '법령': 47,
#  '기여': 47,
#  '주거': 47,
#  '자동차': 47,
#  '금융': 47,
#  '미만': 47,
#  '관할': 47,
#  '삭제': 47,
#  '농업': 47,
#  '행정기관': 47,
#  '방범': 47,
#  '여성': 46,
#  '서류': 46,
#  '업종': 46,
#  '분양': 46,
#  '주변': 45,
#  '진흥': 45,
#  '국회의원': 45,
#  '조성': 45,
#  '초과': 45,
#  '회사': 45,
#  '재산': 44,
#  '연도': 44,
#  '사실': 44,
#  '이행': 44,
#  '재원': 44,
#  '우리나라': 44,
#  '가중': 44,
#  '단절': 43,
#  '위험': 43,
#  '가정': 43,
#  '검사': 43,
#  '채용': 43,
#  '분야': 43,
#  '성폭력': 43,
#  '청구': 43,
#  '납부': 43,
#  '한국': 42,
#  '법적': 42,
#  '구성': 42,
#  '분석': 42,
#  '건축물': 42,
#  '자율': 42,
#  '방법': 41,
#  '보건': 41,
#  '구축': 41,
#  '국토교통부': 41,
#  '이유': 40,
#  '부가가치세': 40,
#  '특별법': 40,
#  '사망': 40,
#  '보건복지부': 40,
#  '실효': 40,
#  '처분': 40,
#  '단지': 40,
#  '동안': 40,
#  '협력': 40,
#  '일몰': 40,
#  '사용자': 40,
#  '장함': 40,
#  '공익': 40,
#  '행정': 39,
#  '강제': 39,
#  '개인': 39,
#  '경영': 39,
#  '방해': 39,
#  '의사': 39,
#  '종사': 39,
#  '각종': 38,
#  '로서': 38,
#  '선택': 38,
#  '기능': 38,
#  '능력': 38,
#  '우선': 38,
#  '공업': 38,
#  '취득': 38,
#  '휴가': 38,
#  '노인': 38,
#  '매년': 38,
#  '부여': 38,
#  '방안': 38,
#  '장비': 38,
#  '환자': 38,
#  '조직': 38,
#  '책임': 38,
#  '공동': 37,
#  '안건': 37,
#  '향상': 37,
#  '과정': 37,
#  '해사': 37,
#  '각각': 36,
#  '수요': 36,
#  '연구': 36,
#  '더욱': 36,
#  '해외': 36,
#  '예비': 36,
#  '건전': 36,
#  '정의': 35,
#  '협의': 35,
#  '개월': 35,
#  '수단': 35,
#  '악화': 35,
#  '투명': 35,
#  '자금': 35,
#  '원자력': 35,
#  '통상': 35,
#  '수당': 35,
#  '보상금': 35,
#  '위원장': 35,
#  '담당': 34,
#  '별로': 34,
#  '회의': 34,
#  '실제': 34,
#  '확인': 34,
#  '통한': 34,
#  '토지': 34,
#  '치료': 34,
#  '시간': 34,
#  '임업': 34,
#  '소재': 34,
#  '선정': 34,
#  '기반': 34,
#  '어린이': 34,
#  '원칙': 34,
#  '구분': 34,
#  '공유': 34,
#  '세대': 34,
#  '가맹': 34,
#  '대비': 33,
#  '보조': 33,
#  '위탁': 33,
#  '손실': 33,
#  '성과': 33,
#  '장애': 33,
#  '취지': 33,
#  '적극': 33,
#  '경감': 33,
#  '해외진출': 33,
#  '대학': 33,
#  '기초': 33,
#  '규정': 33,
#  '보존': 32,
#  '설립': 32,
#  '소비자': 32,
#  '전환': 32,
#  '사무': 32,
#  '유족': 32,
#  '주체': 32,
#  '조세': 32,
#  '따라서': 32,
#  '작성': 32,
#  '폐광': 31,
#  '지원이': 31,
#  '승인': 31,
#  '단축': 31,
#  '상담': 31,
#  '별도': 31,
#  '일반': 31,
#  '거래': 31,
#  '학대': 31,
#  '벌금': 31,
#  '침해': 31,
#  '대한민국': 31,
#  '기록': 31,
#  '정치': 31,
#  '균형': 31,
#  '혜택': 31,
#  '제대로': 30,
#  '상의': 30,
#  '특성': 30,
#  '대상자': 30,
#  '양육': 30,
#  '간이': 30,
#  '급식': 30,
#  '이전': 30,
#  '취업': 30,
#  '수입': 30,
#  '응급의료': 30,
#  '인재': 30,
#  '진행': 29,
#  '통합': 29,
#  '인상': 29,
#  '법인세': 29,
#  '상승': 29,
#  '취득세': 29,
#  '조항': 29,
#  '어업': 29,
#  '명령': 29,
#  '세계': 29,
#  '감사': 29,
#  '행사': 29,
#  '개인정보': 29,
#  '보안': 29,
#  '침체': 28,
#  '영상': 28,
#  '특정': 28,
#  '단서': 28,
#  '시스템': 28,
#  '점검': 28,
#  '용역': 28,
#  '소비': 28,
#  '철도': 28,
#  '중심': 28,
#  '실질': 28,
#  '임대': 28,
#  '군수': 28,
#  '보수': 28,
#  '경쟁력': 28,
#  '재해': 28,
#  '자원': 28,
#  '진료': 28,
#  '코로나바이러스': 28,
#  '입학': 28,
#  '징계': 28,
#  '농어촌': 28,
#  '전력': 28,
#  '사업': 28,
#  '역할': 27,
#  '변화': 27,
#  '세법': 27,
#  '제정': 27,
#  '질병': 27,
#  '당시': 27,
#  '징역': 27,
#  '벤처기업': 27,
#  '감독': 27,
#  '개별': 27,
#  '이탈': 27,
#  '시책': 27,
#  '국제': 27,
#  '반환': 27,
#  '전문성': 27,
#  '폭력': 27,
#  '집행': 27,
#  '입체': 27,
#  '인증': 27,
#  '타당성조사': 27,
#  '영업': 27,
#  '스포츠': 27,
#  '시각장애인': 27,
#  '관광': 27,
#  '에너지': 26,
#  '운용': 26,
#  '취소': 26,
#  '급여': 26,
#  '계약': 26,
#  '보증': 26,
#  '직무': 26,
#  '허용': 26,
#  '감염증': 26,
#  '동원': 26,
#  '설비': 26,
#  '전쟁': 26,
#  '긴급': 26,
#  '노동조합': 26,
#  '제시': 25,
#  '도록': 25,
#  '전담': 25,
#  '보유': 25,
#  '용도': 25,
#  '로부터': 25,
#  '외국인': 25,
#  '제재': 25,
#  '노력': 25,
#  '경제활동': 25,
#  '한정': 25,
#  '가능성': 25,
#  '임차': 25,
#  '상임': 25,
#  '중소': 25,
#  '결산': 25,
#  '때문': 25,
#  '보전': 25,
#  '핵연료': 25,
#  '원전': 25,
#  '초래': 25,
#  '항공': 25,
#  '과세표준': 25,
#  '장치': 25,
#  '구조': 25,
#  '징수': 25,
#  '사이버': 25,
#  '소음': 25,
#  '취약': 25,
#  '대한': 25,
#  '신체': 24,
#  '한계': 24,
#  '교부': 24,
#  '성장': 24,
#  '전문': 24,
#  '편의': 24,
#  '고용노동부': 24,
#  '종료': 24,
#  '청장': 24,
#  '검증': 24,
#  '동시': 24,
#  '정신': 24,
#  '저장': 24,
#  '육아휴직': 24,
#  '대부분': 24,
#  '대기업': 24,
#  '균형발전': 24,
#  '산정': 24,
#  '위치': 24,
#  '형사': 24,
#  '전부': 24,
#  '공인': 24,
#  '투표': 24,
#  '기획재정부장관': 24,
#  '수급': 24,
#  '점자': 24,
#  '국민권익위': 24,
#  '주인': 24,
#  '경기': 23,
#  '방식': 23,
#  '외부': 23,
#  '양육비': 23,
#  '차원': 23,
#  '참여': 23,
#  '재단': 23,
#  '임대주택': 23,
#  '도지사': 23,
#  '핵심': 23,
#  '부금': 23,
#  '공항': 23,
#  '지출': 23,
#  '노후': 23,
#  '공원': 23,
#  '과도': 23,
#  '본부': 23,
#  '영세': 23,
#  '폐기물': 23,
#  '수리': 23,
#  '생명': 22,
#  '전망': 22,
#  '방송': 22,
#  '업주': 22,
#  '비롯': 22,
#  '해소': 22,
#  '명예': 22,
#  '파악': 22,
#  '매출': 22,
#  '이상인': 22,
#  '형평성': 22,
#  '주요': 22,
#  '정법': 22,
#  '소득세': 22,
#  '축소': 22,
#  '이바지': 22,
#  '보고서': 22,
#  '보조금': 22,
#  '남북': 22,
#  '종류': 22,
#  '입법': 22,
#  '위축': 22,
#  '업자': 22,
#  '국외': 22,
#  '선수': 22,
#  '국가채무': 22,
#  '육성': 21,
#  '대통령': 21,
#  '경비': 21,
#  '현장': 21,
#  '다수': 21,
#  '지위': 21,
#  '매우': 21,
#  '원금': 21,
#  '소요': 21,
#  '원인': 21,
#  '인사': 21,
#  '제조': 21,
#  '노동': 21,
#  '재산세': 21,
#  '계속': 21,
#  '예수': 21,
#  '상태': 21,
#  '행정안전부': 21,
#  '해제': 21,
#  '측정': 21,
#  '체육관': 21,
#  '광부': 21,
#  '신규': 21,
#  '헌혈': 21,
#  '대의': 20,
#  '교육부': 20,
#  '약자': 20,
#  '부족': 20,
#  '여객': 20,
#  '희생': 20,
#  '회복': 20,
#  '보완': 20,
#  '전국': 20,
#  '전체': 20,
#  '위협': 20,
#  '감안': 20,
#  '물질': 20,
#  '평균': 20,
#  '심화': 20,
#  '구제': 20,
#  '이익': 20,
#  '소유': 20,
#  '차량': 20,
#  '예정': 20,
#  '후보자': 20,
#  '과태료': 20,
#  '대원': 20,
#  '군인': 20,
#  '대규모': 20,
#  '기회': 20,
#  '수신료': 20,
#  '공간': 20,
#  '현저': 20,
#  '지도': 20,
#  '소상': 20,
#  '부지': 20,
#  '자치': 20,
#  '공시가격': 20,
#  '혁신': 20,
#  '비영리': 20,
#  '대체': 19,
#  '연금': 19,
#  '달리': 19,
#  '수익': 19,
#  '본인': 19,
#  '가지': 19,
#  '연간': 19,
#  '재발': 19,
#  '거부': 19,
#  '현황': 19,
#  '소관': 19,
#  '유적': 19,
#  '건물': 19,
#  '최대': 19,
#  '제품': 19,
#  '지연': 19,
#  '분할': 19,
#  '조합': 19,
#  '간의': 19,
#  '통보': 19,
#  '배우자': 19,
#  '예산안': 19,
#  '합의': 19,
#  '수업': 19,
#  '기존': 19,
#  '세제': 19,
#  '시효': 19,
#  '교원': 19,
#  '지구': 19,
#  '응급환자': 19,
#  '검토': 19,
#  '국회법': 19,
#  '집중': 19,
#  '형태': 18,
#  '세금': 18,
#  '장려': 18,
#  '유급': 18,
#  '물가': 18,
#  '운전자': 18,
#  '권한': 18,
#  '이로': 18,
#  '임시': 18,
#  '발전소': 18,
#  '사법': 18,
#  '양성': 18,
#  '훈련': 18,
#  '하나': 18,
#  '우리': 18,
#  '사태': 18,
#  '강화': 18,
#  '거주': 18,
#  '모두': 18,
#  '구체': 18,
#  '경찰서': 18,
#  '납북': 18,
#  '반면': 18,
#  '훼손': 18,
#  '택시': 18,
#  '가액': 18,
#  '해결': 18,
#  '공장': 18,
#  '통장': 18,
#  '이장': 18,
#  '지자체': 18,
#  '녹지': 18,
#  '인터넷': 17,
#  '교섭단체': 17,
#  '기구': 17,
#  '장소': 17,
#  '지난': 17,
#  '담보': 17,
#  '여러': 17,
#  '확정': 17,
#  '특별자치시': 17,
#  '주의': 17,
#  '체결': 17,
#  '수가': 17,
#  '역시': 17,
#  '선출': 17,
#  '위임': 17,
#  '근무': 17,
#  '사기': 17,
#  '시기': 17,
#  '초등학교': 17,
#  '저해': 17,
#  '프로그램': 17,
#  '상시': 17,
#  '소년': 17,
#  '단위': 17,
#  '임명': 17,
#  '상이': 17,
#  '책무': 17,
#  '통일': 17,
#  '고령화': 17,
#  '중단': 17,
#  '지역별': 17,
#  '연령': 17,
#  '배출': 17,
#  '데이터': 17,
#  '선임': 17,
#  '품목': 17,
#  '물가상승률': 17,
#  '실내': 17,
#  '문화재': 17,
#  '개혁': 17,
#  '경제성': 16,
#  '수수료': 16,
#  '동의': 16,
#  '인건비': 16,
#  '대가': 16,
#  '보훈': 16,
#  '출연': 16,
#  '구입': 16,
#  '구매': 16,
#  '연구개발': 16,
#  '장기간': 16,
#  '가치': 16,
#  '종전': 16,
#  '업체': 16,
#  '부의': 16,
#  '유류': 16,
#  '어민': 16,
#  '원자력발전소': 16,
#  '최소': 16,
#  '판결': 16,
#  '융자': 16,
#  '조건': 16,
#  '보행': 16,
#  '정도': 16,
#  '고시': 16,
#  '유아': 16,
#  '어린이집': 16,
#  '법무부': 16,
#  '추천': 16,
#  '관서': 16,
#  '유발': 16,
#  '가입': 16,
#  '불금': 16,
#  '준수': 16,
#  '헌법': 16,
#  '자가': 16,
#  '범죄예방': 16,
#  '집단': 16,
#  '별표': 16,
#  '하락': 16,
#  '합산': 16,
#  '이송': 16,
#  '자원부': 16,
#  '왕도': 16,
#  '격차': 16,
#  '가장': 16,
#  '국유재산': 16,
#  '물품': 15,
#  '보험료': 15,
#  '전반': 15,
#  '통제': 15,
#  '교육감': 15,
#  '인식': 15,
#  '차별': 15,
#  '자체': 15,
#  '경험': 15,
#  '부합': 15,
#  '상품': 15,
#  '예외': 15,
#  '운행': 15,
#  '특별회계': 15,
#  '수집': 15,
#  '지방세': 15,
#  '직업': 15,
#  '조달': 15,
#  '휴업': 15,
#  '지체': 15,
#  '전용': 15,
#  '만료': 15,
#  '노출': 15,
#  '만큼': 15,
#  '극복': 15,
#  '원자력발전': 15,
#  '배분': 15,
#  '상한': 15,
#  '부터': 15,
#  '직원': 15,
#  '양도소득세': 15,
#  '축산': 15,
#  '유통': 15,
#  '무상': 15,
#  '공직': 15,
#  '서면': 15,
#  '외국': 15,
#  '분류': 15,
#  '정성': 15,
#  '미리': 15,
#  '저출산': 15,
#  '정당': 15,
#  '인하': 15,
#  '감염': 15,
#  '공정': 15,
#  '농가': 15,
#  '예측': 15,
#  '전기': 15,
#  '한도': 15,
#  '임대료': 15,
#  '화로': 15,
#  '화재': 15,
#  '출생신고': 15,
#  '세무사': 15,
#  '직장': 15,
#  '가운데': 15,
#  '상환': 15,
#  '소방': 15,
#  '불균형': 15,
#  '안보': 15,
#  '스토킹': 15,
#  '추계': 15,
#  '재건축': 15,
#  '공중보건': 15,
#  '실적': 14,
#  '한시': 14,
#  '필수': 14,
#  '확충': 14,
#  '투기': 14,
#  '화해': 14,
#  '설명': 14,
#  '납세': 14,
#  '해석': 14,
#  '고하': 14,
#  '생존': 14,
#  '인도': 14,
#  '부모': 14,
#  '기반시설': 14,
#  '접근성': 14,
#  '폐지': 14,
#  '양도': 14,
#  '시작': 14,
#  '규칙': 14,
#  '글로벌': 14,
#  '유도': 14,
#  '대도시': 14,
#  '주장': 14,
#  '형법': 14,
#  '분리': 14,
#  '병원': 14,
#  '재직': 14,
#  '민주': 14,
#  '선거운동': 14,
#  '퇴직': 14,
#  '임원': 14,
#  '비리': 14,
#  '손해': 14,
#  '상대': 14,
#  '계층': 14,
#  '일시': 14,
#  '예상': 14,
#  '전형': 14,
#  '낙후': 14,
#  '수산물': 14,
#  '합리': 14,
#  '불법': 14,
#  '자립': 14,
#  '확장': 14,
#  '지도자': 14,
#  '과세특례': 14,
#  '대처': 14,
#  '재활용': 14,
#  '부작용': 14,
#  '전략': 14,
#  '기질': 14,
#  '가정폭력': 14,
#  '도시재생': 14,
#  '신용카드': 14,
#  '소녀': 14,
#  '공용': 14,
#  '학교폭력': 13,
#  '공단': 13,
#  '버스': 13,
#  '크게': 13,
#  '대중교통': 13,
#  '설계': 13,
#  '경과': 13,
#  '협조': 13,
#  '매입': 13,
#  '보호자': 13,
#  '운전': 13,
#  '정지': 13,
#  '중인': 13,
#  '불편': 13,
#  '경찰': 13,
#  '안전성': 13,
#  '가산': 13,
#  '용지': 13,
#  '이자': 13,
#  '자재': 13,
#  '어선': 13,
#  '비중': 13,
#  '일자리': 13,
#  '소송': 13,
#  '회계감사': 13,
#  '근절': 13,
#  '품질': 13,
#  '인원': 13,
#  '근로기준법': 13,
#  '본회의': 13,
#  '소유자': 13,
#  ...}

# %%
# 정의당 21
wordcloud(JE_)
# Out:
# {'국가': 84,
#  '운영': 83,
#  '지원': 75,
#  '지방자치단체': 69,
#  '사회': 68,
#  '교육': 68,
#  '해당': 67,
#  '행위': 66,
#  '근로자': 63,
#  '사항': 63,
#  '위원회': 62,
#  '관련': 60,
#  '이상': 60,
#  '보건': 60,
#  '발생': 57,
#  '이하': 57,
#  '보호': 56,
#  '관리': 56,
#  '의무': 55,
#  '대상': 55,
#  '대학': 54,
#  '지급': 53,
#  '지역': 52,
#  '대하': 52,
#  '법인': 50,
#  '시설': 49,
#  '국립': 49,
#  '조정': 48,
#  '계획': 48,
#  '기간': 48,
#  '사람': 47,
#  '의료': 47,
#  '기준': 45,
#  '거나': 44,
#  '보험': 44,
#  '위반': 43,
#  '국민': 43,
#  '아동': 43,
#  '도시': 43,
#  '사건': 42,
#  '피해자': 42,
#  '부담': 42,
#  '시행': 40,
#  '기관': 40,
#  '부동산': 40,
#  '신설': 40,
#  '고용': 39,
#  '계약': 39,
#  '의결': 39,
#  '청소년': 39,
#  '업무': 38,
#  '사용': 38,
#  '조치': 37,
#  '도서관': 37,
#  '위해': 36,
#  '제기': 36,
#  '설치': 36,
#  '기업': 35,
#  '범죄': 35,
#  '사업자': 35,
#  '환경': 35,
#  '금지': 35,
#  '지정': 34,
#  '실시': 34,
#  '학교': 34,
#  '목적': 34,
#  '일부': 34,
#  '괴롭힘': 34,
#  '마련': 33,
#  '장관': 33,
#  '범위': 33,
#  '주택': 33,
#  '토지': 33,
#  '개정': 32,
#  '제한': 32,
#  '결정': 32,
#  '수급': 32,
#  '상황': 32,
#  '항제': 32,
#  '치료': 31,
#  '적용': 31,
#  '제도': 31,
#  '거래': 31,
#  '건강': 31,
#  '문제': 30,
#  '피해': 30,
#  '대통령령': 30,
#  '신고': 30,
#  '명시': 30,
#  '금액': 30,
#  '병원': 29,
#  '의료인': 29,
#  '현행': 29,
#  '지적': 29,
#  '방지': 29,
#  '보장': 29,
#  '직장': 29,
#  '국민연금': 29,
#  '수립': 28,
#  '장애인': 28,
#  '책임': 28,
#  '단체': 28,
#  '공원': 28,
#  '현행법': 28,
#  '예방': 27,
#  '대해': 27,
#  '산업': 27,
#  '또한': 26,
#  '업자': 26,
#  '청구': 26,
#  '포함': 26,
#  '공무원': 26,
#  '연금': 26,
#  '처벌': 25,
#  '실효': 25,
#  '설립': 25,
#  '이용': 25,
#  '소송': 25,
#  '온종일': 25,
#  '대표': 25,
#  '내용': 25,
#  '확대': 25,
#  '차별': 25,
#  '선거': 25,
#  '인정': 24,
#  '최근': 24,
#  '안정': 24,
#  '제공': 24,
#  '지속': 24,
#  '주민': 24,
#  '정책': 24,
#  '근거': 24,
#  '농어': 24,
#  '등록': 24,
#  '필요': 23,
#  '법원': 23,
#  '부과': 23,
#  '요구': 23,
#  '소속': 23,
#  '여성': 23,
#  '휴가': 23,
#  '경제': 22,
#  '수행': 22,
#  '조건': 22,
#  '의견': 22,
#  '난임': 22,
#  '감염병': 21,
#  '재판': 21,
#  '당사자': 21,
#  '아동학대': 21,
#  '임금': 21,
#  '투자': 21,
#  '체계': 20,
#  '특별': 20,
#  '이내': 20,
#  '한국': 20,
#  '소득': 20,
#  '고려': 20,
#  '업주': 20,
#  '한편': 20,
#  '소유': 20,
#  '비율': 20,
#  '허용': 20,
#  '조사': 20,
#  '신청': 20,
#  '사유': 20,
#  '관계': 19,
#  '심의': 19,
#  '의원': 19,
#  '활동': 19,
#  '상의': 19,
#  '결과': 19,
#  '개선': 19,
#  '제외': 19,
#  '제출': 19,
#  '명령': 19,
#  '출산': 19,
#  '자녀': 19,
#  '변경': 18,
#  '보건복지부': 18,
#  '증가': 18,
#  '분쟁': 18,
#  '손해': 18,
#  '권리': 18,
#  '근로': 18,
#  '추진': 18,
#  '정보': 18,
#  '가족': 18,
#  '유족': 18,
#  '징역': 18,
#  '임신': 18,
#  '이유': 18,
#  '회사': 18,
#  '문화': 17,
#  '추가': 17,
#  '대규모': 17,
#  '참여': 17,
#  '법령': 17,
#  '민주': 17,
#  '재산': 17,
#  '보유': 17,
#  '조항': 17,
#  '급여': 17,
#  '재해': 17,
#  '집행': 17,
#  '위탁': 17,
#  '정부': 16,
#  '초과': 16,
#  '반영': 16,
#  '번호': 16,
#  '제주': 15,
#  '종사': 15,
#  '취득': 15,
#  '비용': 15,
#  '우려': 15,
#  '정치': 15,
#  '협력': 15,
#  '이행': 15,
#  '가정': 15,
#  '전제': 15,
#  '종합': 15,
#  '공공기관': 15,
#  '활성화': 15,
#  '연간': 15,
#  '수준': 15,
#  '불구': 15,
#  '점포': 15,
#  '담배': 15,
#  '구역': 15,
#  '수익': 15,
#  '성폭력': 14,
#  '어려움': 14,
#  '이후': 14,
#  '확보': 14,
#  '기술': 14,
#  '사실': 14,
#  '고발': 14,
#  '다른': 14,
#  '재정': 14,
#  '관할': 14,
#  '신탁': 14,
#  '방법': 14,
#  '교원': 14,
#  '신체': 14,
#  '직무': 14,
#  '임차': 14,
#  '채용': 14,
#  '통해': 14,
#  '발전': 14,
#  '추천': 14,
#  '양성': 14,
#  '법관': 14,
#  '금융투자': 14,
#  '판단': 13,
#  '생활': 13,
#  '절차': 13,
#  '노력': 13,
#  '공익': 13,
#  '배상': 13,
#  '도입': 13,
#  '예외': 13,
#  '도지사': 13,
#  '지방': 13,
#  '부모': 13,
#  '협의': 13,
#  '참고': 13,
#  '일정': 13,
#  '자의': 13,
#  '보상': 13,
#  '성범죄': 13,
#  '사망': 13,
#  '사용자': 13,
#  '근로시간': 13,
#  '유통': 13,
#  '청년': 13,
#  '의과대학': 13,
#  '규정': 13,
#  '감염': 12,
#  '해외': 12,
#  '위기': 12,
#  '회의': 12,
#  '점자': 12,
#  '시장': 12,
#  '기본': 12,
#  '폐지': 12,
#  '경비': 12,
#  '형태': 12,
#  '중앙': 12,
#  '특례': 12,
#  '발의': 12,
#  '의안': 12,
#  '것이므': 12,
#  '수정': 12,
#  '대책': 12,
#  '윤리': 12,
#  '도시재생': 12,
#  '물질': 12,
#  '유기농': 12,
#  '유해': 12,
#  '미만': 12,
#  '고문': 12,
#  '진료': 12,
#  '위험': 12,
#  '평가': 12,
#  '교통': 12,
#  '지방의회': 12,
#  '수당': 12,
#  '폭행': 11,
#  '위생': 11,
#  '공급': 11,
#  '이자': 11,
#  '이익': 11,
#  '심사': 11,
#  '시민': 11,
#  '구성원': 11,
#  '과정': 11,
#  '효율': 11,
#  '구성': 11,
#  '안이': 11,
#  '신뢰': 11,
#  '자료': 11,
#  '대상자': 11,
#  '회계': 11,
#  '삭제': 11,
#  '정신': 11,
#  '평균': 11,
#  '벌금': 11,
#  '부여': 11,
#  '직접': 11,
#  '안전': 11,
#  '우리나라': 11,
#  '보조금': 11,
#  '의료행위': 11,
#  '예비': 11,
#  '치과': 11,
#  '스토킹': 11,
#  '전국': 10,
#  '질병': 10,
#  '전담': 10,
#  '따라서': 10,
#  '이자율': 10,
#  '제정': 10,
#  '중소기업': 10,
#  '신용': 10,
#  '상향': 10,
#  '손해배상': 10,
#  '부재': 10,
#  '전환': 10,
#  '거부': 10,
#  '상호': 10,
#  '탄소': 10,
#  '원칙': 10,
#  '서비스': 10,
#  '가운데': 10,
#  '공직자': 10,
#  '영향': 10,
#  '어업': 10,
#  '수업': 10,
#  '전부': 10,
#  '기여': 10,
#  '작성': 10,
#  '명칭': 10,
#  '과태료': 10,
#  '적극': 10,
#  '공개': 10,
#  '도록': 10,
#  '부지': 10,
#  '채권': 10,
#  '규모': 10,
#  '개월': 10,
#  '퇴직': 10,
#  '후보자': 10,
#  '한부모': 10,
#  '로펌': 10,
#  '타당성조사': 10,
#  '경영': 10,
#  '운동': 9,
#  '대응': 9,
#  '권고': 9,
#  '성적': 9,
#  '침해': 9,
#  '현재': 9,
#  '전체': 9,
#  '주요': 9,
#  '개인': 9,
#  '사례': 9,
#  '도의': 9,
#  '하도급': 9,
#  '필요성': 9,
#  '학생': 9,
#  '고객': 9,
#  '이외': 9,
#  '투기': 9,
#  '자산': 9,
#  '실제': 9,
#  '구체': 9,
#  '육성': 9,
#  '자재': 9,
#  '회복': 9,
#  '배제': 9,
#  '형사': 9,
#  '장기': 9,
#  '희생': 9,
#  '판결': 9,
#  '집단': 9,
#  '대리점': 9,
#  '강화': 9,
#  '행사': 9,
#  '전통': 9,
#  '전문': 9,
#  '실정': 9,
#  '사무': 9,
#  '흡연': 9,
#  '규제': 9,
#  '입학': 9,
#  '승인': 9,
#  '감사': 9,
#  '사립학교': 9,
#  '단축': 9,
#  '양육': 9,
#  '공탁': 9,
#  '집단소송': 9,
#  '대한': 9,
#  '여부': 8,
#  '상태': 8,
#  '코로나': 8,
#  '구축': 8,
#  '자금': 8,
#  '상담': 8,
#  '최고': 8,
#  '금융': 8,
#  '보조': 8,
#  '중단': 8,
#  '개발': 8,
#  '우리': 8,
#  '근절': 8,
#  '각종': 8,
#  '요청': 8,
#  '하나': 8,
#  '근무': 8,
#  '제대로': 8,
#  '도모': 8,
#  '이바지': 8,
#  '특성': 8,
#  '국유재산': 8,
#  '담당': 8,
#  '연도': 8,
#  '인력': 8,
#  '조례': 8,
#  '센터': 8,
#  '특정': 8,
#  '처분': 8,
#  '장의': 8,
#  '매년': 8,
#  '식품': 8,
#  '영세': 8,
#  '면적': 8,
#  '판매': 8,
#  '복지': 8,
#  '시효': 8,
#  '의학': 8,
#  '출신': 8,
#  '처리': 8,
#  '공직': 8,
#  '별도': 8,
#  '도급': 8,
#  '불공정': 8,
#  '체결': 8,
#  '갱신': 8,
#  '완화': 8,
#  '담보': 8,
#  '임대차': 8,
#  '임대': 8,
#  '민주화': 8,
#  '호의': 8,
#  '로서': 8,
#  '허가': 8,
#  '증명서': 8,
#  '자기': 8,
#  '정거': 8,
#  '점검': 8,
#  '피고인': 8,
#  '용도': 8,
#  '재원': 8,
#  '소유자': 8,
#  '취지': 8,
#  '유효': 8,
#  '신규': 8,
#  '남녀': 8,
#  '출생': 8,
#  '면허': 8,
#  '송금': 8,
#  '수단': 8,
#  '공보': 8,
#  '지역구': 8,
#  '배심원': 8,
#  '인수': 8,
#  '강간': 7,
#  '정도': 7,
#  '고하': 7,
#  '확산': 7,
#  '소상': 7,
#  '공인': 7,
#  '취약': 7,
#  '계층': 7,
#  '주의': 7,
#  '의사': 7,
#  '추세': 7,
#  '유공': 7,
#  '정의': 7,
#  '예상': 7,
#  '통지': 7,
#  '시간': 7,
#  '취하': 7,
#  '유인': 7,
#  '산정': 7,
#  '억제': 7,
#  '진행': 7,
#  '위원': 7,
#  '주장': 7,
#  '선택': 7,
#  '해소': 7,
#  '그린': 7,
#  '변화': 7,
#  '정함': 7,
#  '모든': 7,
#  '소규모': 7,
#  '화학물질': 7,
#  '공시': 7,
#  '농지': 7,
#  '발급': 7,
#  '최대': 7,
#  '심리': 7,
#  '선고': 7,
#  '기회': 7,
#  '각각': 7,
#  '일상': 7,
#  '성과': 7,
#  '성별': 7,
#  '가맹': 7,
#  '로부터': 7,
#  '가입자': 7,
#  '직원': 7,
#  '차이': 7,
#  '장애': 7,
#  '유지': 7,
#  '가구': 7,
#  '차량': 7,
#  '향상': 7,
#  '취소': 7,
#  '동물': 7,
#  '권유': 7,
#  '부가': 7,
#  '공사': 7,
#  '자산운용': 7,
#  '달리': 7,
#  '생명': 7,
#  '자격': 7,
#  '착오': 7,
#  '사후관리': 7,
#  '의약품': 7,
#  '표시': 7,
#  '출생신고': 7,
#  '사법': 7,
#  '대학원': 7,
#  '시정': 7,
#  '책임자': 7,
#  '전당': 7,
#  '익수': 7,
#  '국내': 6,
#  '보고': 6,
#  '비롯': 6,
#  '실질': 6,
#  '금전': 6,
#  '대차': 6,
#  '배기량': 6,
#  '효력': 6,
#  '단계': 6,
#  '문제점': 6,
#  '병행': 6,
#  '한정': 6,
#  '정화': 6,
#  '자가': 6,
#  '효과': 6,
#  '하향': 6,
#  '현실': 6,
#  '뉴딜정책': 6,
#  '조성': 6,
#  '구조': 6,
#  '해결': 6,
#  '동시': 6,
#  '실행': 6,
#  '행정': 6,
#  '국회의원': 6,
#  '매각': 6,
#  '통계': 6,
#  '기존': 6,
#  '친환경': 6,
#  '유기': 6,
#  '제시': 6,
#  '방송통신대': 6,
#  '대리': 6,
#  '구속': 6,
#  '실태': 6,
#  '공표': 6,
#  '확정': 6,
#  '산부인과': 6,
#  '경조사': 6,
#  '본인': 6,
#  '본사': 6,
#  '권한': 6,
#  '명의': 6,
#  '고용노동부': 6,
#  '탁자': 6,
#  '동안': 6,
#  '촉진': 6,
#  '보존': 6,
#  '관리인': 6,
#  '최저': 6,
#  '인승': 6,
#  '이상인': 6,
#  '매입': 6,
#  '가액': 6,
#  '에너지': 6,
#  '확인': 6,
#  '성희롱': 6,
#  '근로기준법': 6,
#  '평등': 6,
#  '양립': 6,
#  '고의': 6,
#  '기금': 6,
#  '인적': 6,
#  '수산물': 6,
#  '시술': 6,
#  '복무': 6,
#  '상대자': 6,
#  '법조': 6,
#  '정당': 6,
#  '일용': 6,
#  '공중': 6,
#  '화전': 6,
#  '동의': 5,
#  '국제': 5,
#  '가해자': 5,
#  '형법': 5,
#  '형량': 5,
#  '높이': 5,
#  '특수': 5,
#  '방식': 5,
#  '진자': 5,
#  '청장': 5,
#  '우선': 5,
#  '역할': 5,
#  '별로': 5,
#  '고통': 5,
#  '부업': 5,
#  '서민': 5,
#  '영업': 5,
#  '가중': 5,
#  '불법': 5,
#  '자동차': 5,
#  '면제': 5,
#  '세제': 5,
#  '기한': 5,
#  '중지': 5,
#  '자신': 5,
#  '탈취': 5,
#  '경쟁력': 5,
#  '대기업': 5,
#  '보전': 5,
#  '부정': 5,
#  '경쟁': 5,
#  '표준': 5,
#  '계약서': 5,
#  '개정안': 5,
#  '투명': 5,
#  '필수': 5,
#  '응대': 5,
#  '경비원': 5,
#  '공동': 5,
#  '지시': 5,
#  '실현': 5,
#  '기반': 5,
#  '전략': 5,
#  '행정기관': 5,
#  '대통령': 5,
#  '감소': 5,
#  '역시': 5,
#  '수요': 5,
#  '위원장': 5,
#  '주체': 5,
#  '여건': 5,
#  '공유': 5,
#  '증진': 5,
#  '현황': 5,
#  '부처': 5,
#  '고위': 5,
#  '재의': 5,
#  '선정': 5,
#  '제조': 5,
#  '이용자': 5,
#  '총장': 5,
#  '정원': 5,
#  '조직': 5,
#  '농업인': 5,
#  '상한': 5,
#  '보상금': 5,
#  '파악': 5,
#  '개별': 5,
#  '검찰': 5,
#  '구제': 5,
#  '협약': 5,
#  '진상': 5,
#  '직권': 5,
#  '고등': 5,
#  '경력': 5,
#  '신분': 5,
#  '검사': 5,
#  '존중': 5,
#  '전문의': 5,
#  '국가인권위': 5,
#  '대비': 5,
#  '계기': 5,
#  '규율': 5,
#  '광고': 5,
#  '부터': 5,
#  '회수': 5,
#  '직위해제': 5,
#  '수사': 5,
#  '사고': 5,
#  '요소': 5,
#  '전문성': 5,
#  '운용': 5,
#  '제재': 5,
#  '질서': 5,
#  '기능': 5,
#  '수집': 5,
#  '임용': 5,
#  '장기간': 5,
#  '건축물': 5,
#  '환경세': 5,
#  '이사회': 5,
#  '국가보훈처장': 5,
#  '종료': 5,
#  '체불': 5,
#  '대신': 5,
#  '가입': 5,
#  '중앙회': 5,
#  '모의': 5,
#  '주식': 5,
#  '일반': 5,
#  '소비자': 5,
#  '반환': 5,
#  '현장': 5,
#  '소비': 5,
#  '수의': 5,
#  '국회의원선거': 5,
#  '식생활': 5,
#  '출자': 5,
#  '태아': 5,
#  '유급': 5,
#  '형평성': 5,
#  '분배': 5,
#  '지금': 5,
#  '중인': 5,
#  '크레딧': 5,
#  '예측': 5,
#  '상업': 5,
#  '계열': 5,
#  '휴업': 5,
#  '중소': 5,
#  '배당': 5,
#  '장애등급': 5,
#  '공기업': 5,
#  '자본': 5,
#  '기탁금': 5,
#  '연령': 5,
#  '세로': 5,
#  '상병': 5,
#  '시가': 5,
#  '원가': 5,
#  '규칙': 5,
#  '중대': 5,
#  '사업': 5,
#  '잠정': 5,
#  '착취': 4,
#  '강간죄': 4,
#  '구성요건': 4,
#  '협박': 4,
#  '대법원': 4,
#  '현저': 4,
#  '상대방': 4,
#  '위계': 4,
#  '코로나바이러스': 4,
#  '재난': 4,
#  '서울': 4,
#  '국회': 4,
#  '경제활동': 4,
#  '이로': 4,
#  '입법': 4,
#  '대부': 4,
#  '법정': 4,
#  '퍼센트': 4,
#  '경기': 4,
#  '승용자동차': 4,
#  '과도': 4,
#  '연장': 4,
#  '측면': 4,
#  '조정제': 4,
#  '경감': 4,
#  '저해': 4,
#  '반드시': 4,
#  '입증': 4,
#  '고등학교': 4,
#  '폭언': 4,
#  '사전': 4,
#  '회로': 4,
#  '분야': 4,
#  '심화': 4,
#  '반복': 4,
#  '아이': 4,
#  '법적': 4,
#  '특별법': 4,
#  '국무총리': 4,
#  '교육부': 4,
#  '부위': 4,
#  '원장': 4,
#  '행정안전부': 4,
#  '감독': 4,
#  '더욱': 4,
#  '뿌리': 4,
#  '행위자': 4,
#  '가치': 4,
#  '책무': 4,
#  '생태계': 4,
#  '말일': 4,
#  '명세서': 4,
#  '농업': 4,
#  '입금': 4,
#  '치유': 4,
#  '인신': 4,
#  '경찰': 4,
#  '대한민국': 4,
#  '헌법': 4,
#  '임대주택': 4,
#  '명예': 4,
#  '군법': 4,
#  '기재': 4,
#  '확정판결': 4,
#  '당시': 4,
#  '목숨': 4,
#  '절반': 4,
#  '복종': 4,
#  '적정': 4,
#  '벌칙': 4,
#  '지난': 4,
#  '사태': 4,
#  '청구권': 4,
#  '요건': 4,
#  '정성': 4,
#  '한도': 4,
#  '상품': 4,
#  '교사': 4,
#  '징계': 4,
#  '개시': 4,
#  '분리': 4,
#  '한계': 4,
#  '물의': 4,
#  '인사': 4,
#  '해지': 4,
#  '수탁': 4,
#  '모두': 4,
#  '명문': 4,
#  '강제': 4,
#  '독점': 4,
#  '지위': 4,
#  '빈번': 4,
#  '공립': 4,
#  '연구': 4,
#  '논란': 4,
#  '존재': 4,
#  '단서': 4,
#  '합계': 4,
#  '경관': 4,
#  '전입': 4,
#  '확충': 4,
#  '비중': 4,
#  '재산세': 4,
#  '시일': 4,
#  '상환': 4,
#  '정관': 4,
#  '정지': 4,
#  '예산': 4,
#  '교부': 4,
#  '인재': 4,
#  '시험': 4,
#  '임의': 4,
#  '수의사': 4,
#  '강사': 4,
#  '발표': 4,
#  '방문': 4,
#  '가지': 4,
#  '과실': 4,
#  '징벌': 4,
#  '변호사': 4,
#  '반면': 4,
#  '범한': 4,
#  '불안감': 4,
#  '존속': 4,
#  '차임': 4,
#  '예금': 4,
#  '성명': 4,
#  '횟수': 4,
#  '재발': 4,
#  '가장': 4,
#  '주거': 4,
#  '니코틴': 4,
#  '표기': 4,
#  '시각장애인': 4,
#  '음성': 4,
#  '접근성': 4,
#  '책자': 4,
#  '환자': 4,
#  '연구원': 4,
#  '편중': 4,
#  '상위': 4,
#  '인상': 4,
#  '소송대리인': 4,
#  '송부': 4,
#  '금품': 4,
#  '산입': 4,
#  '손실': 4,
#  '혼인': 4,
#  '상권': 4,
#  '일원화': 4,
#  '예규': 4,
#  '학사': 4,
#  '선발': 4,
#  '후보': 4,
#  '피선거권': 4,
#  '재무제표': 4,
#  '평결': 4,
#  '경매': 4,
#  '접근': 4,
#  '경찰관': 4,
#  '내과': 4,
#  '법률': 4,
#  '경우': 4,
#  '자치': 4,
#  '자치구': 4,
#  '재판소': 3,
#  '여야': 3,
#  '추행': 3,
#  '위력': 3,
#  '유형': 3,
#  '통합': 3,
#  '감염증': 3,
#  '초기': 3,
#  '차단': 3,
#  '긴급': 3,
#  '방역': 3,
#  '크게': 3,
#  '위축': 3,
#  '자영': 3,
#  '간접': 3,
#  '연체': 3,
#  '상승': 3,
#  '시대': 3,
#  '취득세': 3,
#  '혜택': 3,
#  '보호자': 3,
#  '일몰': 3,
#  '화해': 3,
#  '일방': 3,
#  '종용': 3,
#  '궁극': 3,
#  '자체': 3,
#  '경향': 3,
#  '유출': 3,
#  '유용': 3,
#  '공정위': 3,
#  '자문': 3,
#  '민주주의': 3,
#  '교과': 3,
#  '관심': 3,
#  '불신': 3,
#  '저하': 3,
#  '여러': 3,
#  '참정권': 3,
#  '독립': 3,
#  '소재': 3,
#  '노동자': 3,
#  '갑질': 3,
#  '기타': 3,
#  '처우': 3,
#  '간의': 3,
#  '상생': 3,
#  '방향': 3,
#  '목표': 3,
#  '과제': 3,
#  ...}

# %% [markdown]
# # 5. '제안자' valuecount

# %%
df_20.head()
# Out:
#    Unnamed: 0     의안번호 처리여부                                        의안명 제안자구분  \
# 0           0  ZZ23959    계           「인공지능산업 진흥에 관한 법률안」에 대한 의견표명 결정문    기타
# 1           1  2024996    처               집합건물의 소유 및 관리에 관한 법률 일부개정법률안    의원
# 2           2  2024995    처                               지방세법 일부개정법률안    의원
# 3           3  2024994    처    법률용어 정비를 위한 정보위원회 소관 2개 법률 일부개정을 위한 법률안   위원장
# 4           4  2024993    처                진실·화해를 위한 과거사정리 기본법 일부개정법률안   위원장
#
#          제안일자        의결일자    의결결과  심사진행상태                   문서  \
# 0  2020-05-28         NaN     NaN     NaN                 의안원문
# 1  2020-05-22  2020-05-29  임기만료폐기     NaN                 의안원문
# 2  2020-05-22  2020-05-29  임기만료폐기     NaN  의안원문\n비용추계서 미첨부 사유서
# 3  2020-05-20  2020-05-20    원안가결     NaN                 의안원문
# 4  2020-05-20  2020-05-20    원안가결     NaN                 의안원문
#
#                      제안회기                                               제안이유  \
# 0  제20대 (2016~2020) 제378회                                                NaN
# 1  제20대 (2016~2020) 제378회  ■ 제안이유아파트 등 공동주택은 「공동주택관리법」에 의해 체계적으로 관리되고 있는 ...
# 2  제20대 (2016~2020) 제378회  제안이유 및 주요내용현행법상 아파트 등 주택에 대한 재산세 과세표준은 국토교통부가 ...
# 3  제20대 (2016~2020) 제378회                                                NaN
# 4  제20대 (2016~2020) 제378회                                                NaN
#
#      소관위원회                                                제안자  index  \
# 0      NaN                                                  a    NaN
# 1  법제사법위원회  ['김병관(더불어민주당/金炳官)',  '고용진(더불어민주당/高榕禛)',  '김병욱(...    NaN
# 2  행정안전위원회  ['김병관(더불어민주당/金炳官)',  '김철민(더불어민주당/金哲玟)',  '박재호(...    NaN
# 3    정보위원회                                                  a    NaN
# 4  행정안전위원회                                                  a    NaN
#
#                                                 제안의원      제안정당  \
# 0                                                NaN       NaN
# 1  [김병관, '고용진, '김병욱, '김철민, '박재호, '박정, '서형수, '심기준,...  [더불어민주당]
# 2  [김병관, '김철민, '박재호, '서형수, '심기준, '위성곤, '유승희, '이규희...  [더불어민주당]
# 3                                                NaN       NaN
# 4                                                NaN       NaN
#
#                                                 주요내용
# 0
# 1  가. 지방자치단체의 장은 조사 또는 감사 결과 관리인에게 부정한 행위나 그 밖에 그...
# 2  현행법상 아파트 등 주택에 대한 재산세 과세표준은 국토교통부가 해마다 「부동산 가격...
# 3
# 4

# %%
lawmaker_20 = df_20['제안의원'].apply(lambda x: pd.Series(x)).stack()
lawmaker_21 = df_21['제안의원'].apply(lambda x: pd.Series(x)).stack()

# %%
lawmaker_20 = lawmaker_20.replace("a",np.NaN)
lawmaker_21 = lawmaker_21.replace("a",np.NaN)

# %%
maker20 = lawmaker_20.value_counts().keys().tolist()
count20 = lawmaker_20.value_counts().tolist()
DF_lawmaker20 = pd.DataFrame(data={'maker':maker20, 'count':count20})

maker21 = lawmaker_21.value_counts().keys().tolist()
count21 = lawmaker_21.value_counts().tolist()
DF_lawmaker21 = pd.DataFrame(data={'maker':maker21, 'count':count21})

# %%
DF_lawmaker20.head(10)
# Out:
#   maker  count
# 0  '이찬열   3997
# 1  '신창현   3490
# 2   '박정   2696
# 3  '황주홍   2678
# 4  '김철민   2416
# 5  '윤관석   2413
# 6  '김해영   2379
# 7  '이동섭   2334
# 8  '김정우   2170
# 9  '윤후덕   2070

# %%
DF_lawmaker21.head(10)
# Out:
#   maker  count
# 0  '김경만    444
# 1  '이수진    441
# 2   '박정    414
# 3  '박성준    368
# 4  '김병욱    349
# 5  '임종성    344
# 6  '황운하    337
# 7  '양정숙    324
# 8  '김철민    318
# 9  '신정훈    308
